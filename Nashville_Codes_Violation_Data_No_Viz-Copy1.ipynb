# %% [markdown]
# #### Import packages

# %%
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns
from collections import Counter
from nltk.tokenize import word_tokenize
import numpy as np
import re
import psycopg2
from sklearn.preprocessing import binarize

# %matplotlib inline

# %% [markdown]
# #### Read in Codes Excel file, make all uppercase, drop all bad rows, set index to be Violation_ID

# %%
codes_df = pd.read_excel(io='Codes\' List of Violations 15 aug 2017.xlsx', 
                         usecols=[0,2,3,4], 
                         names=['VIOLATION_ID', 'VIOLATION_TYPE', 'VIOLATION_DESC', 'VIOLATION_TEXT'],
                         dtype={'VIOLATION_ID': object, 'VIOLATION_TYPE': object, 'VIOLATION_DESC': object, 'VIOLATION_TEXT': object}
                        )
codes_df = codes_df.dropna(axis=0, subset=['VIOLATION_TYPE'])
codes_df.set_index('VIOLATION_ID', inplace=True)
codes_df = codes_df.apply(lambda x: x.astype(str).str.upper())
codes_df.head(10)
# Out:
#              VIOLATION_TYPE                      VIOLATION_DESC  \
# VIOLATION_ID
# 1                   BANNERS                             BANNERS
# 2                BGMATOWNER      PROPER MAINTENANCE REQ - OWNER
# 4                 BLDGMAINT              PROPER MAINTENANCE REQ
# 5                BLDGPERMIT            BUILDING PERMIT REQUIRED
# 6                 BLDGSCOPE              SCOPE OF BUILDING CODE
# 7                BOARDINGRQ               BOARDING REQUIREMENTS
# 8                  BOARDVAC        BOARDING OF VACANT BUILDINGS
# 9                    CARROW         VEHICLE IN THE RIGHT-OF-WAY
# 10                 CERTCOMP  CERTIFICATE OF COMPLIANCE REQUIRED
# 11                  CERTOCC   CERTIFICATE OF OCCUPANCY REQUIRED
#
#                                                  VIOLATION_TEXT
# VIOLATION_ID
# 1             SECTION 17.32.060 & 17.32.070 -  BANNERS: BANN...
# 2             SECTION 16.16.030 (B) - PROPER MAINTENANCE REQ...
# 4             SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 5             SECTION 16.28.010 - BUILDING PERMIT REQUIRED: ...
# 6             SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 7             SECTION 16.24.340 (U) (2) – BOARDING OF VACANT...
# 8             SECTION 16.24.340 (U) (1) – BOARDING OF VACANT...
# 9             SECTION 12.08.210 - ABANDONED VEHICLES: ABANDO...
# 10            SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 11            SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...

# %% [markdown]
# #### Add column for new categories

# %%
codes_df['VIOLATION_CATEGORY'] = ''
codes_df.head(10)
# Out:
#              VIOLATION_TYPE                      VIOLATION_DESC  \
# VIOLATION_ID
# 1                   BANNERS                             BANNERS
# 2                BGMATOWNER      PROPER MAINTENANCE REQ - OWNER
# 4                 BLDGMAINT              PROPER MAINTENANCE REQ
# 5                BLDGPERMIT            BUILDING PERMIT REQUIRED
# 6                 BLDGSCOPE              SCOPE OF BUILDING CODE
# 7                BOARDINGRQ               BOARDING REQUIREMENTS
# 8                  BOARDVAC        BOARDING OF VACANT BUILDINGS
# 9                    CARROW         VEHICLE IN THE RIGHT-OF-WAY
# 10                 CERTCOMP  CERTIFICATE OF COMPLIANCE REQUIRED
# 11                  CERTOCC   CERTIFICATE OF OCCUPANCY REQUIRED
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 1             SECTION 17.32.060 & 17.32.070 -  BANNERS: BANN...
# 2             SECTION 16.16.030 (B) - PROPER MAINTENANCE REQ...
# 4             SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 5             SECTION 16.28.010 - BUILDING PERMIT REQUIRED: ...
# 6             SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 7             SECTION 16.24.340 (U) (2) – BOARDING OF VACANT...
# 8             SECTION 16.24.340 (U) (1) – BOARDING OF VACANT...
# 9             SECTION 12.08.210 - ABANDONED VEHICLES: ABANDO...
# 10            SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 11            SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %% [markdown]
# #### Add new categories based on criteria

# %% [markdown]
# ##### * alcohol violations are those whose VIOLATION_TYPE starts with 'BB' or whose VIOLATION_TEXT starts with 'T.C.A 57-5'. This is split into two categories: 'ALCOHOL -- PERMITS' and 'ALCOHOL -- OTHER'

# %%
codes_df.loc[(codes_df['VIOLATION_TYPE'].str.match('BB.*') | 
              codes_df['VIOLATION_TEXT'].str.match('T.C.A 57-5.*')) &
              codes_df['VIOLATION_DESC'].str.contains('PERMIT')
             , 'VIOLATION_CATEGORY'] = 'ALCOHOL -- PERMITS'

codes_df.loc[(codes_df['VIOLATION_CATEGORY'] == 'ALCOHOL -- PERMITS')]
# Out:
#              VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 781                BB708020                    SALES WITHOUT A PERMIT
# 784               BB708030D                            CATERER PERMIT
# 793               BB708070C                         BB PERMIT DISPLAY
# 794               BB708070D                BB OFF SALE PERMIT DISPLAY
# 795                BB708080               BB PERMIT ADDRESS DISPLAYED
# 796                BB708100      ON SALE PERMIT ISSUANCE REQUIREMENTS
# 798               BB708105D   CATERER LOCATION REVOKED ON SALE PERMIT
# 831                BB708220               BB BEER PERMIT NOT RETURNED
# 836               BB708230E                BB ON AND OFF SALES PERMIT
# 837               BB708230F               BB CATERER PERMIT EACH SITE
# 843                BB720020          PERMIT SUSPENSION AND REVOCATION
# 855              BT575103A1      OPERATING WITHOUT COUNTY CITY PERMIT
# 856             BT575103A10         PERMITS TO CITIZEN LEGAL RESIDENT
# 857              BT575103A2                  PERMIT TO BUSINESS OWNER
# 859             BT575103A3B           PERMIT FOR SINGLE LOCATION ONLY
# 860             BT575103A3C         BUSINESS NAME SAME AS PERMIT NAME
# 861              BT575103A4    TWO BUSINESSES ONE LOCATION ONE PERMIT
# 862              BT575103A5               ON SALE OFF SALE ONE PERMIT
# 870              BT575105B5  ONSALE PERMIT FOR ON PREMISE CONSUMPTION
# 884              BT575111D3   HOMEMADE BEER STORAGE ON PERMITTED SITE
# 890               BT575207A              FAILURE TO PERMIT INSPECTION
# 943                   BBR12                     PERMITTEE RESPONSIBLE
# 952                   BBR21                         SURRENDER PERMITS
# 957                   BBR29  CANNOT TEMPORARY PERMITS WITH COMPLAINTS
# 961                   BBR32                           CATERER PERMITS
# 966                   BBR37                     SPECIAL EVENT PERMITS
# 968                   BBR40                DENY PERMIT AFTER 6 MONTHS
# 969                   BBR41          NO PERMIT ISSUED WITH COMPLAINTS
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 781           M.C.L 7.08.020: NO PERSON SHALL SELL BEER WITH...
# 784           M.C.L 7.08.030D: A CATERER'S PERMIT SHALL BE I...
# 793           M.C.L 7.08.070C: THE PERMIT HOLDER SHALL DISPL...
# 794           M.C.L 7.08.070D: THE HOLDER OF A RETAILER'S "O...
# 795           M.C.L 7.08.080: THE SPECIFIC ADDRESS OR DESCRI...
# 796           M.C.L 7.08.100: RETAILER ON-SALE BEER PERMITS ...
# 798           M.C.L 7.08.105D: NO CATERER'S PERMIT SHALL BE ...
# 831           M.C.L 7.08.220: A PERMIT HOLDER MUST RETURN HI...
# 836           M.C.L 7.08.230E: A PERMIT SHALL BE VALID FOR A...
# 837           M.C.L 7.08.230F: A CATERER'S PERMIT IS VALID F...
# 843           M.C.L SECTION 7.20.020: IN ADDITION TO ANY OTH...
# 855           T.C.A 57-5-103(A)(1): IT IS UNLAWFUL TO OPERAT...
# 856           T.C.A 57-5-103(A)(10): AFTER JULY 1, 2015, A C...
# 857           T.C.A 57-5-103(A)(2): PERMITS SHALL BE ISSUED ...
# 859           T.C.A 57-5-103(A)(3)(B): A PERMIT SHALL BE VAL...
# 860           T.C.A 57-5-103(A)(3)(C): A PERMIT SHALL BE VAL...
# 861           T.C.A 57-5-103(A)(4): WHERE AN OWNER OPERATES ...
# 862           T.C.A 57-5-103(A)(5): A BUSINESS CAN SELL BEER...
# 870           T.C.A 57-5-105(B)(5): IN ORDER TO RECEIVE A PE...
# 884           T.C.A 57-5-111(D)(3): IF THE CONTEST, COMPETIT...
# 890           T.C.A 57-5-207(A): THE FAILURE OF ANY PERSON, ...
# 943           IN DISCIPLINARY PROCEEDINGS, IT SHALL BE NO DE...
# 952           PERMITTEES SHALL SURRENDER THEIR PERMITS, IN P...
# 957           TEMPORARY PERMITS SHALL NOT BE ISSUED BY THE E...
# 961           PURSUANT TO METROPOLITAN CODE OF LAWS SECTION ...
# 966           APPLICANTS FOR SPECIAL EVENT PERMITS WILL BE L...
# 968           IF AN APPLICATION HAS NOT BEEN GRANTED OR DENI...
# 969           A PERMIT SHALL NOT BE ISSUED BY THE EXECUTIVE ...
#
#               VIOLATION_CATEGORY
# VIOLATION_ID
# 781           ALCOHOL -- PERMITS
# 784           ALCOHOL -- PERMITS
# 793           ALCOHOL -- PERMITS
# 794           ALCOHOL -- PERMITS
# 795           ALCOHOL -- PERMITS
# 796           ALCOHOL -- PERMITS
# 798           ALCOHOL -- PERMITS
# 831           ALCOHOL -- PERMITS
# 836           ALCOHOL -- PERMITS
# 837           ALCOHOL -- PERMITS
# 843           ALCOHOL -- PERMITS
# 855           ALCOHOL -- PERMITS
# 856           ALCOHOL -- PERMITS
# 857           ALCOHOL -- PERMITS
# 859           ALCOHOL -- PERMITS
# 860           ALCOHOL -- PERMITS
# 861           ALCOHOL -- PERMITS
# 862           ALCOHOL -- PERMITS
# 870           ALCOHOL -- PERMITS
# 884           ALCOHOL -- PERMITS
# 890           ALCOHOL -- PERMITS
# 943           ALCOHOL -- PERMITS
# 952           ALCOHOL -- PERMITS
# 957           ALCOHOL -- PERMITS
# 961           ALCOHOL -- PERMITS
# 966           ALCOHOL -- PERMITS
# 968           ALCOHOL -- PERMITS
# 969           ALCOHOL -- PERMITS

# %%
codes_df.loc[(codes_df['VIOLATION_TYPE'].str.match('BB.*') | 
              codes_df['VIOLATION_TEXT'].str.match('T.C.A 57-5.*')) &
              ~codes_df['VIOLATION_DESC'].str.contains('PERMIT')
             , 'VIOLATION_CATEGORY'] = 'ALCOHOL -- OTHER'

codes_df.loc[(codes_df['VIOLATION_CATEGORY'] == 'ALCOHOL -- OTHER')]
# Out:
#              VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 782               BB708030B    OFF SALE - CONSUME ON OR NEAR PREMISES
# 783               BB708030C   ON SALE REQUIRED FOR ON PREMISE CONSUME
# 785               BB708030E         SPECIAL EVENT - SALES ON PREMISES
# 786              BB708040B3  OWNERS CONVICT BEER LAWS MORAL TURPITUDE
# 787              BB708040B5       OWNERS INCARCERATED MORAL TURPITUDE
# 788               BB708040G      SUPPLEMENTAL APPLICATION INFORMATION
# 789               BB708040H            FALSE STATEMENT ON APPLICATION
# 790               BB708060B                  PAYMENT OF PRIVILEGE TAX
# 791               BB708070A                           BB PUBLIC PLACE
# 792               BB708070B                     BB INVOICES AND MEMOS
# 797               BB708105C         CATERER ADVANCED NOTICE OF EVENTS
# 799               BB708105E   CATERER IN 100 FEET OF CHURCH OR SCHOOL
# 800                BB708110                  LIQUOR SALES TO UNDER 21
# 801               BB708130A           BB PROHIBITED DRUGS ON PREMISES
# 802               BB708130B        BB BEVERAGE IN EXCESS OF 8 PERCENT
# 803               BB708130C                    BB POSSESSION UNDER 21
# 804               BB708140A            BB EMPLOY ANY PERSON CONVICTED
# 805               BB708140B             BB EMPLOY ANY PERSON RELEASED
# 806               BB708140C                 BB SELL TO UNDER 21 YEARS
# 807               BB708140D                   BB SELL BETWEEN 3AM-6AM
# 808               BB708140E                        BB UNDER 18 LOITER
# 809               BB708140F            BB FALSE STATEMENT APPLICATION
# 810               BB708140G               BB OPERATE DISORDERLY PLACE
# 811               BB708140H              BB UNLAWFUL PASSING TO MINOR
# 812               BB708140I              BB SELL FOR PASSING TO MINOR
# 813               BB708140J                     BB DISORDERLY CONDUCT
# 814               BB708140K                  BB UNAUTHORIZED TRANSFER
# 815               BB708140L                    BB SALE TO INTOXICATED
# 816               BB708140M                     BB INTOXICATED LOITER
# 817               BB708140O                      BB DELIVERY 11PM-3AM
# ...                     ...                                       ...
# 933              BB708090A1                                  DISTANCE
# 934               BT5751038                                  DISTANCE
# 935                   BBR11                 POST LAWS AND REGULATIONS
# 936                    BBR1                      TEMP LICENSE ALLOWED
# 937                    BBR2            COMMERCIALLY SEALED CONTAINERS
# 938                    BBR3        UNDER 18 TRANSPORT, SELL, DISPENSE
# 939                    BBR6                  NO DRIVE-THROUGH SERVICE
# 940                    BBR8  SPECIAL EVENT BONAFIDE CHARITY POLITICAL
# 941                    BBR9                   ALL OWNERS AND PARTNERS
# 942                   BBR10                               NO DELIVERY
# 944                   BBR13               LEASE OR OWNERSHIP REQUIRED
# 945                  BBR14A                    ALL APPLICANTS OVER 21
# 946                  BBR14B                          ASCERTAINING AGE
# 947                   BBR15                   SPECIAL EVENT APPROVALS
# 948                   BBR16                    PAYMENT TYPES ACCEPTED
# 949                   BBR17                 CRIMES OF MORAL TURPITUDE
# 950                   BBR18                         HEALTH DEPARTMENT
# 951                   BBR19                              FIRE MARSHAL
# 953                   BBR22               COMPLAINTS FILED IN WRITING
# 954                   BBR24                       OLD OR NEW LOCATION
# 955                   BBR26                APPLICATIONS 10 DAYS PRIOR
# 956                   BBR28       CANNOT SURRENDER TO AVOID PENALTIES
# 959                   BBR30                             GRANDFATHERED
# 960                   BBR31                         EXPANDED PREMISES
# 962                   BBR34                        STANDARD PENALTIES
# 963                   BBR33                PAST VIOLATIONS CONSIDERED
# 964                   BBR35                    LLC EQUALS CORPORATION
# 965                   BBR36            NO MOTIONS FOR RECONSIDERATION
# 967                   BBR38                          SUSPENSION RULES
# 970                   BBR39               SPORTS AUTHORITY FACILITIES
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 782           M.C.L 7.08.030B: A RETAILER'S "OFF-SALE" PERMI...
# 783           M.C.L 7.08.030C: A RETAILER'S "ON-SALE" PERMIT...
# 785           M.C.L 7.08.030E: A RETAILER'S SPECIAL EVENTS P...
# 786           M.C.L 7.08.040B3: THAT NO PERSON, FIRM, CORPOR...
# 787           M.C.L 7.08.040B5: THAT NO PERSON HAVING AT LEA...
# 788           M.C.L 7.08.040G: AN APPLICANT OR PERMIT HOLDER...
# 789           M.C.L 7.08.040H: ANY APPLICANT MAKING A FALSE ...
# 790           M.C.L 7.08.060B: ALL PERMIT HOLDERS SHALL PAY ...
# 791           M.C.L 7.08.070A: THE PREMISES ARE DECLARED TO ...
# 792           M.C.L 7.08.070B: THE PERMIT HOLDER SHALL KEEP ...
# 797           M.C.L 7.08.105C: ALL CATERER'S PERMIT HOLDERS ...
# 799           M.C.L 7.08.105E: NO CATERER'S PERMIT SHALL BE ...
# 800           M.C.L 7.08.110: FOR ANY VIOLATION OF ANY PROVI...
# 801           M.C.L 7.08.130A: IT IS UNLAWFUL FOR ANY PERSON...
# 802           M.C.L 7.08.130B: IT IS UNLAWFUL FOR ANY PERSON...
# 803           M.C.L 7.08.130C: IT IS UNLAWFUL FOR ANY PERSON...
# 804           M.C.L 7.08.140A: IT IS UNLAWFUL FOR ANY BEER P...
# 805           M.C.L 7.08.140B: IT IS UNLAWFUL FOR ANY BEER P...
# 806           M.C.L 7.08.140C: IT IS UNLAWFUL FOR ANY BEER P...
# 807           M.C.L 7.08.140D: IT IS UNLAWFUL FOR ANY BEER P...
# 808           M.C.L 7.08.140E: IT IS UNLAWFUL FOR ANY BEER P...
# 809           M.C.L 7.08.140F: IT IS UNLAWFUL FOR ANY BEER P...
# 810           M.C.L 7.08.140G: IT IS UNLAWFUL FOR ANY BEER P...
# 811           M.C.L 7.08.140H: IT IS UNLAWFUL FOR ANY BEER P...
# 812           M.C.L 7.08.140I: IT IS UNLAWFUL FOR ANY BEER P...
# 813           M.C.L 7.08.140J: IT IS UNLAWFUL FOR ANY BEER P...
# 814           M.C.L 7.08.140K: IT IS UNLAWFUL FOR ANY BEER P...
# 815           M.C.L 7.08.140L: IT IS UNLAWFUL FOR ANY BEER P...
# 816           M.C.L 7.08.140M: IT IS UNLAWFUL FOR ANY BEER P...
# 817           M.C.L 7.08.140O: IT IS UNLAWFUL FOR ANY BEER P...
# ...                                                         ...
# 933           M.C.L 7.08.090A1: NO BEER PERMIT SHALL BE ISSU...
# 934           T.C.A 57-5-103(8): ANY PERSON, FIRM, CORPORATI...
# 935           ALL RETAIL PERMITTEES SHALL CONSPICUOUSLY POST...
# 936           THE EXECUTIVE SECRETARY TO THE METROPOLITAN BE...
# 937           AN OFF-SALE BEER PERMITTEE SHALL SELL BEER ONL...
# 938           NO PERSON UNDER 18 YEARS OF AGE SHALL TRANSPOR...
# 939           BEER SHALL NOT BE SOLD THROUGH ANY DRIVE-THROU...
# 940           SPECIAL EVENTS HELD ON PUBLIC PROPERTY CAN ONL...
# 941           ALL APPLICANTS FOR BEER PERMITS MUST SUPPLY TH...
# 942           NO PERMITTEE NOR ANY OF HIS/HER AGENTS SHALL D...
# 944           WHEN APPLYING FOR AN ON OR OFF-SALE PERMIT, AL...
# 945           ALL APPLICANTS FOR A PERMIT OF ANY KIND RELATI...
# 946           WHEN ASCERTAINING THE AGE OF A PERSON PURCHASI...
# 947           WHEN APPLYING FOR A SPECIAL EVENT PERMIT, APPL...
# 948           ALL APPLICATION FEES FOR BEER PERMITS AND BEER...
# 949           THE METROPOLITAN BEER PERMIT BOARD RECOGNIZES ...
# 950           UPON MAKING APPLICATION FOR A BEER PERMIT FROM...
# 951           UPON MAKING APPLICATION FOR AN ON-SALE BEER PE...
# 953           ALL COMPLAINTS REQUESTED TO BE HEARD BY THE ME...
# 954           AN OLD LOCATION IS ANY LOCATION THAT HAS HAD A...
# 955                                                     RULE 26
# 956           A PERMIT HOLDER MAY NOT AVOID A HEARING OR PRO...
# 959           1. THE GRANDFATHER CLAUSE OF ORDINANCE 092-246...
# 960           NO PERMITTEE SHALL EXPAND THE PREMISES FOR WHI...
# 962           THE FOLLOWING CONSTITUTES STANDARD PENALTIES F...
# 963           THE BEER BOARD SHALL CONSIDER A PERMIT HOLDER'...
# 964           FOR ALL PURPOSES UNDER THE METROPOLITAN BEER L...
# 965           THE BEER PERMIT BOARD SHALL NOT ENTERTAIN MOTI...
# 967           UPON SUSPENSION OF A BEER PERMIT, THE PERMITTE...
# 970           THIS RULE IS APPLICABLE ONLY TO BEER SALES WIT...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 782            ALCOHOL -- OTHER
# 783            ALCOHOL -- OTHER
# 785            ALCOHOL -- OTHER
# 786            ALCOHOL -- OTHER
# 787            ALCOHOL -- OTHER
# 788            ALCOHOL -- OTHER
# 789            ALCOHOL -- OTHER
# 790            ALCOHOL -- OTHER
# 791            ALCOHOL -- OTHER
# 792            ALCOHOL -- OTHER
# 797            ALCOHOL -- OTHER
# 799            ALCOHOL -- OTHER
# 800            ALCOHOL -- OTHER
# 801            ALCOHOL -- OTHER
# 802            ALCOHOL -- OTHER
# 803            ALCOHOL -- OTHER
# 804            ALCOHOL -- OTHER
# 805            ALCOHOL -- OTHER
# 806            ALCOHOL -- OTHER
# 807            ALCOHOL -- OTHER
# 808            ALCOHOL -- OTHER
# 809            ALCOHOL -- OTHER
# 810            ALCOHOL -- OTHER
# 811            ALCOHOL -- OTHER
# 812            ALCOHOL -- OTHER
# 813            ALCOHOL -- OTHER
# 814            ALCOHOL -- OTHER
# 815            ALCOHOL -- OTHER
# 816            ALCOHOL -- OTHER
# 817            ALCOHOL -- OTHER
# ...                         ...
# 933            ALCOHOL -- OTHER
# 934            ALCOHOL -- OTHER
# 935            ALCOHOL -- OTHER
# 936            ALCOHOL -- OTHER
# 937            ALCOHOL -- OTHER
# 938            ALCOHOL -- OTHER
# 939            ALCOHOL -- OTHER
# 940            ALCOHOL -- OTHER
# 941            ALCOHOL -- OTHER
# 942            ALCOHOL -- OTHER
# 944            ALCOHOL -- OTHER
# 945            ALCOHOL -- OTHER
# 946            ALCOHOL -- OTHER
# 947            ALCOHOL -- OTHER
# 948            ALCOHOL -- OTHER
# 949            ALCOHOL -- OTHER
# 950            ALCOHOL -- OTHER
# 951            ALCOHOL -- OTHER
# 953            ALCOHOL -- OTHER
# 954            ALCOHOL -- OTHER
# 955            ALCOHOL -- OTHER
# 956            ALCOHOL -- OTHER
# 959            ALCOHOL -- OTHER
# 960            ALCOHOL -- OTHER
# 962            ALCOHOL -- OTHER
# 963            ALCOHOL -- OTHER
# 964            ALCOHOL -- OTHER
# 965            ALCOHOL -- OTHER
# 967            ALCOHOL -- OTHER
# 970            ALCOHOL -- OTHER
#
# [154 rows x 4 columns]

# %% [markdown]
# ##### * plumbing violations are those whose VIOLATION_TYPE starts with 'CAP' or whose VIOLATION_TEXT starts with 'SECTION 16.24.410', 'SECTION 16.24.420', 'SECTION 16.24.430', 'SECTION 16.24.440', or 'SECTION 16.24.450'

# %%
codes_df.loc[(codes_df['VIOLATION_TYPE'].str.contains('CAP.*') | 
              codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.4[12345]0')), 
             'VIOLATION_CATEGORY'] = 'PLUMBING'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'PLUMBING']
# Out:
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 146                      PLUMDWLUT                 PLUMBING – DWELLING UNITS
# 147                      PLUMEMFAC            PLUMBING – EMPLOYEE FACILITIES
# 148                      PLUMFIXCL      PLUMBING SYSTEMS – FIXTURE CLEARANCE
# 149                     PLUMGENREQ   PLUMBING SYSTEMS – GENERAL REQUIREMENTS
# 150                      PLUMHOTEL                          PLUMBING – HOTEL
# 151                      PLUMRMHSE                 PLUMBING – ROOMING HOUSES
# 152                     PLUMSYSHAZ         PLUMBING SYSTEMS – SYSTEM HAZARDS
# 164                     SANDRAINMT    SANITARY DRAINAGE SYSTEM – MAINTENANCE
# 165                     SANDRAINSY        SANITARY DRAINAGE SYSTEM – GENERAL
# 193                       TOLRMLOC                   TOILET ROOMS – LOCATION
# 194                      TOLRMPRVC                    TOILET ROOMS – PRIVACY
# 195                     TOLRNLOCEM  TOILET ROOMS – EMPLOYEE TOILET FACILITIE
# 206                       WATERCON             WATER SYSTEM – CONTAMINATION
# 207                       WATERGEN                    WATER SYSTEM – GENERAL
# 208                       WATERSUP                            WATER – SUPPLY
# 209                     WATERWTRHT          WATER – WATER HEATING FACILITIES
# 530                CAAP_PLUM_DWLUT                 PLUMBING – DWELLING UNITS
# 531                CAAP_PLUM_EMFAC            PLUMBING – EMPLOYEE FACILITIES
# 532                CAAP_PLUM_FIXCL      PLUMBING SYSTEMS – FIXTURE CLEARANCE
# 533               CAAP_PLUM_GENREQ   PLUMBING SYSTEMS – GENERAL REQUIREMENTS
# 534                CAAP_PLUM_HOTEL                          PLUMBING – HOTEL
# 535                CAAP_PLUM_RMHSE                 PLUMBING – ROOMING HOUSES
# 536               CAAP_PLUM_SYSHAZ         PLUMBING SYSTEMS – SYSTEM HAZARDS
# 537           CAAP_SAN_DRAIN_MAINT    SANITARY DRAINAGE SYSTEM – MAINTENANCE
# 538             CAAP_SAN_DRAIN_SYS        SANITARY DRAINAGE SYSTEM – GENERAL
# 539                 CAAP_TOLRM_LOC                   TOILET ROOMS – LOCATION
# 540                CAAP_TOLRM_PRVC                    TOILET ROOMS – PRIVACY
# 541             CAAP_TOLRN_LOCEMFC  TOILET ROOMS – EMPLOYEE TOILET FACILITIE
# 542              CAAP_WATER_CONTAM              WATER SYSTEM – CONTAMINATION
# 543                 CAAP_WATER_GEN                    WATER SYSTEM – GENERAL
# ...                            ...                                       ...
# 682                          CAP21                PAN UNDER THE WATER HEATER
# 683                          CAP22                    WATER HEATER INSTALLED
# 684                          CAP23                    DEFECTIVE WATER HEATER
# 685                          CAP24      UNSTOP THE DRAIN ON THE KITCHEN SINK
# 686                          CAP25    UNSTOP THE DRAIN ON THE LAVATORY BASIN
# 687                          CAP26           UNSTOP THE DRAIN ON THE BATHTUB
# 688                          CAP27            UNSTOP THE DRAIN ON THE SHOWER
# 689                          CAP28     UNSTOP THE DRAIN / FLUSH WATER CLOSET
# 690                          CAP29           DAMAGED FLUSH WATER CLOSET SEAT
# 691                          CAP30                    DAMAGED BUILDING DRAIN
# 692                          CAP31          EXTEND THE VENTS A MINIMUM OF 6”
# 693                          CAP32                       DEFECTIVE SUMP PUMP
# 694                          CAP33        TRAP FOR THE WASHING MACHINE DRAIN
# 695                          CAP34             CONNECT WASHING MACHINE DRAIN
# 696                          CAP35      BROKEN TOP ON THE FLUSH WATER CLOSET
# 697                          CAP36     MISSING TOP ON THE FLUSH WATER CLOSET
# 698                          CAP37        DAMAGED OR LEAKING AERATOR SPRAYER
# 699                          CAP38       DAMAGED PLUMBING WATER SUPPLY LINES
# 700                          CAP39          DAMAGED COUNTER TOP WORK SURFACE
# 701                          CAP40   OUTSIDE WATER FAUCET HANDLE AND FIXTURE
# 702                          CAP41      DAMAGED CLEAN OUT PLUG ON SEWER LINE
# 703                          CAP42       DAMAGED DRAIN LINES UNDER THE HOUSE
# 704                          CAP43         VENT TO THE OUTSIDE FOR THE DRYER
# 705                          CAP44           FAUCETS FOR THE WASHING MACHINE
# 706                          CAP45          UNSTOP THE WASHING MACHINE DRAIN
# 707                          CAP46   RE-SECURE THE WATER CLOSET TO THE FLOOR
# 708                          CAP47                 VENT FOR THE WATER CLOSET
# 709                          CAP48                    OTHER PLUMBING DEFECTS
# 710                          CAP50                               EXHAUST FAN
# 711                          CAP51              PLUMBING EMPLOYEE FACILITIES
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 146           SECTION 16.24.410 (A) - PLUMBING (DWELLING UNI...
# 147           SECTION 16.24.410 (D) - PLUMBING (EMPLOYEE FAC...
# 148           SECTION 16.24.430 (B) - PLUMBING SYSTEMS (FIXT...
# 149           SECTION 16.24.430 (A) - PLUMBING SYSTEMS (GENE...
# 150           SECTION 16.24.410 (C) - PLUMBING (HOTEL) WHERE...
# 151           SECTION 16.24.410 (B) - PLUMBING (ROOMING HOUS...
# 152           SECTION 16.24.430 (C) - PLUMBING SYSTEMS (HAZA...
# 164           SECTION 16.24.450 (B) - SANITARY DRAINAGE (MAI...
# 165           SECTION 16.24.450 (A) - SANITARY DRAINAGE (GEN...
# 193           SECTION 16.24.420 (B) - TOILET ROOMS (LOCATION...
# 194           SECTION 16.24.420 (A) - TOILET ROOMS (PRIVACY)...
# 195           SECTION 16.24.420 (C) - TOILET ROOMS TOILET FA...
# 206           SECTION 16.24.440 (B) - WATER SYSTEM (CONTAMIN...
# 207           SECTION 16.24.440 (A) - WATER SYSTEM (GENERAL)...
# 208           SECTION 16.24.440 (C) - WATER (SUPPLY) THE WAT...
# 209           SECTION 16.24.440 (D) - WATER (HEATING) WATER ...
# 530           SECTION 16.24.410 (A) - PLUMBING (DWELLING UNI...
# 531           SECTION 16.24.410 (D) - PLUMBING (EMPLOYEE FAC...
# 532           SECTION 16.24.430 (B) - PLUMBING SYSTEMS (FIXT...
# 533           SECTION 16.24.430 (A) - PLUMBING SYSTEMS (GENE...
# 534           SECTION 16.24.410 (C) - PLUMBING (HOTEL) WHERE...
# 535           SECTION 16.24.410 (B) - PLUMBING (ROOMING HOUS...
# 536           SECTION 16.24.430 (C) - PLUMBING SYSTEMS (HAZA...
# 537           SECTION 16.24.450 (B) - SANITARY DRAINAGE (MAI...
# 538           SECTION 16.24.450 (A) - SANITARY DRAINAGE (GEN...
# 539           SECTION 16.24.420 (B) - TOILET ROOMS (LOCATION...
# 540           SECTION 16.24.420 (A) - TOILET ROOMS (PRIVACY)...
# 541           SECTION 16.24.420 (C) - TOILET ROOMS TOILET FA...
# 542           SECTION 16.24.440 (B) - WATER SYSTEM (CONTAMIN...
# 543           SECTION 16.24.440 (A) - WATER SYSTEM (GENERAL)...
# ...                                                         ...
# 682                                                         NAN
# 683                                                         NAN
# 684                                                         NAN
# 685                                                         NAN
# 686                                                         NAN
# 687                                                         NAN
# 688                                                         NAN
# 689                                                         NAN
# 690                                                         NAN
# 691                                                         NAN
# 692           -PROPERLY EXTEND THE VENTS A MINIMUM OF 6” ABO...
# 693                                                         NAN
# 694                                                         NAN
# 695                                                         NAN
# 696                                                         NAN
# 697                                                         NAN
# 698                                                         NAN
# 699                                                         NAN
# 700                                                         NAN
# 701                                                         NAN
# 702                                                         NAN
# 703                                                         NAN
# 704                                                         NAN
# 705                                                         NAN
# 706                                                         NAN
# 707                                                         NAN
# 708                                                         NAN
# 709                                                         NAN
# 710                                                         NAN
# 711           16.24.410.D - A MINIMUM OF ONE WATER CLOSET, O...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 146                    PLUMBING
# 147                    PLUMBING
# 148                    PLUMBING
# 149                    PLUMBING
# 150                    PLUMBING
# 151                    PLUMBING
# 152                    PLUMBING
# 164                    PLUMBING
# 165                    PLUMBING
# 193                    PLUMBING
# 194                    PLUMBING
# 195                    PLUMBING
# 206                    PLUMBING
# 207                    PLUMBING
# 208                    PLUMBING
# 209                    PLUMBING
# 530                    PLUMBING
# 531                    PLUMBING
# 532                    PLUMBING
# 533                    PLUMBING
# 534                    PLUMBING
# 535                    PLUMBING
# 536                    PLUMBING
# 537                    PLUMBING
# 538                    PLUMBING
# 539                    PLUMBING
# 540                    PLUMBING
# 541                    PLUMBING
# 542                    PLUMBING
# 543                    PLUMBING
# ...                         ...
# 682                    PLUMBING
# 683                    PLUMBING
# 684                    PLUMBING
# 685                    PLUMBING
# 686                    PLUMBING
# 687                    PLUMBING
# 688                    PLUMBING
# 689                    PLUMBING
# 690                    PLUMBING
# 691                    PLUMBING
# 692                    PLUMBING
# 693                    PLUMBING
# 694                    PLUMBING
# 695                    PLUMBING
# 696                    PLUMBING
# 697                    PLUMBING
# 698                    PLUMBING
# 699                    PLUMBING
# 700                    PLUMBING
# 701                    PLUMBING
# 702                    PLUMBING
# 703                    PLUMBING
# 704                    PLUMBING
# 705                    PLUMBING
# 706                    PLUMBING
# 707                    PLUMBING
# 708                    PLUMBING
# 709                    PLUMBING
# 710                    PLUMBING
# 711                    PLUMBING
#
# [81 rows x 4 columns]

# %% [markdown]
# ##### * electrical violations are those whose VIOLATION_TYPE starts with 'CAE' or whose VIOLATION_TEXT starts with 'SECTION 16.24.490', 'SECTION 16.24.500'

# %%
codes_df.loc[codes_df['VIOLATION_TYPE'].str.contains('CAE.*') | 
            codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.(490|500)') |
            codes_df['VIOLATION_DESC'].str.contains('LIGHTING')
             , 'VIOLATION_CATEGORY'] = 'ELECTRICAL'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'ELECTRICAL']
# Out:
# /Users/paulomartinez/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.
#                     VIOLATION_TYPE                           VIOLATION_DESC  \
# VIOLATION_ID
# 18                         ECSYSHZ                ELECTRICAL SYSTEM HAZARDS
# 19                      ECSYSHZCRT          ELECTRICAL SYSTEM CERTIFICATION
# 20                       ELECEAREC                   ELECTRICAL RECEPTACLES
# 21                          ELECEQ                    ELECTRICAL EQUIPMENT
# 22                      ELECEQLIGH             ELECTRICAL LIGHTING FIXTURES
# 23                         ELECFAC           ELECTRICAL FACILITIES REQUIRED
# 24                      ELECSVCPAN                 ELECTRICAL SERVICE PANEL
# 109                     LIGHTEMISS                      LIGHTING (EMISSION)
# 111                       LIGHTMAX                     LIGHTING (MAX LEVEL)
# 410                   CAAE_ELEC_EQ                     ELECTRICAL EQUIPMENT
# 411              CAAE_ELECEA_RECPT                   ELECTRICAL RECEPTACLES
# 412              CAAE_ELECEQ_LIGHT             ELECTRICAL LIGHTING FIXTURES
# 413                   CAAE_ELECFAC           ELECTRICAL FACILITIES REQUIRED
# 414             CAAE_ELECSVC_PANEL                 ELECTRICAL SERVICE PANEL
# 415               CAAE_ELECSYS_HAZ                ELECTRICAL SYSTEM HAZARDS
# 416           CAAE_ELECSYS_HAZCERT          ELECTRICAL SYSTEM CERTIFICATION
# 562            CAAZ_LIGHT_EMISSION                      LIGHTING (EMISSION)
# 563                 CAAZ_LIGHT_MAX                     LIGHTING (MAX LEVEL)
# 606                          CAE01                                   REWIRE
# 607                          CAE02                 ELECTRICAL SERVICE PANEL
# 608                          CAE03              RELOCATE ELECTRICAL SERVICE
# 609                          CAE04                  CONDUIT AND WEATHERHEAD
# 610                          CAE05             BATHROOM/KITCHEN GFCI OUTLET
# 611                          CAE06  ELECTRICAL SYSTEM CHECKED AND CERTIFIED
# 612                          CAE07           REPAIR DEFECTIVE SERVICE PANEL
# 613                          CAE08         REPLACE, REPAIR DEFECTIVE EQUIP.
# 614                          CAE09        REPLACE MISSING WALL OUTLET COVER
# 615                          CAE10       REPLACE MISSING WALL SWITCH COVERS
# 616                          CAE11  REPLACE SUBSTANDARD WIRING (DROP-CORDS)
# 617                          CAE12      PROVIDE CONDUITS FOR EXPOSED WIRING
# 618                          CAE13                   REMOVE EXTENSION CORDS
# 619                          CAE14     REPLACE CEILING LIGHT FIXTURE COVERS
# 620                          CAE15                     PROVIDE JUNCTION BOX
# 621                          CAE16                     EXTERIOR PORCH LIGHT
# 622                          CAE17              REPLACE MISSING FUSE BLANKS
# 623                          CAE18       REMOVE, REPLACE SUDSTANDARD WIRING
# 624                          CAE19                     BATHROOM GFCI OUTLET
# 625                          CAE20       DEFECTIVE WALL OUTLETS ON EXTERIOR
# 626                          CAE21         CORRECT OTHER ELECTRICAL DEFECTS
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 18            SECTION 16.24.490 (C) - ELECTRICAL SYSTEM HAZA...
# 19            SECTION 16.24.490 (C) - ELECTRICAL SYSTEM HAZA...
# 20            SECTION 16.24.500 (B) RECEPTACLES: EVERY HABIT...
# 21            SECTION 16.24.500 (A) - ELECTRICAL EQUIPMENT I...
# 22            SECTION 16.24.500 (C) - LIGHTING FIXTURES: EVE...
# 23            SECTION 16.24.490(A) - ELECTRICAL FACILITIES R...
# 24            SECTION 16.24.490 (B) - ELECTRICAL SERVICE: SE...
# 109           SECTION 17.28.100 (A) - LIGHTING (EMISSION): A...
# 111           SECTION 17.28.100 (A) - LIGHTING (MAX LEVEL): ...
# 410           SECTION 16.24.500 (A) - ELECTRICAL EQUIPMENT I...
# 411           SECTION 16.24.500 (B) RECEPTACLES: EVERY HABIT...
# 412           SECTION 16.24.500 (C) - LIGHTING FIXTURES: EVE...
# 413           SECTION 16.24.490(A) - ELECTRICAL FACILITIES R...
# 414           SECTION 16.24.490 (B) - ELECTRICAL SERVICE: SE...
# 415           SECTION 16.24.490 (C) - ELECTRICAL SYSTEM HAZA...
# 416           SECTION 16.24.490 (C) - ELECTRICAL SYSTEM HAZA...
# 562           SECTION 17.28.100 (A) - LIGHTING (EMISSION): A...
# 563           SECTION 17.28.100 (A) - LIGHTING (MAX LEVEL): ...
# 606                                                         NAN
# 607                                                         NAN
# 608                                                         NAN
# 609                                                         NAN
# 610                                                         NAN
# 611                                                         NAN
# 612                                                         NAN
# 613                                                         NAN
# 614                                                         NAN
# 615                                                         NAN
# 616                   -REPLACE SUBSTANDARD WIRING (DROP-CORDS).
# 617                                                         NAN
# 618                                                         NAN
# 619                                                         NAN
# 620                                                         NAN
# 621                                                         NAN
# 622                                                         NAN
# 623                                                         NAN
# 624                                                         NAN
# 625                                                         NAN
# 626                                                         NAN
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 18                   ELECTRICAL
# 19                   ELECTRICAL
# 20                   ELECTRICAL
# 21                   ELECTRICAL
# 22                   ELECTRICAL
# 23                   ELECTRICAL
# 24                   ELECTRICAL
# 109                  ELECTRICAL
# 111                  ELECTRICAL
# 410                  ELECTRICAL
# 411                  ELECTRICAL
# 412                  ELECTRICAL
# 413                  ELECTRICAL
# 414                  ELECTRICAL
# 415                  ELECTRICAL
# 416                  ELECTRICAL
# 562                  ELECTRICAL
# 563                  ELECTRICAL
# 606                  ELECTRICAL
# 607                  ELECTRICAL
# 608                  ELECTRICAL
# 609                  ELECTRICAL
# 610                  ELECTRICAL
# 611                  ELECTRICAL
# 612                  ELECTRICAL
# 613                  ELECTRICAL
# 614                  ELECTRICAL
# 615                  ELECTRICAL
# 616                  ELECTRICAL
# 617                  ELECTRICAL
# 618                  ELECTRICAL
# 619                  ELECTRICAL
# 620                  ELECTRICAL
# 621                  ELECTRICAL
# 622                  ELECTRICAL
# 623                  ELECTRICAL
# 624                  ELECTRICAL
# 625                  ELECTRICAL
# 626                  ELECTRICAL

# %% [markdown]
# ##### * waste violations are those whose VIOLATION_TYPE starts with 'CAG[A-Z]_' or 'CAAA_RODENT_INFESTA', or whose VIOLATION_DESC starts with 'RUBBISH', 'WASTE', 'GARBAGE', 'JUNK', 'LITTER', 'SANITATION', etc.

# %%
codes_df.loc[codes_df['VIOLATION_TYPE'].str.contains('CAG[A-Z]_') | 
             codes_df['VIOLATION_TYPE'].str.contains('CAAA_RODENT_INFESTA') |
             codes_df['VIOLATION_TYPE'].str.contains('SEW') |
             codes_df['VIOLATION_DESC'].str.contains('RUBBISH') |
             codes_df['VIOLATION_DESC'].str.contains('WASTE') |
             codes_df['VIOLATION_DESC'].str.contains('GARBAGE') |
             codes_df['VIOLATION_DESC'].str.contains('JUNK') |    
             codes_df['VIOLATION_DESC'].str.contains('SANITATION') |
             codes_df['VIOLATION_DESC'].str.contains('LITTER') |
             codes_df['VIOLATION_DESC'].str.contains('DUMP') |
             codes_df['VIOLATION_DESC'].str.contains('OPEN STORAGE') |
             codes_df['VIOLATION_DESC'].str.contains('SEWAGE') | 
             codes_df['VIOLATION_DESC'].str.contains('STAGNANT') |
             codes_df['VIOLATION_DESC'].str.contains('DEBRIS') |
             codes_df['VIOLATION_DESC'].str.contains('TRASH')
             , 'VIOLATION_CATEGORY'] = 'WASTE'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'WASTE']
# Out:
#                 VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 16                   DUMPDESIG               DUMPING IN PERMITTED PLACES
# 17                    DUMPSTER   HOURS OF COLLECTION & DUMPSTER REQUIRED
# 64                      EXTSAN           EXTERIOR PROP AREA – SANITATION
# 92                   HAZWASGEN  HAZARDOUS, PATHOGENIC, RADIOACTIVE WASTE
# 93                  HAZWSTPATH  HAZARDOUS, PATHOGENIC, RADIOACTIVE WASTE
# 100                    HSANSTD                   SANITATION REQUIREMENTS
# 113                  LITBUSCIT        LITTER ON PUBLIC PLACES - CITIZENS
# 114                  LITBUSREP        LITTER ON BUSINESS PREMISES -OWNER
# 119                 LITPRVPROO       LITTER ON PRIVATE PROPERTY - OWNERS
# 120                 LITPRVPROP       LITTER ON OCCUPIED PRIVATE PROPERTY
# 121                  LITVACLOT                     LITTER ON VACANT LOTS
# 122                     LITVEH                      LITTER FROM VEHICLES
# 123                 LITVEHLOAD           LITTER FROM VEHICLE LOADS TIRES
# 124                   LITWATER                           LITTER IN WATER
# 129                   NUISGARB                  GARBAGE CAUSING NUISANCE
# 140                    OPNSTOR   EXTERIOR PROP AREA – OPEN STORAGE - ALL
# 141                     OPSTDB   EXTERIOR PROP AREA – OPEN STOR – DEBRIS
# 142                    OPSTJTD   EXTERIOR PROP AREA – OPEN STORAGE – JTD
# 143                    OPSTVEH   EXTERIOR PROP AREA – OPEN STORAGE - VEH
# 157                  RODACCGAR                   ACCUMULATION OF GARBAGE
# 158                  RODSTOGAR           STORAGE AND DISPOSAL OF GARBAGE
# 159                  RUBDISGAR   RUBBISH AND GARBAGE – DISPOSAL  GARBAGE
# 160                  RUBGARCON          RUBBISH AND GARBAGE – CONTAINERS
# 161                    RUBGARD    RUBBISH AND GARBAGE – DISPOSAL RUBBISH
# 162                  RUBGARFAC  RUBBISH AND GARBAGE – GARBAGE FACILITIES
# 163                 RUBGARSTOR     RUBBISH AND GARBAGE – RUBBISH STORAGE
# 167                   SEWCONCT                   CONNECT TO PUBLIC SEWER
# 168                  SEWCONPER             PRIVATE CONNECTIONS PERMITTED
# 169                 SEWRNOFWTR                   RUNOFF IN BODY OF WATER
# 170                  SEWRUNOFF               RUNOFF OF CONTENTS UNLAWFUL
# ...                        ...                                       ...
# 633                   CAGG_LVH                      LITTER FROM VEHICLES
# 634                   CAGH_HWG                         EXCESS VEGETATION
# 635                  CAGI_GCAN               GARBAGE APPROVED CONTAINERS
# 636               CAGJ_GT_RATS                     RAT HARBORAGE GARBAGE
# 637                   CAGK_JTD                  JUNK TRASH RAT HARBORAGE
# 638                  CAGL_STAG                            STAGNANT WATER
# 639                   CAGM_GTD                      DIRT, FILTH, GARBAGE
# 650              CAGO_CHICKENS                          KEEPING CHICKENS
# 651                  CAGP_RWR2                  RUNNING WATER REQUIRED 2
# 652                  CAGQ_SDIS                   SEWAGE DISCHARGE STREAM
# 653                  CAGR_SPUB                  SEWER, CONNECT TO PUBLIC
# 654                   CAGT_SOG                          SEWAGE ON GROUND
# 655                   CAGU_SBK            SEWAGE DISP. IMPROPERLY MAINT.
# 656                  CAGV_SIWL               SEWAGE - ILLEGAL WASTE LINE
# 657                  CAGX_LEAK                           FAULTY PLUMBING
# 658                   CAGZ_OTH                          OTHER VIOLATIONS
# 659           CAHC_ILLEG_DUMCN               ILLEGAL DUMPING - CONTAINER
# 660           CAHC_ILLEGAL_DUM                ILLEGAL DUMPING - PROPERTY
# 748                     CAST44              REGULATION GARBAGE CONTAINER
# 752                     CAST49                               REMOVE JUNK
# 756                  HD1032120       APPROVED GARBAGE & TRASH CONTAINERS
# 757                  HD1032130           ACCUMUALTION OF GARBAGE & TRASH
# 759                  HD1032160                 STAGNANT WATER COLLECTION
# 760                 HD10360201            DIRT, FILTH, RUBBISH & GARBAGE
# 764                  HD1572020                          SEWAGE ON GROUND
# 765                   HD157240     IMPROPER MAINT SEWAGE DISPOSAL SYSTEM
# 767               HDPM_GT_RATS                     RAT HARBORAGE GARBAGE
# 768                   HDPM_JTD                  JUNK TRASH RAT HARBORAGE
# 769                  HDPM_STAG                            STAGNANT WATER
# 776            CAAZ_STRP_NOISE                   EXCESSIVE NOISE / WASTE
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 16            SECTION 10.20.130 - DUMPING PERMITTED IN DESIG...
# 17            SECTION 10.20.330 – DUMPSTERS – HOURS OF COLLE...
# 64            SECTION 16.24.330 (A) – SANITATION: ALL EXTERI...
# 92            SECTION 10.20.240 - HAZARDOUS, PATHOGENIC AND ...
# 93            SECTION 10.20.240 - HAZARDOUS, PATHOGENIC AND ...
# 100           SECTION 10.36.020 - SANITATION REQUIREMENTS: E...
# 113           SECTION 10.24.060 - LITTER ON PUBLIC PLACES - ...
# 114           SECTION 10.24.050 - LITTER ON BUSINESS PREMISE...
# 119           SECTION 10.24.070 - LITTER ON PRIVATE PROPERTY...
# 120           SECTION 10.24.080 - LITTER ON OCCUPIED PRIVATE...
# 121           SECTION 10.24.140 - LITTER ON VACANT LOTS: NO ...
# 122           SECTION 10.24.150 - LITTER FROM VEHICLES - LIA...
# 123           SECTION 10.24.160 - LITTER FROM VEHICLE LOADS ...
# 124           SECTION 10.24.130 - LITTER IN BODIES OF WATER:...
# 129           SECTION 10.20.120 - NUSIANCE DECLARED: IT IS U...
# 140           SECTION 16.24.330 (B) – OPEN STORAGE: IT IS UN...
# 141           SECTION 16.24.330 (B) – OPEN STORAGE (DEBRIS):...
# 142           SECTION 16.24.330 (B) – OPEN STORAGE (JUNK, TR...
# 143           SECTION 16.24.330 (B) – OPEN STORAGE (VEHICLES...
# 157           SECTION 10.32.130 - ACCUMULATION OF GARBAGE: I...
# 158           SECTION 10.32.120 - STORAGE AND DISPOSAL OF GA...
# 159           SECTION 16.24.360 (C) - DISPOSAL OF GARBAGE. E...
# 160           SECTION 16.24.360 (E) - CONTAINERS. THE OPERAT...
# 161           SECTION 16.24.360 (A) - DISPOSAL OF RUBBISH. E...
# 162           SECTION 16.24.360 (D) - GARBAGE FACILITIES. TH...
# 163           SECTION 16.24.360 (B) - RUBBISH STORAGE FACILI...
# 167           SECTION 15.40.040 - CONNECTION REQUIRED: ANY P...
# 168           SECTION 15.72.020(B) - PRIVATE CONNECTIONS PER...
# 169           SECTION 15.72.070 - DISCHARGE OF WASTE INTO A ...
# 170           SECTION 15.72.060 - RUNOFF OF CONTENTS UNLAWFU...
# ...                                                         ...
# 633           MCL CHAPTER 10.24.150 - LITTER FROM VEHICLES--...
# 634           MCL CHAPTER 10.26.010 – EVERY PREMISE INCLUDIN...
# 635           MCL CHAPTER 10.32.120 - ALL GARBAGE AND TRASH ...
# 636           MCL CHAPTER 10.32.130 – PERMITTING GARBAGE AND...
# 637           MCL CHAPTER 10.32.140 - PERMITTING LUMBER, JUN...
# 638           MCL CHAPTER 10.32.160 – THE CHIEF MEDICAL DIRE...
# 639           MCL CHAPTER 10.36.020 A -  EVERY DWELLING AND ...
# 650           MCL CHAPTER 8.12.020  KEEPING OF CHICKENS.NO P...
# 651           MCL CHAPTER 16.24.440 – NO WATER – THE WATER S...
# 652           MCL CHAPTER 15.72.070   - DISCHARGE OF WASTE I...
# 653           MCL CHAPTER 15.40.040 – CONNECT TO PUBLIC SANI...
# 654           MCL CHAPTER 15.72.020 - SECTION B - SEWAGE RUN...
# 655           MCL CHAPTER 15.72.040 - SEWAGE RUNNING ON GROU...
# 656           MCL CHAPTER 15.72.060 - ILLEGAL WASTE LINE(S) ...
# 657           MCL CHAPTER 16.12.030 – FAULTY PLUMBING – ALL ...
# 658                                                      OTHER:
# 659           SECTION 10.20.130 (B) - IT IS UNLAWFUL FOR ANY...
# 660           SECTION 10.20.130 (A) – DUMPING PERMITTED IN D...
# 748           -PROVIDE METAL REGULATION GARBAGE CONTAINER WI...
# 752           -REMOVE (USED LUMBER, DEBRIS, REFRIGERATOR, AB...
# 756                                                         NAN
# 757                                                         NAN
# 759                                                         NAN
# 760                                                         NAN
# 764                                                         NAN
# 765                                                         NAN
# 767           MCL CHAPTER 10.32.130 – PERMITTING GARBAGE AND...
# 768           MCL CHAPTER 10.32.140 - PERMITTING LUMBER, JUN...
# 769           MCL CHAPTER 10.32.160 – THE CHIEF MEDICAL DIRE...
# 776           SECTION 6.28.030 (F) NOISE: ALL STRP OCCUPANTS...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 16                        WASTE
# 17                        WASTE
# 64                        WASTE
# 92                        WASTE
# 93                        WASTE
# 100                       WASTE
# 113                       WASTE
# 114                       WASTE
# 119                       WASTE
# 120                       WASTE
# 121                       WASTE
# 122                       WASTE
# 123                       WASTE
# 124                       WASTE
# 129                       WASTE
# 140                       WASTE
# 141                       WASTE
# 142                       WASTE
# 143                       WASTE
# 157                       WASTE
# 158                       WASTE
# 159                       WASTE
# 160                       WASTE
# 161                       WASTE
# 162                       WASTE
# 163                       WASTE
# 167                       WASTE
# 168                       WASTE
# 169                       WASTE
# 170                       WASTE
# ...                         ...
# 633                       WASTE
# 634                       WASTE
# 635                       WASTE
# 636                       WASTE
# 637                       WASTE
# 638                       WASTE
# 639                       WASTE
# 650                       WASTE
# 651                       WASTE
# 652                       WASTE
# 653                       WASTE
# 654                       WASTE
# 655                       WASTE
# 656                       WASTE
# 657                       WASTE
# 658                       WASTE
# 659                       WASTE
# 660                       WASTE
# 748                       WASTE
# 752                       WASTE
# 756                       WASTE
# 757                       WASTE
# 759                       WASTE
# 760                       WASTE
# 764                       WASTE
# 765                       WASTE
# 767                       WASTE
# 768                       WASTE
# 769                       WASTE
# 776                       WASTE
#
# [83 rows x 4 columns]

# %% [markdown]
# ##### * sign violations are those whose VIOLATION_TYPE contains 'SIGN' or 'BANNER' but does not contain 'CONSIGN'

# %%
codes_df.loc[(codes_df['VIOLATION_TYPE'].str.contains('SIGN') |
              codes_df['VIOLATION_DESC'].str.contains('PROHIBITED SIGN') |
              codes_df['VIOLATION_TYPE'].str.contains('BANNER')) &
             ~codes_df['VIOLATION_TYPE'].str.contains('CON')
             , 'VIOLATION_CATEGORY'] = 'SIGNAGE'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'SIGNAGE']
# Out:
#                     VIOLATION_TYPE                         VIOLATION_DESC  \
# VIOLATION_ID
# 1                          BANNERS                                BANNERS
# 172                     SGNPRHBPOR        PROHIBITED SIGN - PORTABLE SIGN
# 173                      SGNPROBLK               PROHIBITED SIGNS - BLANK
# 175                       SIGNABAN                        ABANDONED SIGNS
# 176                      SIGNDILAP                      DILAPIDATED SIGNS
# 177                       SIGNHARM              PROHIBITED SIGN - HARMFUL
# 178                       SIGNIPLS      SIGNS – PROHIBITED PLACEMENT –BUS
# 179                       SIGNIPPP  SIGNS – PROHIBITED PLACEMENT – PUBLIC
# 180                      SIGNMAINT                      SIGN MAINTENANCE
# 181                        SIGNMAT                          SIGN MATERIAL
# 182                     SIGNMOTION   ELECTRONIC SIGN (LED) DISPLAY MOTION
# 183                     SIGNPERMIT                   SIGN PERMIT REQUIRED
# 184                      SIGNPROHB                       PROHIBITED SIGNS
# 185                      SIGNPROHH          SIGNS – PROHIBITED – HANDHELD
# 186                     SIGNTIMING   ELECTRONIC SIGN (LED) DISPLAY TIMING
# 187                     SIGNUNSILL                 UNSAFE OR ILLEGAL SIGN
# 188                       SIGNVEHP     SIGNS – PROHIBITED (VEHICLE SIGNS)
# 189                        SIGNWND              SIGNS – PROHIBITED - WIND
# 547                   CAAZ_BANNERS                                BANNERS
# 576              CAAZ_SGN_PROHBBLK               PROHIBITED SIGNS - BLANK
# 577             CAAZ_SGN_PROHBPORT        PROHIBITED SIGN - PORTABLE SIGN
# 578            CAAZ_SIGN_25PERCENT        SIGNS – GREATER THAN 25 PERCENT
# 579                 CAAZ_SIGN_ABAN                        ABANDONED SIGNS
# 580                CAAZ_SIGN_DILAP                      DILAPIDATED SIGNS
# 581               CAAZ_SIGN_HNDHLD          SIGNS – PROHIBITED – HANDHELD
# 582                 CAAZ_SIGN_IPLS      SIGNS – PROHIBITED PLACEMENT –BUS
# 583                 CAAZ_SIGN_IPPP  SIGNS – PROHIBITED PLACEMENT – PUBLIC
# 584                CAAZ_SIGN_MAINT                       SIGN MAINTENANCE
# 585                  CAAZ_SIGN_MAT                          SIGN MATERIAL
# 586               CAAZ_SIGN_MOTION   ELECTRONIC SIGN (LED) DISPLAY MOTION
# 587               CAAZ_SIGN_PERMIT                   SIGN PERMIT REQUIRED
# 588           CAAZ_SIGN_PERMIT_REQ                   SIGN PERMIT REQUIRED
# 589                CAAZ_SIGN_POLEN          PROHIBITED ON POSTS AND POLES
# 590                CAAZ_SIGN_PROHB                       PROHIBITED SIGNS
# 591                  CAAZ_SIGN_ROW                           SIGNS IN ROW
# 592                 CAAZ_SIGN_TEMP            ON-PREMISES TEMPORARY SIGNS
# 593               CAAZ_SIGN_TIMING   ELECTRONIC SIGN (LED) DISPLAY TIMING
# 594              CAAZ_SIGN_UNSAILL                 UNSAFE OR ILLEGAL SIGN
# 595                 CAAZ_SIGN_VEHP     SIGNS – PROHIBITED (VEHICLE SIGNS)
# 596                 CAAZ_SIGN_WIND             SIGNS  – PROHIBITED - WIND
# 597               CAAZ_SIGN_WINDOW               WINDOW SIGNS AND DISPLAY
# 755             CAZZ_SGN_PROHBHARM              PROHIBITED SIGN - HARMFUL
# 775                CAAZ_STRP_SIGNS                     SIGNAGE PROHIBITED
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 1             SECTION 17.32.060 & 17.32.070 -  BANNERS: BANN...
# 172           SECTION 17.32.050 (S) - PORTABLE SIGNS: PORTAB...
# 173           SECTION 17.32.050 (M) - PROHIBITED SIGNS (BLAN...
# 175           SECTION 17.40-510 (D) - ABANDONED SIGNS - [SIG...
# 176           SECTION 17.40.510 (C) - DILAPIDATED SIGNS - AL...
# 177           SECTION 17.32.050 (R ) - PROHIBITED SIGNS (HAR...
# 178           SECTION 17.32.050 (E) - PROHIBITED SIGNS: SIGN...
# 179           SECTION 17.32.050 (F) - PROHIBITED SIGNS: SIGN...
# 180           SECTION 17.32.020 (B) (3) - MAINTENANCE: ALL S...
# 181           SECTION 17.32.020 (B) (2) - PERMANENCY REQUIRE...
# 182           SECTION 17.32.050 (G) (3) - PROHIBITED SIGNS: ...
# 183           SECTION 17.40.520 – ILLEGAL SIGNS – PERMIT REQ...
# 184           SECTION 17.32.050 - PROHIBITED SIGNS: IT IS UN...
# 185           SECTION 17.32.040 (G) - HAND CARRIED SIGNS: SI...
# 186           SECTION 17.32.050(G) (1) - PROHIBITED SIGNS: S...
# 187           SECTION 17.40.510 (B) (1) - ILLEGAL SIGNS - SI...
# 188           SECTION 17.32.050 (Q) - PROHIBITED SIGNS: SIGN...
# 189           SECTION 17.32.050 (O) - PROHIBITED SIGNS: SIGN...
# 547           SECTION 17.32.060 & 17.32.070 - BANNERS: BANNE...
# 576           SECTION 17.32.050 (M) - PROHIBITED SIGNS (BLAN...
# 577           SECTION 17.32.050 (S) - PORTABLE SIGNS: PORTAB...
# 578           SECTION 17.32.040 (M) – TEMPORARY SIGNS AND DI...
# 579           SECTION 17.40-510 (D) - ABANDONED SIGNS - [SIG...
# 580           SECTION 17.40.510 (C) - DILAPIDATED SIGNS - AL...
# 581           SECTION 17.32.040 (G) - HAND CARRIED SIGNS: SI...
# 582           SECTION 17.32.050 (E) - PROHIBITED SIGNS: SIGN...
# 583           SECTION 17.32.050 (F) - PROHIBITED SIGNS: SIGN...
# 584           SECTION 17.32.020 (B) (3) - MAINTENANCE: ALL S...
# 585           SECTION 17.32.020 (B) (2) - PERMANENCY REQUIRE...
# 586           SECTION 17.32.050 (G) (3) - PROHIBITED SIGNS: ...
# 587           SECTION 17.40.510 - SIGN PERMIT REQUIRED: SIGN...
# 588           SECTION 17.40.520 – ILLEGAL SIGNS – PERMIT REQ...
# 589           SECTION 6.04.010 - PROHIBITED ON POSTS AND POL...
# 590           SECTION 17.32.050 - PROHIBITED SIGNS: IT IS UN...
# 591           SECTION 17.32.050 - PROHIBITED LOCATION:  SIGN...
# 592           SECTION 17.32.060 -  ON-PREMISES TEMPORARY SIG...
# 593           SECTION 17.32.050(G) (1) - PROHIBITED SIGNS: S...
# 594           SECTION 17.40.510 (B) (1) - ILLEGAL SIGNS - SI...
# 595           SECTION 17.32.050 (Q) - PROHIBITED SIGNS: SIGN...
# 596           SECTION 17.32.050 (O) - PROHIBITED SIGNS: SIGN...
# 597           SECTION 17.32.040 - WINDOW SIGNS/DISPLAYS:  TE...
# 755           SECTION 17.32.050 (R ) - PROHIBITED SIGNS (HAR...
# 775           SECTION 6.28.030 (E) SIGNAGE: SIGNS, ADVERTISI...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 1                       SIGNAGE
# 172                     SIGNAGE
# 173                     SIGNAGE
# 175                     SIGNAGE
# 176                     SIGNAGE
# 177                     SIGNAGE
# 178                     SIGNAGE
# 179                     SIGNAGE
# 180                     SIGNAGE
# 181                     SIGNAGE
# 182                     SIGNAGE
# 183                     SIGNAGE
# 184                     SIGNAGE
# 185                     SIGNAGE
# 186                     SIGNAGE
# 187                     SIGNAGE
# 188                     SIGNAGE
# 189                     SIGNAGE
# 547                     SIGNAGE
# 576                     SIGNAGE
# 577                     SIGNAGE
# 578                     SIGNAGE
# 579                     SIGNAGE
# 580                     SIGNAGE
# 581                     SIGNAGE
# 582                     SIGNAGE
# 583                     SIGNAGE
# 584                     SIGNAGE
# 585                     SIGNAGE
# 586                     SIGNAGE
# 587                     SIGNAGE
# 588                     SIGNAGE
# 589                     SIGNAGE
# 590                     SIGNAGE
# 591                     SIGNAGE
# 592                     SIGNAGE
# 593                     SIGNAGE
# 594                     SIGNAGE
# 595                     SIGNAGE
# 596                     SIGNAGE
# 597                     SIGNAGE
# 755                     SIGNAGE
# 775                     SIGNAGE

# %% [markdown]
# ##### * building exterior violations are those whose VIOLATION_DESC contains 'EXTERIOR' and either 'BLDG' or 'BUILDING', or whose VIOLATION_TYPE contains 'CAST[01-24]'

# %%
codes_df.loc[codes_df['VIOLATION_TYPE'].str.contains('CAST([01][0-9]|[2][0-4])') |
              (codes_df['VIOLATION_DESC'].str.contains('EXTERIOR') &
               codes_df['VIOLATION_DESC'].str.contains('(BLDG|BUILDING)'))
             , 'VIOLATION_CATEGORY'] = 'EXTBLD'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'EXTBLD']
# Out:
# /Users/paulomartinez/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.
#                 VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 27                    EXTBAHAT    EXTERIOR OF BLDGS – BASEMENT HATCHWAYS
# 28                      EXTBAL         EXTERIOR OF BUILDINGS - BALCONIES
# 29                   EXTCHIMTW   EXTERIOR OF BLDGS – CHIMNEYS AND TOWERS
# 30                      EXTDEC             EXTERIOR OF BUILDINGS – DECKS
# 31                     EXTDECF   EXTERIOR OF BLDGS – DECORATIVE FEATURES
# 33                     EXTDOOR             EXTERIOR OF BUILDINGS – DOORS
# 34                  EXTEPIDRES   EXTERIOR OF BUILDINGS – PREMISES ID RES
# 41                  EXTEXTWALL    EXTERIOR OF BUILDINGS – EXTERIOR WALLS
# 42                   EXTFDWALL  EXTERIOR OF BUILDINGS – FOUNDATION WALLS
# 46                   EXTGBAWIN  EXTERIOR OF BLDGS – GUARDS BASEMENT WIND
# 47                     EXTGLAZ           EXTERIOR OF BUILDINGS – GLAZING
# 49                  EXTGUTTTER     EXTERIOR OF BLDGS – ROOFS– GUTTER SYS
# 50                  EXTHANDGRD  EXTERIOR OF BLDGS – HANDRAILS AND GUARDS
# 51                   EXTOPNWIN  EXTERIOR OF BUILDINGS – OPENABLE WINDOWS
# 52                    EXTOVEXT   EXTERIOR OF BLDGS – OVERHANG EXTENSIONS
# 53                  EXTPIDNRES    EXTERIOR OF BLDGS – PREMISES ID NONRES
# 54                   EXTPIMFAM  EXTERIOR OF BLDG – PREMISES ID MULTI-FAM
# 55                      EXTPOR           EXTERIOR OF BUILDINGS - PORCHES
# 57                    EXTPTMET   EXTERIOR OF BLDGS – TREATMENT METAL SUR
# 58                    EXTPTSID    EXTERIOR OF BLDGS – TREATMENT (SIDING)
# 59                     EXTPTWD  EXTERIOR OF BLDGS – PRO TREATMENT (WOOD)
# 62                  EXTROFDRAN   EXTERIOR OF BLDGS – ROOFS– DRAINAGE SYS
# 63                   EXTROFSYS   EXTERIOR OF BLDGS – ROOFS – ROOF SYSTEM
# 65                  EXTSCRENNR  EXTERIOR OF BLDGS  INSECT SCREENS NONRES
# 66                  EXTSCRNRES    EXTERIOR OF BLDGS – INSECT SCREENS RES
# 68                      EXTSTA         EXTERIOR OF BUILDINGS – STAIRWAYS
# 69                    EXTSTMEM    EXTERIOR OF BLDGS – STRUCTURAL MEMBERS
# 91                    GRAFFITI          EXTERIOR OF BUILDINGS – GRAFFITI
# 434             CAAH_EXT_BAHAT    EXTERIOR OF BLDGS – BASEMENT HATCHWAYS
# 435             CAAH_EXT_BALCO         EXTERIOR OF BUILDINGS - BALCONIES
# ...                        ...                                       ...
# 460             CAAH_EXT_PTMET   EXTERIOR OF BLDGS – TREATMENT METAL SUR
# 461             CAAH_EXT_PTSID    EXTERIOR OF BLDGS – TREATMENT (SIDING)
# 462              CAAH_EXT_PTWD  EXTERIOR OF BLDGS – PRO TREATMENT (WOOD)
# 464           CAAH_EXT_ROFDRAN   EXTERIOR OF BLDGS – ROOFS– DRAINAGE SYS
# 465            CAAH_EXT_ROFSYS   EXTERIOR OF BLDGS – ROOFS – ROOF SYSTEM
# 468            CAAH_EXT_STAIRW         EXTERIOR OF BUILDINGS – STAIRWAYS
# 469             CAAH_EXT_STMEM    EXTERIOR OF BLDGS – STRUCTURAL MEMBERS
# 483                CAAH_GBAWIN  EXTERIOR OF BLDGS – GUARDS BASEMENT WIND
# 484              CAAH_GRAFFITI          EXTERIOR OF BUILDINGS – GRAFFITI
# 712                     CAST01                              ROOF LEAKING
# 713                     CAST02   RAISE SAGGING ROOF TO ORIGINAL POSITION
# 714                     CAST03              REPLACE ENTIRE ROOF COVERING
# 715                     CAST04              MISSING AND DEFECTIVE SIDING
# 716                     CAST05       EXTERIOR (BRICK VENEER-STONE) WALLS
# 717                     CAST06     DAMAGED (FRONT OR REAR) PORCH CEILING
# 718                     CAST07                   OVERHAUL PORCH OR STEPS
# 719                     CAST08                  CONCRETE PORCH AND STEPS
# 720                     CAST10    CORNICES, EAVES, STAIRS, PORCH COLUMNS
# 721                     CAST14    ROTTED OR DEFECTIVE SHEATHING, RAFTERS
# 722                     CAST15  MORTAR JOINTS OF CHIMNEYS, MISSING BRICK
# 723                     CAST16                   UNSAFE PARTS OF CHIMNEY
# 724                     CAST17                       BROKEN WINDOW GLASS
# 725                     CAST18                          OVERHAUL WINDOWS
# 726                     CAST19         SCREENS FOR ALL WINDOWS AND DOORS
# 727                     CAST20                           DAMAGED SCREENS
# 728                     CAST21                        MISSING DOWNSPOUTS
# 729                     CAST22   RUSTED AND DEFECTIVE GUTTERS DOWNSPOUTS
# 730                     CAST23    UNDERPINNING, HATCHWAY, EXTERIOR DOORS
# 731                     CAST24                            PAINT EXTERIOR
# 732                    CAST24B                            EXTERIOR PAINT
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 27            SECTION 16.24.340 (R) – BASEMENT HATCHWAYS: BA...
# 28            SECTION 16.24.340 (J) – BALCONIES: EVERY EXTER...
# 29            SECTION 16.24.340 (K) – CHIMNEYS AND TOWERS: A...
# 30            SECTION 16.24.340 (J) – DECKS: EVERY EXTERIOR ...
# 31            SECTION 16.24.340 (H) – DECORATIVE FEATURES: A...
# 33            SECTION 16.24.340 (Q) – DOORS: ALL EXTERIOR DO...
# 34            SECTION 16.24.340 (C)(1)– PREMISES IDENTIFICAT...
# 41            SECTION 16.24.340 (F) – EXTERIOR WALLS: ALL EX...
# 42            SECTION 16.24.340 (E) – FOUNDATION WALLS: ALL ...
# 46            SECTION 16.24.340 (S) – GUARDS FOR BASEMENT WI...
# 47            SECTION 16.24.340 (N) – GLAZING: ALL GLAZING M...
# 49            SECTION 16.24.340 (G) – ROOF GUTTERS: ROOF DRA...
# 50            SECTION 16.24.340 (L) – HANDRAILS AND GUARDS: ...
# 51            SECTION 16.24.340 (O) – OPENABLE WINDOWS: EVER...
# 52            SECTION 16.24.340 (I) – OVERHANG EXTENSIONS: A...
# 53            SECTION 16.24.340 (C)(2) – PREMISES IDENTIFICA...
# 54            SECTION 16.24.340 (C)(3) – PREMISES IDENTIFICA...
# 55            SECTION 16.24.340 (J) – PORCHES: EVERY EXTERIO...
# 57            SECTION 16.24.340 (B) – PROTECTIVE TREATMENT (...
# 58            SECTION 16.24.340 (B) – PROTECTIVE TREATMENT (...
# 59            SECTION 16.24.340 (B) – PROTECTIVE TREATMENT (...
# 62            SECTION 16.24.340 (G) – ROOF DRAINAGE: ROOF DR...
# 63            SECTION 16.24.340 (G) – ROOF SYSTEM: THE ROOF ...
# 65            SECTION 16.24.340 (P) – INSECT SCREENS: DURING...
# 66            SECTION 16.24.340 (P) – INSECT SCREENS: DURING...
# 68            SECTION 16.24.340 (J) – STAIRWAYS: EVERY EXTER...
# 69            SECTION 16.24.340 (D) – STRUCTURAL MEMBERS: AL...
# 91            SECTION 16.24.340 (T) – DEFACEMENT OF PROPERTY...
# 434           SECTION 16.24.340 (R) – BASEMENT HATCHWAYS: BA...
# 435           SECTION 16.24.340 (J) – BALCONIES: EVERY EXTER...
# ...                                                         ...
# 460           SECTION 16.24.340 (B) – PROTECTIVE TREATMENT (...
# 461           SECTION 16.24.340 (B) – PROTECTIVE TREATMENT (...
# 462           SECTION 16.24.340 (B) – PROTECTIVE TREATMENT (...
# 464           SECTION 16.24.340 (G) – ROOF DRAINAGE: ROOF DR...
# 465           SECTION 16.24.340 (G) – ROOF SYSTEM: THE ROOF ...
# 468           SECTION 16.24.340 (J) – STAIRWAYS: EVERY EXTER...
# 469           SECTION 16.24.340 (D) – STRUCTURAL MEMBERS: AL...
# 483           SECTION 16.24.340 (S) – GUARDS FOR BASEMENT WI...
# 484           SECTION 16.24.340 (T) – DEFACEMENT OF PROPERTY...
# 712                                                         NAN
# 713                                                         NAN
# 714                                                         NAN
# 715                                                         NAN
# 716           -REPAIR EXTERIOR (BRICK VENEER-STONE) WALLS, R...
# 717                                                         NAN
# 718                                                         NAN
# 719                                                         NAN
# 720                                                         NAN
# 721                                                         NAN
# 722                                                         NAN
# 723                                                         NAN
# 724                                                         NAN
# 725           -OVERHAUL WINDOWS; PROVIDE SOUND GLASS, SASH, ...
# 726                                                         NAN
# 727                                                         NAN
# 728                                                         NAN
# 729                                                         NAN
# 730                                                         NAN
# 731                                                         NAN
# 732                                                         NAN
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 27                       EXTBLD
# 28                       EXTBLD
# 29                       EXTBLD
# 30                       EXTBLD
# 31                       EXTBLD
# 33                       EXTBLD
# 34                       EXTBLD
# 41                       EXTBLD
# 42                       EXTBLD
# 46                       EXTBLD
# 47                       EXTBLD
# 49                       EXTBLD
# 50                       EXTBLD
# 51                       EXTBLD
# 52                       EXTBLD
# 53                       EXTBLD
# 54                       EXTBLD
# 55                       EXTBLD
# 57                       EXTBLD
# 58                       EXTBLD
# 59                       EXTBLD
# 62                       EXTBLD
# 63                       EXTBLD
# 65                       EXTBLD
# 66                       EXTBLD
# 68                       EXTBLD
# 69                       EXTBLD
# 91                       EXTBLD
# 434                      EXTBLD
# 435                      EXTBLD
# ...                         ...
# 460                      EXTBLD
# 461                      EXTBLD
# 462                      EXTBLD
# 464                      EXTBLD
# 465                      EXTBLD
# 468                      EXTBLD
# 469                      EXTBLD
# 483                      EXTBLD
# 484                      EXTBLD
# 712                      EXTBLD
# 713                      EXTBLD
# 714                      EXTBLD
# 715                      EXTBLD
# 716                      EXTBLD
# 717                      EXTBLD
# 718                      EXTBLD
# 719                      EXTBLD
# 720                      EXTBLD
# 721                      EXTBLD
# 722                      EXTBLD
# 723                      EXTBLD
# 724                      EXTBLD
# 725                      EXTBLD
# 726                      EXTBLD
# 727                      EXTBLD
# 728                      EXTBLD
# 729                      EXTBLD
# 730                      EXTBLD
# 731                      EXTBLD
# 732                      EXTBLD
#
# [77 rows x 4 columns]

# %% [markdown]
# ##### * extermination violations are those whose VIOLATION_DESC contains 'EXTERMINATION'

# %%
codes_df.loc[codes_df['VIOLATION_DESC'].str.contains('EXTERMINATION') |
             codes_df['VIOLATION_DESC'].str.contains('VERMIN|RODENT') |
             codes_df['VIOLATION_DESC'].str.contains('CHICKEN') |
             codes_df['VIOLATION_DESC'].str.contains('EXCREMENT')
             , 'VIOLATION_CATEGORY'] = 'ANIMALS/VERMIN'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'ANIMALS/VERMIN']
# Out:
#                    VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 12                      CHICKFARM  CHICKENS AND OTHER DOMESTIC FARM ANIMALS
# 35                     EXTERMOCUP        EXTERMINATION – MULTIPLE OCCUPANCY
# 36                     EXTEROCCUP           EXTERMINATION – SINGLE OCCUPANT
# 37                     EXTEROWNER                     EXTERMINATION – OWNER
# 38                       EXTERREQ                    EXTERMINATION REQUIRED
# 39                      EXTERSOCC                  EXTERMINATION – OCCUPANT
# 61                         EXTROD     EXTERIOR PROP AREA – RODENT HARBORAGE
# 402           CAAA_RODENT_INFESTA                        RODENT INFESTATION
# 463                  CAAH_EXT_ROD     EXTERIOR PROP AREA – RODENT HARBORAGE
# 477             CAAH_EXTER_MOCCUP        EXTERMINATION – MULTIPLE OCCUPANCY
# 478              CAAH_EXTER_OCCUP           EXTERMINATION – SINGLE OCCUPANT
# 479              CAAH_EXTER_OWNER                     EXTERMINATION – OWNER
# 480                CAAH_EXTER_REQ                    EXTERMINATION REQUIRED
# 481             CAAH_EXTER_SOCCUP                  EXTERMINATION – OCCUPANT
# 551            CAAZ_CHICK_ANIMALS  CHICKENS AND OTHER DOMESTIC FARM ANIMALS
# 627                      CAGA_DEX                             DOG EXCREMENT
# 650                 CAGO_CHICKENS                          KEEPING CHICKENS
# 747                        CAST42           RODENTS, INFESTATION AND VERMIN
# 761                    HD10360202             VERMIN AND RODENT INFESTATION
# 770                     HDPM_VERM                                    VERMIN
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 12            SECTION 17.16.330 (B) (2)(3) - DOMESTIC ANIMAL...
# 35            SECTION 16.24.370 (C) - EXTERMINATION REQUIRED...
# 36            SECTION 16.24.370 (B) - EXTERMINATION REQUIRED...
# 37            SECTION 16.24.370 (A) - EXTERMINATION REQUIRED...
# 38            SECTION 16.24.370 - EXTERMINATION REQUIRED. AP...
# 39            SECTION 16.24.370 (D) - EXTERMINATION REQUIRED...
# 61            SECTION 16.24.330 (F) – RODENT HARBORAGE: ALL ...
# 402           SECTION 16.24.330 - RODENT HARBORAGE: ALL STRU...
# 463           SECTION 16.24.330 (F) – RODENT HARBORAGE: ALL ...
# 477           SECTION 16.24.370 (C) - EXTERMINATION REQUIRED...
# 478           SECTION 16.24.370 (B) - EXTERMINATION REQUIRED...
# 479           SECTION 16.24.370 (A) - EXTERMINATION REQUIRED...
# 480           SECTION 16.24.370 - EXTERMINATION REQUIRED. AP...
# 481           SECTION 16.24.370 (D) - EXTERMINATION REQUIRED...
# 551           SECTION 17.16.330 (B) (2)(3) - DOMESTIC ANIMAL...
# 627           MCL CHAPTER 8.04.180 – REMOVAL OF EXCREMENT.  ...
# 650           MCL CHAPTER 8.12.020  KEEPING OF CHICKENS.NO P...
# 747                                                         NAN
# 761                                                         NAN
# 770           MCL CHAPTER 10.36.020 A -  EVERY DWELLING AND ...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 12               ANIMALS/VERMIN
# 35               ANIMALS/VERMIN
# 36               ANIMALS/VERMIN
# 37               ANIMALS/VERMIN
# 38               ANIMALS/VERMIN
# 39               ANIMALS/VERMIN
# 61               ANIMALS/VERMIN
# 402              ANIMALS/VERMIN
# 463              ANIMALS/VERMIN
# 477              ANIMALS/VERMIN
# 478              ANIMALS/VERMIN
# 479              ANIMALS/VERMIN
# 480              ANIMALS/VERMIN
# 481              ANIMALS/VERMIN
# 551              ANIMALS/VERMIN
# 627              ANIMALS/VERMIN
# 650              ANIMALS/VERMIN
# 747              ANIMALS/VERMIN
# 761              ANIMALS/VERMIN
# 770              ANIMALS/VERMIN

# %% [markdown]
# ##### * fire safety violations are those whose VIOLATION_DESC contains 'FIRE'

# %%
codes_df.loc[codes_df['VIOLATION_DESC'].str.contains('FIRE')
             , 'VIOLATION_CATEGORY'] = 'FIRE'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'FIRE']
# Out:
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 81                       FIREDOORS    FIRE SAFETY – EMERGENCY ESCAPE (DOORS)
# 82                      FIREPSMDIN  FIRE PROTECTION – SMOKE DETECTOR INSTALL
# 83                       FIRESFESC            FIRE SAFETY – EMERGENCY ESCAPE
# 84                       FIRESFGEN         FIRE SAFETY REQUIREMENTS – EGRESS
# 85                       FIRESFNCO  FIRE SAFETY – EMERGENCY ESCAPE (OPENING)
# 86                      FIRESFNCOH   FIRE SAFETY – EMERGENCY ESCAPE (HEIGHT)
# 87                      FIRESFNCOW    FIRE SAFETY – EMERGENCY ESCAPE (WIDTH)
# 88                        FIRESFOP       FIRE SAFETY – EMERGENCY ESCAPE (OP)
# 89                      FIRESMKDET         FIRE PROTECTION – SMOKE DETECTORS
# 417           CAAF_FIREPROT_SMDINS  FIRE PROTECTION – SMOKE DETECTOR INSTALL
# 418           CAAF_FIREPROT_SMKDET         FIRE PROTECTION – SMOKE DETECTORS
# 419              CAAF_FIRESF_DOORS    FIRE SAFETY – EMERGENCY ESCAPE (DOORS)
# 420                CAAF_FIRESF_ESC            FIRE SAFETY – EMERGENCY ESCAPE
# 421                CAAF_FIRESF_GEN         FIRE SAFETY REQUIREMENTS – EGRESS
# 422                CAAF_FIRESF_NCO  FIRE SAFETY – EMERGENCY ESCAPE (OPENING)
# 423               CAAF_FIRESF_NCOH   FIRE SAFETY – EMERGENCY ESCAPE (HEIGHT)
# 424               CAAF_FIRESF_NCOW    FIRE SAFETY – EMERGENCY ESCAPE (WIDTH)
# 425                 CAAF_FIRESF_OP       FIRE SAFETY – EMERGENCY ESCAPE (OP)
# 951                          BBR19                              FIRE MARSHAL
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 81            SECTION 16.24.530 (H) - LOCKED DOORS: ALL MEAN...
# 82            SECTION 16.24.550 (B) - 1A & B INSTALLATION: E...
# 83            SECTION 16.24.530 (B) - EMERGENCY ESCAPE AND R...
# 84            SECTION 16.24.530 (A) - GENERAL: A SAFE, CONTI...
# 85            SECTION 16.24.530 (C) - MINIMUM NET CLEAR OPEN...
# 86            SECTION 16.24.530 (D) - MINIMUM NET CLEAR OPEN...
# 87            SECTION 16.24.530 (E) - MINIMUM NET CLEAR OPEN...
# 88            SECTION 16.24.530 (F) - OPERATION: REQUIRED EM...
# 89            SECTION 16.24.550 (A) - SMOKE DETECTORS: EXIST...
# 417           SECTION 16.24.550 (B) - 1A & B INSTALLATION: E...
# 418           SECTION 16.24.550 (A) - SMOKE DETECTORS: EXIST...
# 419           SECTION 16.24.530 (H) - LOCKED DOORS: ALL MEAN...
# 420           SECTION 16.24.530 (B) - EMERGENCY ESCAPE AND R...
# 421           SECTION 16.24.530 (A) - GENERAL: A SAFE, CONTI...
# 422           SECTION 16.24.530 (C) - MINIMUM NET CLEAR OPEN...
# 423           SECTION 16.24.530 (D) - MINIMUM NET CLEAR OPEN...
# 424           SECTION 16.24.530 (E) - MINIMUM NET CLEAR OPEN...
# 425           SECTION 16.24.530 (F) - OPERATION: REQUIRED EM...
# 951           UPON MAKING APPLICATION FOR AN ON-SALE BEER PE...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 81                         FIRE
# 82                         FIRE
# 83                         FIRE
# 84                         FIRE
# 85                         FIRE
# 86                         FIRE
# 87                         FIRE
# 88                         FIRE
# 89                         FIRE
# 417                        FIRE
# 418                        FIRE
# 419                        FIRE
# 420                        FIRE
# 421                        FIRE
# 422                        FIRE
# 423                        FIRE
# 424                        FIRE
# 425                        FIRE
# 951                        FIRE

# %% [markdown]
# ##### * vehicle violations are those whose VIOLATION_TEXT contains 'SECTION 16.24.330' and 'PARKING', or 'SECTION 16.24.330 ([KP])' or whose VIOLATION_TYPE contains 'CAR'

# %%
codes_df.loc[codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.330 \([KP]') |
             (codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.330') &
             codes_df['VIOLATION_TEXT'].str.contains('PARKING')) |
             codes_df['VIOLATION_TYPE'].str.contains('CAR') |
             codes_df['VIOLATION_TEXT'].str.contains('SECTION 6.28.030\(H\)') |
             codes_df['VIOLATION_DESC'].str.contains('PARK')
             , 'VIOLATION_CATEGORY'] = 'VEHICLE'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'VEHICLE']
# Out:
#                   VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 9                         CARROW               VEHICLE IN THE RIGHT-OF-WAY
# 25                        EXPARK   EXTERIOR PROP AREA – VEHICLES – PARKING
# 56                      EXTPRKAR   EXTERIOR PROP AREA – DESIGNATED PARKING
# 67                      EXTSDWLK            EXTERIOR PROP AREA – SIDEWALKS
# 71                       EXTTRLS  EXTERIOR PROP AREA – TRAILERS WATERCRAFT
# 72                     EXTVEHCON      EXTERIOR PROP AREA – VEH – INOP/UNLC
# 73                      EXTVEHPT     EXTERIOR PROP AREA – VEHICLE PAINTING
# 74                      EXTVEHRP     EXTERIOR PROP AREA – VEH – DIS/REPAIR
# 144                   PAVINGPARK            PAVING PERMANENT PARKING AREAS
# 166                       SCHBUS                              SCHOOL BUSES
# 196                    TRACTRAIL                   TRACTOR-TRAILER PARKING
# 198                    TRUCKCOMM                  COMMERCIAL TRUCK PARKING
# 393               CAAA_IMV_ACCUM  UNLIC / INOP / ACCUMULATION MTR VEHICLES
# 397           CAAA_PARK_ON_GRASS                          PARKING ON GRASS
# 398             CAAA_PARKING_25%                  PARKING AREA EXCEEDS 25%
# 454                CAAH_EXT_PARK   EXTERIOR PROP AREA – VEHICLES – PARKING
# 459               CAAH_EXT_PRKAR   EXTERIOR PROP AREA – DESIGNATED PARKING
# 467               CAAH_EXT_SDWLK            EXTERIOR PROP AREA – SIDEWALKS
# 471                CAAH_EXT_TRLS  EXTERIOR PROP AREA – TRAILERS WATERCRAFT
# 472              CAAH_EXT_VEHCON      EXTERIOR PROP AREA – VEH – INOP/UNLC
# 473               CAAH_EXT_VEHPT     EXTERIOR PROP AREA – VEHICLE PAINTING
# 474               CAAH_EXT_VEHRP     EXTERIOR PROP AREA – VEH – DIS/REPAIR
# 517                 CAAH_SCH_BUS                              SCHOOL BUSES
# 519            CAAH_TRAC_TRAILER                   TRACTOR-TRAILER PARKING
# 521                   CAAH_TRUCK                  COMMERCIAL TRUCK PARKING
# 548                 CAAZ_CAR_ROW               VEHICLE IN THE RIGHT OF WAY
# 569             CAAZ_PAVING_PARK            PAVING PERMANENT PARKING AREAS
# 777                 CAAZ_STRP_RV            RV - CAMPERS, BUSES PROHIBITED
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 9             SECTION 12.08.210 - ABANDONED VEHICLES: ABANDO...
# 25            SECTION 16.24.330 (K)(3) – MOTOR VEHICLES (PAR...
# 56            SECTION 16.24.330 (K)(3) – VEHICLE PARKING ARE...
# 67            SECTION 16.24.330 (D) – SIDEWALKS AND DRIVEWAY...
# 71            SECTION 16.24.330 (P) – TRAILERS AND WATERCRAF...
# 72            SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (CON...
# 73            SECTION 16.24.330 (K)(4) – VEHICLE PAINTING: P...
# 74            SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (REP...
# 144           SECTION 17.20.070 (G) - PAVING: PERMANENT PARK...
# 166           SECTION 16.24.330 (K) (8) - SCHOOL BUSES: ON A...
# 196           SECTION 16.24.330 (K) (7) - TRACTOR-TRAILERS: ...
# 198           SECTION 16.24.330 (K) (6) - TRUCKS: ON ANY RES...
# 393           SECTION 16.24.330 - ACCUMULATION OF MOTOR VEHI...
# 397           SECTION 16.24.330 - PARKING ON GRASS: PARKING ...
# 398           SECTION 16.24.330 - PARKING AREA FOR RESIDENTI...
# 454           SECTION 16.24.330 (K)(3) – MOTOR VEHICLES (PAR...
# 459           SECTION 16.24.330 (K)(3) – VEHICLE PARKING ARE...
# 467           SECTION 16.24.330 (D) – SIDEWALKS AND DRIVEWAY...
# 471           SECTION 16.24.330 (P) – TRAILERS AND WATERCRAF...
# 472           SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (CON...
# 473           SECTION 16.24.330 (K)(4) – VEHICLE PAINTING: P...
# 474           SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (REP...
# 517           SECTION 16.24.330 (K) (8) - SCHOOL BUSES: ON A...
# 519           SECTION 16.24.330 (K) (7) - TRACTOR-TRAILERS: ...
# 521           SECTION 16.24.330 (K) (6) - TRUCKS: ON ANY RES...
# 548           SECTION 12.08.210 - ABANDONED VEHICLES: ABANDO...
# 569           SECTION 17.20.070 (G) - PAVING: PERMANENT PARK...
# 777           SECTION 6.28.030(H) PROHIBITED VEHICLES:  NO R...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 9                       VEHICLE
# 25                      VEHICLE
# 56                      VEHICLE
# 67                      VEHICLE
# 71                      VEHICLE
# 72                      VEHICLE
# 73                      VEHICLE
# 74                      VEHICLE
# 144                     VEHICLE
# 166                     VEHICLE
# 196                     VEHICLE
# 198                     VEHICLE
# 393                     VEHICLE
# 397                     VEHICLE
# 398                     VEHICLE
# 454                     VEHICLE
# 459                     VEHICLE
# 467                     VEHICLE
# 471                     VEHICLE
# 472                     VEHICLE
# 473                     VEHICLE
# 474                     VEHICLE
# 517                     VEHICLE
# 519                     VEHICLE
# 521                     VEHICLE
# 548                     VEHICLE
# 569                     VEHICLE
# 777                     VEHICLE

# %% [markdown]
# ##### * interior building violations are those whose VIOLATION_TEXT contains 'SECTION 16.24.3[589]0' or 'SECTION 16.24.4[78]0'

# %%
codes_df.loc[codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.3[589]0') |
             codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.4[78]0') |
             codes_df['VIOLATION_TYPE'].str.contains('CAST([2][5-9]|[3][0-9]|40)') |
             codes_df['VIOLATION_TYPE'].str.contains('CAGM')
             , 'VIOLATION_CATEGORY'] = 'INTBLD'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'INTBLD']
# Out:
# /Users/paulomartinez/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 94                         HEATREC     HEATING – HEATING FACILITIES REQUIRED
# 95                         HEATRES         HEATING – RESIDENTIAL OCCUPANCIES
# 96                      HEATSUPPLY                     HEATING – HEAT SUPPLY
# 97                      HEATWRKSPC             HEAT – OCCUPIABLE WORK SPACES
# 102                       INTBLDGN     INTERIORS OF BLDGS AND STRUCTURES GEN
# 103                      INTBLDSUR          INTERIOR OF BUILDINGS - SURFACES
# 104                      INTHNDGRD  INTERIOR OF BLDGS – HANDRAILS AND GUARDS
# 105                     INTINTDOOR    INTERIOR OF BUILDINGS – INTERIOR DOORS
# 106                       INTSTAIR   INTERIOR OF BLDGS – STAIRS WALKING SURF
# 108                     LIGHTCHALL        LIGHT – COMMON HALLS AND STAIRWAYS
# 110                      LIGHTHSPC                  LIGHT – HABITABLE SPACES
# 112                       LIGHTOTR                      LIGHT – OTHER SPACES
# 125                       MECHCOMB  MECHANICAL EQUIP – REMOVE OF COMBUS PROD
# 126                      MECHEQUIP             MECHANICAL EQUIP – APPLIANCES
# 190                          STMEM    INTERIOR OF BLDGS – STRUCTURAL MEMBERS
# 201                       VENTBATH  VENTILATION – BATHROOMS AND TOILET ROOMS
# 202                       VENTCOOK          VENTILATION – COOKING FACILITIES
# 203                      VENTDRYER      VENTILATION – CLOTHES DRYER EXHAUST
# 204                        VENTHAB            VENTILATION – HABITABLE SPACES
# 205                       VENTPROC         VENTILATION – PROCESS VENTILATION
# 394           CAAA_INTERIOR_REPAIR                           INTERIOR REPAIR
# 485                  CAAH_HEAT_REC     HEATING – HEATING FACILITIES REQUIRED
# 486                  CAAH_HEAT_RES         HEATING – RESIDENTIAL OCCUPANCIES
# 487               CAAH_HEAT_SUPPLY                     HEATING – HEAT SUPPLY
# 488              CAAH_HEAT_WRK_SPC             HEAT – OCCUPIABLE WORK SPACES
# 489                 CAAH_INT_BLDGN     INTERIORS OF BLDGS AND STRUCTURES GEN
# 490                CAAH_INT_BLDSUR          INTERIOR OF BUILDINGS - SURFACES
# 491                CAAH_INT_HNDGRD  INTERIOR OF BLDGS – HANDRAILS AND GUARDS
# 492               CAAH_INT_INTDOOR    INTERIOR OF BUILDINGS – INTERIOR DOORS
# 493                 CAAH_INT_STAIR   INTERIOR OF BLDGS – STAIRS WALKING SURF
# ...                            ...                                       ...
# 524              CAAH_VENT_COOKFAC          VENTILATION – COOKING FACILITIES
# 525                CAAH_VENT_DRYER       VENTILATION – CLOTHES DRYER EXHAUST
# 526               CAAH_VENT_HABSPC            VENTILATION – HABITABLE SPACES
# 527                 CAAH_VENT_PROC         VENTILATION – PROCESS VENTILATION
# 528                 CAAM_MECH_COMB  MECHANICAL EQUIP – REMOVE OF COMBUS PROD
# 529                CAAM_MECH_EQUIP             MECHANICAL EQUIP – APPLIANCES
# 639                       CAGM_GTD                      DIRT, FILTH, GARBAGE
# 641                         CAGM02       DEFECTIVE ELECTRIC WALL BASE HEATER
# 642                         CAGM03                MISSING HEAT CONTROL KNOBS
# 643                         CAGM04                           SEAL OPEN GRATE
# 644                         CAGM05   DEFECTIVE HEAT SUPPLY VENTS IN BASEMENT
# 645                         CAGM06         HEATING SYSTEM PROPERLY INSTALLED
# 646                         CAGM07         ADEQUATE VENTILATION FOR BATHROOM
# 647                         CAGM08                           SMOKE DETECTORS
# 648                         CAGM09                        HVAC SYSTEM REPAIR
# 649                         CAGM10                    FORCED AIR DUCT REPAIR
# 733                         CAST25  DAMAGED INTERIOR WALLS, CEILINGS, FLOORS
# 734                         CAST26  CLEAN FINISH FOR ALL WALLS CEILINGS DOOR
# 735                         CAST27         BROKEN, LOOSE AND MISSING PLASTER
# 736                         CAST28                CEILING: LOOSE AND MISSING
# 737                         CAST31     ROTTED, MISSING OR DEFECTIVE FLOORING
# 738                         CAST32                    RAISE AND LEVEL FLOORS
# 739                         CAST33          SAND AND REFINISH FLOOR SURFACES
# 740                         CAST34                            FLOOR COVERING
# 741                         CAST35                                 HANDRAILS
# 742                         CAST36                BANISTER SECURING HANDRAIL
# 743                         CAST37              BROKEN AND WOOD STAIR TREADS
# 744                         CAST38                     DAMAGED INTERIOR DOOR
# 745                         CAST39                          MISSING HARDWARE
# 746                         CAST40                            OVERHAUL FRAME
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 94            SECTION 16.24-470 (A) - HEATING REQUIRED HEATI...
# 95            SECTION 16.24.470 (B) - HEATING (RESIDENTIAL) ...
# 96            SECTION 16.24.470 (C) - HEAT (SUPPLY) EVERY OW...
# 97            SECTION 16.24.470 (D) - HEAT (WORK SPACES) IND...
# 102           SECTION 16.24.350 (A) – BUILDING INTERIOR (GEN...
# 103           SECTION 16.24.350 (C) - INTERIOR SURFACES. ALL...
# 104           SECTION 16.24.350 (E) - HANDRAILS AND GUARDS. ...
# 105           SECTION 16.24.350 (F) - INTERIOR DOORS. EVERY ...
# 106           SECTION 16.24.350 (D) - STAIRS AND WALKING SUR...
# 108           SECTION 16.24.380 (B) - LIGHT (COMMON AREAS) E...
# 110           SECTION 16.24.380 (A) - LIGHT (HABITABLE SPACE...
# 112           SECTION 16.24.380 (C) - LIGHT (OTHER SPACES) A...
# 125           SECTION 16.24.480 (B) - MECHANICAL EQUIPMENT (...
# 126           SECTION 16.24.480 (A) - MECHANICAL EQUIPMENT (...
# 190           SECTION 16.24.350 (B) - STRUCTURAL MEMBERS: AL...
# 201           SECTION 16.24.390 (B) - VENTILATION (BATHROOMS...
# 202           SECTION 16.24.390 (C) - VENTILATION (COOKING F...
# 203           SECTION 16.24.390 (E) - VENTILATION (CLOTHES D...
# 204           SECTION 16.24.390 (A) - VENTILATION (HABITABLE...
# 205           SECTION 16.24.390 (D) - VENTILATION (PROCESS) ...
# 394           SECTION 16.24.350 - THE INTERIOR OF A BUILDING...
# 485           SECTION 16.24-470 (A) - HEATING REQUIRED HEATI...
# 486           SECTION 16.24.470 (B) - HEATING (RESIDENTIAL) ...
# 487           SECTION 16.24.470 (C) - HEAT (SUPPLY) EVERY OW...
# 488           SECTION 16.24.470 (D) - HEAT (WORK SPACES) IND...
# 489           SECTION 16.24.350 (A) – BUILDING INTERIOR (GEN...
# 490           SECTION 16.24.350 (C) - INTERIOR SURFACES. ALL...
# 491           SECTION 16.24.350 (E) - HANDRAILS AND GUARDS. ...
# 492           SECTION 16.24.350 (F) - INTERIOR DOORS. EVERY ...
# 493           SECTION 16.24.350 (D) - STAIRS AND WALKING SUR...
# ...                                                         ...
# 524           SECTION 16.24.390 (C) - VENTILATION (COOKING F...
# 525           SECTION 16.24.390 (E) - VENTILATION (CLOTHES D...
# 526           SECTION 16.24.390 (A) - VENTILATION (HABITABLE...
# 527           SECTION 16.24.390 (D) - VENTILATION (PROCESS) ...
# 528           SECTION 16.24.480 (B) - MECHANICAL EQUIPMENT (...
# 529           SECTION 16.24.480 (A) - MECHANICAL EQUIPMENT (...
# 639           MCL CHAPTER 10.36.020 A -  EVERY DWELLING AND ...
# 641                                                         NAN
# 642                                                         NAN
# 643                                                         NAN
# 644                                                         NAN
# 645                                                         NAN
# 646                                                         NAN
# 647                                                         NAN
# 648                                                         NAN
# 649                                                         NAN
# 733           -REPLACE OR REPAIR ALL DAMAGED INTERIOR WALLS,...
# 734                                                         NAN
# 735                                                         NAN
# 736                                                         NAN
# 737                                                         NAN
# 738           -RAISE AND LEVEL FLOORS; PROVIDE SOUND FLOOR J...
# 739                                                         NAN
# 740                                                         NAN
# 741           -PROVIDE HANDRAILS FOR (STAIRWAY TO BASEMENT; ...
# 742                                                         NAN
# 743                                                         NAN
# 744                                                         NAN
# 745                                                         NAN
# 746                                                         NAN
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 94                       INTBLD
# 95                       INTBLD
# 96                       INTBLD
# 97                       INTBLD
# 102                      INTBLD
# 103                      INTBLD
# 104                      INTBLD
# 105                      INTBLD
# 106                      INTBLD
# 108                      INTBLD
# 110                      INTBLD
# 112                      INTBLD
# 125                      INTBLD
# 126                      INTBLD
# 190                      INTBLD
# 201                      INTBLD
# 202                      INTBLD
# 203                      INTBLD
# 204                      INTBLD
# 205                      INTBLD
# 394                      INTBLD
# 485                      INTBLD
# 486                      INTBLD
# 487                      INTBLD
# 488                      INTBLD
# 489                      INTBLD
# 490                      INTBLD
# 491                      INTBLD
# 492                      INTBLD
# 493                      INTBLD
# ...                         ...
# 524                      INTBLD
# 525                      INTBLD
# 526                      INTBLD
# 527                      INTBLD
# 528                      INTBLD
# 529                      INTBLD
# 639                      INTBLD
# 641                      INTBLD
# 642                      INTBLD
# 643                      INTBLD
# 644                      INTBLD
# 645                      INTBLD
# 646                      INTBLD
# 647                      INTBLD
# 648                      INTBLD
# 649                      INTBLD
# 733                      INTBLD
# 734                      INTBLD
# 735                      INTBLD
# 736                      INTBLD
# 737                      INTBLD
# 738                      INTBLD
# 739                      INTBLD
# 740                      INTBLD
# 741                      INTBLD
# 742                      INTBLD
# 743                      INTBLD
# 744                      INTBLD
# 745                      INTBLD
# 746                      INTBLD
#
# [65 rows x 4 columns]

# %% [markdown]
# ##### * occupancy violations are those whose VIOLATION_TEXT contains 'SECTION 16.24.400'

# %%
codes_df.loc[codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.400') |
             codes_df['VIOLATION_DESC'].str.contains('OVERCROWD') |
             codes_df['VIOLATION_DESC'].str.contains('BOARDING') |
             codes_df['VIOLATION_DESC'].str.contains('VACA')
             , 'VIOLATION_CATEGORY'] = 'OCCUPANCY'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'OCCUPANCY']
# Out:
#                     VIOLATION_TYPE                       VIOLATION_DESC  \
# VIOLATION_ID
# 7                       BOARDINGRQ                BOARDING REQUIREMENTS
# 8                         BOARDVAC         BOARDING OF VACANT BUILDINGS
# 14                       CROWDEDFM      OVERCROWDING – UNRELATED ADULTS
# 15                         CROWDGH            OVERCROWDING – GROUP HOME
# 101                      HSANVACBD                VACATION OF BUILDINGS
# 121                      LITVACLOT                LITTER ON VACANT LOTS
# 130                       OCCUPACC     OCCUPANCY – ACCESS FROM BEDROOMS
# 131                       OCCUPBED     OCCUPANCY – BEDROOM REQUIREMENTS
# 132                     OCCUPLIMPV           OCCUPANCY LIMITS – PRIVACY
# 133                     OCCUPOCRWD             OCCUPANCY – OVERCROWDING
# 134                      OCCUPOREQ       OCCUPANCY – OTHER REQUIREMENTS
# 135                      OCCUPPROH                 OCCUPANCY PROHIBITED
# 136                     OCCUPRMHGT  OCCUPANCY – MINIMUM CEILING HEIGHTS
# 138                     OCCUPSLEEP           OCCUPANCY – SLEEPING ROOMS
# 139                     OCCUPWCACC      OCCUPANCY – WATER CLOSET ACCESS
# 200                      VACANTBLD                     VACANT BUILDINGS
# 429             CAAH_BOARDING_REQU                BOARDING REQUIREMENTS
# 430           CAAH_BOARDING_VABLDG         BOARDING OF VACANT BUILDINGS
# 497              CAAH_OCCUP_ACCESS     OCCUPANCY – ACCESS FROM BEDROOMS
# 498               CAAH_OCCUP_BEDRM     OCCUPANCY – BEDROOM REQUIREMENTS
# 499              CAAH_OCCUP_LIMPVY           OCCUPANCY LIMITS – PRIVACY
# 500               CAAH_OCCUP_OCRWD             OCCUPANCY – OVERCROWDING
# 501                CAAH_OCCUP_OREQ       OCCUPANCY – OTHER REQUIREMENTS
# 502              CAAH_OCCUP_PROHIB                 OCCUPANCY PROHIBITED
# 503               CAAH_OCCUP_RMHGT  OCCUPANCY – MINIMUM CEILING HEIGHTS
# 505             CAAH_OCCUP_SLEEPRM           OCCUPANCY – SLEEPING ROOMS
# 506               CAAH_OCCUP_WCACC      OCCUPANCY – WATER CLOSET ACCESS
# 522            CAAH_VACANT_BLDINGS                     VACANT BUILDINGS
# 566               CAAZ_OVCROWDEDFM      OVERCROWDING – UNRELATED ADULTS
# 567               CAAZ_OVCROWDEDGH            OVERCROWDING – GROUP HOME
# 568               CAAZ_OVERCROWDED                         OVERCROWDING
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 7             SECTION 16.24.340 (U) (2) – BOARDING OF VACANT...
# 8             SECTION 16.24.340 (U) (1) – BOARDING OF VACANT...
# 14            SECTION 16.24.030 & 17.04.060 - OVERCROWDING: ...
# 15            SECTION 17.04.060 (2) - FAMILY: NO MORE THAN E...
# 101           SECTION 10.36.030 - VACATION OF BUILDINGS: WHE...
# 121           SECTION 10.24.140 - LITTER ON VACANT LOTS: NO ...
# 130           SECTION 16.24.400 (F) - OCCUPANCY (ACCESS TO B...
# 131           SECTION 16.24.400 (D) - OCCUPANCY (BEDROOM REQ...
# 132           SECTION 16.24.400 (A) - OCCUPANCY LIMITS (PRIV...
# 133           SECTION 16.24.400 (J) - OCCUPANCY (OVERCROWDIN...
# 134           SECTION 16.24.400 (I) - OCCUPANCY (OTHER REQUI...
# 135           SECTION 16.24.400 (H) - OCCUPANCY PROHIBITED K...
# 136           SECTION 16.24.400 (C) - OCCUPANCY (MINIMUM CEI...
# 138           SECTION 16.24.400 (E) - OCCUPANCY (SLEEPING RO...
# 139           SECTION 16.24.400 (G) - OCCUPANCY (WATER CLOSE...
# 200           SECTION 16.24.320 – VACANT BUILDINGS AND STRUC...
# 429           SECTION 16.24.340 (U) (2) – BOARDING OF VACANT...
# 430           SECTION 16.24.340 (U) (1) – BOARDING OF VACANT...
# 497           SECTION 16.24.400 (F) - OCCUPANCY (ACCESS TO B...
# 498           SECTION 16.24.400 (D) - OCCUPANCY (BEDROOM REQ...
# 499           SECTION 16.24.400 (A) - OCCUPANCY LIMITS (PRIV...
# 500           SECTION 16.24.400 (J) - OCCUPANCY (OVERCROWDIN...
# 501           SECTION 16.24.400 (I) - OCCUPANCY (OTHER REQUI...
# 502           SECTION 16.24.400 (H) - OCCUPANCY PROHIBITED K...
# 503           SECTION 16.24.400 (C) - OCCUPANCY (MINIMUM CEI...
# 505           SECTION 16.24.400 (E) - OCCUPANCY (SLEEPING RO...
# 506           SECTION 16.24.400 (G) - OCCUPANCY (WATER CLOSE...
# 522           SECTION 16.24.320 – VACANT BUILDINGS AND STRUC...
# 566           SECTION 16.24.030 & 17.04.060 - OVERCROWDING: ...
# 567           SECTION 17.04.060 (2) - FAMILY: NO MORE THAN E...
# 568           SECTION 17.04.060.  TOO MANY PERSONS LIVING TO...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 7                     OCCUPANCY
# 8                     OCCUPANCY
# 14                    OCCUPANCY
# 15                    OCCUPANCY
# 101                   OCCUPANCY
# 121                   OCCUPANCY
# 130                   OCCUPANCY
# 131                   OCCUPANCY
# 132                   OCCUPANCY
# 133                   OCCUPANCY
# 134                   OCCUPANCY
# 135                   OCCUPANCY
# 136                   OCCUPANCY
# 138                   OCCUPANCY
# 139                   OCCUPANCY
# 200                   OCCUPANCY
# 429                   OCCUPANCY
# 430                   OCCUPANCY
# 497                   OCCUPANCY
# 498                   OCCUPANCY
# 499                   OCCUPANCY
# 500                   OCCUPANCY
# 501                   OCCUPANCY
# 502                   OCCUPANCY
# 503                   OCCUPANCY
# 505                   OCCUPANCY
# 506                   OCCUPANCY
# 522                   OCCUPANCY
# 566                   OCCUPANCY
# 567                   OCCUPANCY
# 568                   OCCUPANCY

# %% [markdown]
# ##### * short-term rental violations are those whose VIOLATION_TEXT contains 'SECTION 6.04' or 'SECTION 6.28'

# %%
codes_df.loc[codes_df['VIOLATION_TEXT'].str.contains('SECTION 6.[(04)(28)]')
             , 'VIOLATION_CATEGORY'] = 'SHORT_TERM_RENTAL'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'SHORT_TERM_RENTAL']
# Out:
#                     VIOLATION_TYPE                   VIOLATION_DESC  \
# VIOLATION_ID
# 589                CAAZ_SIGN_POLEN    PROHIBITED ON POSTS AND POLES
# 772               CAAA_STRP_PERMIT             STRP PERMIT REQUIRED
# 773            CAAZ_STRP_EXCESS BR                  EXCESS BEDROOMS
# 774           CAAZ_STRP_PERTYP_OOC  OWNER OCCUPIED PERMIT VIOLATION
# 775                CAAZ_STRP_SIGNS               SIGNAGE PROHIBITED
# 776                CAAZ_STRP_NOISE          EXCESSIVE NOISE / WASTE
# 777                   CAAZ_STRP_RV   RV - CAMPERS, BUSES PROHIBITED
# 778                 CAAZ_STRP_FOOD         FOOD PROVIDED PROHIBITED
# 779           CAAZ_STRP_EXCESSOCCU                 EXCESS OCCUPANCY
# 780            CAAZ_STRP_OCCLIMITS            OCCUPANCY TIME LIMITS
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 589           SECTION 6.04.010 - PROHIBITED ON POSTS AND POL...
# 772           SECTION 6.28.030 ( C) STRP PERMIT REQUIRED: NO...
# 773           SECTION 6.28.030 (A) SHORT TERM RENTAL PROPERT...
# 774           SECTION 6.28.030 (B) OWNER OCCUPIED: FOR PURPO...
# 775           SECTION 6.28.030 (E) SIGNAGE: SIGNS, ADVERTISI...
# 776           SECTION 6.28.030 (F) NOISE: ALL STRP OCCUPANTS...
# 777           SECTION 6.28.030(H) PROHIBITED VEHICLES:  NO R...
# 778           SECTION 6.28.030 (I) FOOD TO GUESTS PROHIBITED...
# 779           SECTION 6.28.030 ( K) MAXIMUM OCCUPANCY: THE M...
# 780           SECTION 6.28.030 (L) OCCUPANCY TIME LIMTS: THE...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 589           SHORT_TERM_RENTAL
# 772           SHORT_TERM_RENTAL
# 773           SHORT_TERM_RENTAL
# 774           SHORT_TERM_RENTAL
# 775           SHORT_TERM_RENTAL
# 776           SHORT_TERM_RENTAL
# 777           SHORT_TERM_RENTAL
# 778           SHORT_TERM_RENTAL
# 779           SHORT_TERM_RENTAL
# 780           SHORT_TERM_RENTAL

# %% [markdown]
# ##### * fencing violations are those whose VIOLATION_TEXT contains 'FENC' but not 'SECTION 16.24.340 (B)', or those whose 'VIOLATION_DESC' contains 'GATE'

# %%
codes_df.loc[(codes_df['VIOLATION_TEXT'].str.contains('FENC') &
             ~codes_df['VIOLATION_TEXT'].str.contains('SECTION 16.24.340 \(B\)')) |
             codes_df['VIOLATION_DESC'].str.contains('GATE') |
             codes_df['VIOLATION_DESC'].str.contains('FENC')
             , 'VIOLATION_CATEGORY'] = 'FENCING'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'FENCING']
# Out:
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 26                          EXTACC     EXTERIOR PROP AREA – ACCES STRUCTURES
# 32                        EXTDENBW  EXTERIOR PROP AREA – FENCES  BARBED WIRE
# 43                      EXTFENMAIN  EXTERIOR PROP AREA – FENCE MATERIAL MAIN
# 44                       EXTFENMAT    EXTERIOR PROP AREA – FENCING MATERIALS
# 45                         EXTGATE                EXTERIOR PROP AREA – GATES
# 77                      FENCEGHTPR  FENCE HEIGHT – OFF RIGHT-OF-WAY (OPAQUE)
# 78                      FENCEHGFRT       FENCE HEIGHT – INSIDE FRONT SETBACK
# 79                       FENCEHGSR      FENCE HEIGHT – SIDE AND REAR SETBACK
# 80                      FENCEHGTOP    FENCE HEIGHT – OFF RIGHT-OF-WAY (OPEN)
# 381           CAAA_ACCESSORY_STUCT                      ACCESSORY STRUCTURES
# 389            CAAA_FENCE_MATERIAL                            FENCE MATERIAL
# 390                CAAA_GATE_MAINT                          GATE MAINTENANCE
# 432                  CAAH_EX_FENBW  EXTERIOR PROP AREA – FENCES  BARBED WIRE
# 433                   CAAH_EXT_ACC     EXTERIOR PROP AREA – ACCES STRUCTURES
# 443              CAAH_EXT_FENMAINT  EXTERIOR PROP AREA – FENCE MATERIAL MAIN
# 444                CAAH_EXT_FENMAT    EXTERIOR PROP AREA – FENCING MATERIALS
# 445                  CAAH_EXT_GATE                EXTERIOR PROP AREA – GATES
# 554                 CAAZ_FENCE_HGT                              FENCE HEIGHT
# 555             CAAZ_FENCE_HGT_FRT       FENCE HEIGHT – INSIDE FRONT SETBACK
# 556             CAAZ_FENCE_HGT_OPN    FENCE HEIGHT – OFF RIGHT-OF-WAY (OPEN)
# 557             CAAZ_FENCE_HGT_PRV  FENCE HEIGHT – OFF RIGHT-OF-WAY (OPAQUE)
# 558            CAAZ_FENCE_HGT_SRER      FENCE HEIGHT – SIDE AND REAR SETBACK
# 750                         CAST46             REPAIR FENCES, SHEDS, GARAGES
# 751                         CAST48   REMOVE DILAPIDATED FENCES, SHED, GARAGE
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 26            SECTION 16.24.330 (H) – ACCESSORY STRUCTURES: ...
# 32            SECTION 16.24.330 (O) – FENCES (BARBED WIRE): ...
# 43            SECTION 16.24.330 (M) – FENCE MAINTENANCE: MET...
# 44            SECTION 16.24.330 (L) – FENCING MATERIALS: FEN...
# 45            SECTION 16.24.330 (I) – GATES: GATES WHICH ARE...
# 77            SECTION 17.12.040 (E) 26(A) - SCREENING WALLS ...
# 78            SECTION 17.12.040 (E) 26(B) - SCREENING WALLS ...
# 79            SECTION 17.12.040 (E) 26(C) - SCREENING WALLS ...
# 80            SECTION 17.12.040 (E) 26(A) - SCREENING WALLS ...
# 381           SECTION 16.24.330 - ACCESSORY STRUCTURES: ALL ...
# 389           SECTION 16.04.200 - FENCE MATERIALS:  EXPRESSL...
# 390           SECTION 16.24.330 - GATES:  SHALL BE MAINTAINE...
# 432           SECTION 16.24.330 (O) – FENCES (BARBED WIRE): ...
# 433           SECTION 16.24.330 (H) – ACCESSORY STRUCTURES: ...
# 443           SECTION 16.24.330 (M) – FENCE MAINTENANCE: MET...
# 444           SECTION 16.24.330 (L) – FENCING MATERIALS: FEN...
# 445           SECTION 16.24.330 (I) – GATES: GATES WHICH ARE...
# 554           SECTION 17.12.040 - THE MAXIMUM FENCE HEIGHT M...
# 555           SECTION 17.12.040 (E) 26(B) - SCREENING WALLS ...
# 556           SECTION 17.12.040 (E) 26(A) - SCREENING WALLS ...
# 557           SECTION 17.12.040 (E) 26(A) - SCREENING WALLS ...
# 558           SECTION 17.12.040 (E) 26(C) - SCREENING WALLS ...
# 750           -SUBSTANTIALLY REPAIR (FENCES, SHEDS, GARAGES)...
# 751                                                         NAN
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 26                      FENCING
# 32                      FENCING
# 43                      FENCING
# 44                      FENCING
# 45                      FENCING
# 77                      FENCING
# 78                      FENCING
# 79                      FENCING
# 80                      FENCING
# 381                     FENCING
# 389                     FENCING
# 390                     FENCING
# 432                     FENCING
# 433                     FENCING
# 443                     FENCING
# 444                     FENCING
# 445                     FENCING
# 554                     FENCING
# 555                     FENCING
# 556                     FENCING
# 557                     FENCING
# 558                     FENCING
# 750                     FENCING
# 751                     FENCING

# %% [markdown]
# ##### * sales violations are those whose VIOLATION_DESC contains 'CONSIGN' or 'GARAGE SALE' or 'HANDBILL'

# %%
codes_df.loc[codes_df['VIOLATION_DESC'].str.contains('CONSIGN') |
             codes_df['VIOLATION_DESC'].str.contains('GARAGE SALE') |
             codes_df['VIOLATION_DESC'].str.contains('HANDBILL') |
             codes_df['VIOLATION_DESC'].str.contains('VENDING')
             , 'VIOLATION_CATEGORY'] = 'SALES'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'SALES']
# Out:
#                    VIOLATION_TYPE                        VIOLATION_DESC  \
# VIOLATION_ID
# 13                     CONSIGSALE                      CONSIGNMENT SALE
# 90                      GARAGESAL                          GARAGE SALES
# 115                    LITHNBILLP    HANDBILLS - DISTRIBUTION IN PUBLIC
# 116                    LITHNBILLV  HANDBILLS - DISTRIBUTION ON VEHICLES
# 127                      MVENVEND                        MOBILE VENDING
# 156                     RESUSECON                      CONSIGNMENT SALE
# 553             CAAZ_CONSIGN_SALE                      CONSIGNMENT SALE
# 559              CAAZ_GARAGE_SALE                          GARAGE SALES
# 564             CAAZ_MVEN_VENDING                        MOBILE VENDING
# 574           CAAZ_RESUSE_CONSIGN                      CONSIGNMENT SALE
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 13            SECTION 17.16.030 ((B) 4) - CONSIGNMENT SALE (...
# 90            SECTION 17.16.250 (B) - GARAGE SALE: WITHIN AN...
# 115           SECTION 10.24.030 - HANDBILLS - DISTRIBUTION I...
# 116           SECTION 10.24.040 - HANDBILLS-DISTRIBUTION ON ...
# 127           ORDINANCE BL2006-1283 - MOBILE VENDOR: THE PED...
# 156           SECTION 17.16.030 (A) - CONSIGNMENT SALE: ACCE...
# 553           SECTION 17.16.030 ((B) 4) - CONSIGNMENT SALE (...
# 559           SECTION 17.16.250 (B) - GARAGE SALE: WITHIN AN...
# 564           ORDINANCE BL2006-1283 - MOBILE VENDOR: THE PED...
# 574           SECTION 17.16.030 (A) - CONSIGNMENT SALE: ACCE...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 13                        SALES
# 90                        SALES
# 115                       SALES
# 116                       SALES
# 127                       SALES
# 156                       SALES
# 553                       SALES
# 559                       SALES
# 564                       SALES
# 574                       SALES

# %% [markdown]
# ##### * trees

# %%
codes_df.loc[codes_df['VIOLATION_TYPE'].str.contains('TREE') | 
            codes_df['VIOLATION_DESC'].str.contains('VEGETATION') |
            codes_df['VIOLATION_TYPE'].str.contains('WEED')
             , 'VIOLATION_CATEGORY'] = 'LANDSCAPE'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'LANDSCAPE']
# Out:
#                   VIOLATION_TYPE                   VIOLATION_DESC  \
# VIOLATION_ID
# 75                       EXTWEED  EXTERIOR PROP AREA – HIGH WEEDS
# 392              CAAA_HIGH_WEEDS                       HIGH WEEDS
# 475                CAAH_EXT_WEED  EXTERIOR PROP AREA – HIGH WEEDS
# 601             CAAZT_TREE_MAINT      MAINTAIN LANDSCAPE MATERIAL
# 602            CAAZT_TREE_PERMIT              TREE REMOVAL PERMIT
# 603             CAAZT_TREE_PLANS       COMPLY WITH APPROVED PLANS
# 604            CAAZT_TREE_PROTEC                  TREE PROTECTION
# 605           CAAZT_TREE_REMOVAL           HAZARDOUS TREE REMOVAL
# 634                     CAGH_HWG                EXCESS VEGETATION
# 762                   HD10360203                EXCESS VEGETATION
# 771                       HDVIOL             VEGETATION VIOLATION
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 75            SECTION 16.24.330 (E) – HIGH WEEDS: ALL PREMIS...
# 392           SECTION 16.24.330 - HIGH WEEDS: ALL PREMISES S...
# 475           SECTION 16.24.330 (E) – HIGH WEEDS: ALL PREMIS...
# 601           SECTION 17.24.080. FAILURE OF MAINTENANCE OF R...
# 602           SECTION 17.40.470.  FAILURE TO OBTAIN A TREE R...
# 603           SECTION 17.24. FAILURE TO COMPLY WITH APPROVED...
# 604           SECTION 17.24.090.  FAILURE TO ADHERE TO TREE ...
# 605           SECTION 2.104.050 IF THE URBAN FORESTER IS INF...
# 634           MCL CHAPTER 10.26.010 – EVERY PREMISE INCLUDIN...
# 762                                                         NAN
# 771                                                         NAN
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 75                    LANDSCAPE
# 392                   LANDSCAPE
# 475                   LANDSCAPE
# 601                   LANDSCAPE
# 602                   LANDSCAPE
# 603                   LANDSCAPE
# 604                   LANDSCAPE
# 605                   LANDSCAPE
# 634                   LANDSCAPE
# 762                   LANDSCAPE
# 771                   LANDSCAPE

# %% [markdown]
# ##### Here are the rows remaining to be categorized...

# %%
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == '']
# Out:
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 2                       BGMATOWNER            PROPER MAINTENANCE REQ - OWNER
# 4                        BLDGMAINT                    PROPER MAINTENANCE REQ
# 5                       BLDGPERMIT                  BUILDING PERMIT REQUIRED
# 6                        BLDGSCOPE                    SCOPE OF BUILDING CODE
# 10                        CERTCOMP        CERTIFICATE OF COMPLIANCE REQUIRED
# 11                         CERTOCC         CERTIFICATE OF OCCUPANCY REQUIRED
# 40                         EXTEXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 48                         EXTGRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 60                       EXTREPAIR                 EXTERIOR REPAIR – GENERAL
# 70                         EXTSWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 76                      EXTWINDDRF   EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES
# 98                         HOMEOCC         HOME OCCUPATION – PERMIT REQUIRED
# 99                      HOMEOCCCON              HOME OCCUPATION – CONDITIONS
# 107                        LANDREG            LANDLORD REGISTRATION REQUIRED
# 117                      LITNOTICE                POSTING NOTICES PROHIBITED
# 118                         LITPRO          PROPER PLACEMENT IN RECEPTACLES
# 128                          NOISE           CONTINUOUS & INTERMITTENT NOISE
# 137                     OCCUPRMWID           OCCUPANCY – MINIMUM ROOM WIDTHS
# 145                      PERMITREQ       BUILDING AND ZONING PERMIT REQUIRED
# 153                       QUARHOLE                 NUISANCE DECLARED - HOLES
# 154                      RESPMAINT   FAILURE TO MAINTAIN BLDGS OR STRUCTURES
# 155                     RESUESECRS                        SECURITY RESIDENCE
# 174                         SIGH25           SIGNS – GREATER THAN 25 PERCENT
# 191                       STOPWORK                    STOP WORK ORDER POSTED
# 192                      TEMPEXPIR                     TEMPORARY U&O EXPIRED
# 199                     USENOTPERM                         USE NOT PERMITTED
# 210                      SWVIOLPTP  VIOLATIONS - POST CONSTRUCTION TREATMENT
# 212                       SWVIOLWQ      VIOLATIONS FOR WATER QUALITY IMPACTS
# 213                       SWENVCRT           ENVIRONMENTAL COURT PROCEEDINGS
# 214                       SWVIOLGP  VIOLATIONS - FOR CONSTRUCTION ACTIVITIES
# ...                            ...                                       ...
# 427                CAAH_BLDG_MAINT                    PROPER MAINTENANCE REQ
# 428                CAAH_BLDG_SCOPE                    SCOPE OF BUILDING CODE
# 431                  CAAH_CERT_OCC         CERTIFICATE OF OCCUPANCY REQUIRED
# 440                  CAAH_EXT_EXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 447                  CAAH_EXT_GRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 470                  CAAH_EXT_SWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 476               CAAH_EXT_WINDDRF   EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES
# 482           CAAH_EXTERIOR_REPAIR                 EXTERIOR REPAIR – GENERAL
# 504               CAAH_OCCUP_RMWID           OCCUPANCY – MINIMUM ROOM WIDTHS
# 511                CAAH_RESP_MAINT   FAILURE TO MAINTAIN BLDGS OR STRUCTURES
# 546                  CAAR_LAND_REG            LANDLORD REGISTRATION REQUIRED
# 549                 CAAZ_CERT_COMP        CERTIFICATE OF COMPLIANCE REQUIRED
# 550               CAAZ_CERT_COMPLY                CERTIFICATE COMPLIANCE REQ
# 552                CAAZ_COMVEH_RES   COMMERCIAL VEHICLE RESIDENTIAL DISTRICT
# 560                  CAAZ_HOME_OCC              HOME OCCUPATION – CONDITIONS
# 561                   CAAZ_HOMEOCC         HOME OCCUPATION – PERMIT REQUIRED
# 565                     CAAZ_NOISE           CONTINUOUS & INTERMITTENT NOISE
# 570            CAAZ_PERMIT_BLD_REQ       BUILDING AND ZONING PERMIT REQUIRED
# 573            CAAZ_PERMIT_USE_REQ     FAILURE TO OBTAIN REQUIRED USE PERMIT
# 575              CAAZ_REUSE_SECRES                        SECURITY RESIDENCE
# 599            CAAZ_USE_NOT_PERMIT                         USE NOT PERMITTED
# 600           CAAZT_FULL_COMPLANCE                 CERTIFICATE OF COMPLIANCE
# 661           CALL_LANDLORD_REGSTR                     LANDLORD REGISTRATION
# 749                         CAST45                                 YARD AREA
# 753                         CAST51               REMOVE COMBUSTIBLE MATERIAL
# 754                         CAST52                         FAILURE TO REPAIR
# 758                      HD1032140    ACCUMUALTION OF LUMBER, BOXES, BARRELS
# 763                     HD10360204                        CLEAN AMINAL AREAS
# 766                      HD1624110                           FAULTY PLUMBING
# 928                    BT574203B1A                            FAILURE TO PAY
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 2             SECTION 16.16.030 (B) - PROPER MAINTENANCE REQ...
# 4             SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 5             SECTION 16.28.010 - BUILDING PERMIT REQUIRED: ...
# 6             SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 10            SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 11            SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
# 40            SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 48            SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 60            SECTION 16.24.340 – EXTERIOR REPAIR: THE EXTER...
# 70            SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 76            SECTION 16.24.340 (M) – WINDOW, SKYLIGHT AND D...
# 98            SECTION 17.16.250 (C) - HOME OCCUPATION (PERMI...
# 99            SECTION 17.16.250 (C) - HOME OCCUPATION (CONDI...
# 107           TENNESSEE CODE ANNOTATED (TCA) 66-28-101 - FAI...
# 117           SECTION 10.24.020 - POSTING NOTICES PROHIBITED...
# 118           SECTION 10.24.110 - PROPER PLACEMENT IN RECEPT...
# 128           SECTION 17.28.090 (C) - NOISE LEVELS: SOUND LE...
# 137           SECTION 16.34.400 (B) - OCCUPANCY (MINIMUM ROO...
# 145           SECTION 17.40.520 - ZONING PERMIT REQUIRED: AN...
# 153           SECTION 10.52.020 - NUISANCE DECLARED WHEN: HO...
# 154           SECTION 16.24.310 – RESPONSIBILITY: THE OWNER ...
# 155           SECTION 17.16.030 (C) - SECURITY RESIDENCE: RE...
# 174           SECTION 17.32.040 (M) – TEMPORARY SIGNS AND DI...
# 191           SECTION 16.04.110 – VIOLATION OF STOP WORK ORD...
# 192           SECTION 17.04.100 – NO USE AND OCCUPANCY ISSUE...
# 199           SECTION 17.08.030 – USE NOT PERMITTED: THE USE...
# 210                                                 SEE SW CODE
# 212                                                 SEE SW CODE
# 213                                                 SEE SW CODE
# 214                                                 SEE SW CODE
# ...                                                         ...
# 427           SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 428           SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 431           SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
# 440           SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 447           SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 470           SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 476           SECTION 16.24.340 (M) – WINDOW, SKYLIGHT AND D...
# 482           SECTION 16.24.340 – EXTERIOR REPAIR: THE EXTER...
# 504           SECTION 16.34.400 (B) - OCCUPANCY (MINIMUM ROO...
# 511           SECTION 16.24.310 – RESPONSIBILITY: THE OWNER ...
# 546           TENNESSEE CODE ANNOTATED (TCA) 66-28-101 - FAI...
# 549           SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 550           FOLLOWING ISSUANCE OF A ZONING PERMIT, NO STRU...
# 552           SECTION 17.08.030 - USE NOT PERMITTED: THE OPE...
# 560           SECTION 17.16.250 (C) - HOME OCCUPATION (CONDI...
# 561           SECTION 17.16.250  (C) - HOME OCCUPATION (PERM...
# 565           SECTION 17.28.090 (C) - NOISE LEVELS: SOUND LE...
# 570           SECTION 17.40.520 - ZONING PERMIT REQUIRED: AN...
# 573           SECTION 17.40.520 - AN APPLICATION FOR A ZONIN...
# 575           SECTION 17.16.030 (C) - SECURITY RESIDENCE: RE...
# 599           SECTION 17.08.030 – USE NOT PERMITTED: THE USE...
# 600           SECTION 17.40.580 - FOLLOWING ISSUANCE OF A ZO...
# 661           FAILURE TO REGISTER AS A LANDLORD.  T.C.A. 66-...
# 749                                                         NAN
# 753           -REMOVE ALL COMBUSTIBLE MATERIALS -WITHIN TEN ...
# 754           THE OWNER, PARTY IN INTEREST, LESSEE, AGENT, O...
# 758                                                         NAN
# 763                                                         NAN
# 766                                                         NAN
# 928           T.C.A 57-4-203(B)(1)(A): ANY LICENSEE OR OTHER...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 2
# 4
# 5
# 6
# 10
# 11
# 40
# 48
# 60
# 70
# 76
# 98
# 99
# 107
# 117
# 118
# 128
# 137
# 145
# 153
# 154
# 155
# 174
# 191
# 192
# 199
# 210
# 212
# 213
# 214
# ...                         ...
# 427
# 428
# 431
# 440
# 447
# 470
# 476
# 482
# 504
# 511
# 546
# 549
# 550
# 552
# 560
# 561
# 565
# 570
# 573
# 575
# 599
# 600
# 661
# 749
# 753
# 754
# 758
# 763
# 766
# 928
#
# [76 rows x 4 columns]

# %% [markdown]
# ##### Here are the unique categories assigned so far...

# %%
set(codes_df['VIOLATION_CATEGORY'])
# Out:
# {'',
#  'ALCOHOL -- OTHER',
#  'ALCOHOL -- PERMITS',
#  'ANIMALS/VERMIN',
#  'ELECTRICAL',
#  'EXTBLD',
#  'FENCING',
#  'FIRE',
#  'INTBLD',
#  'LANDSCAPE',
#  'OCCUPANCY',
#  'PLUMBING',
#  'SALES',
#  'SHORT_TERM_RENTAL',
#  'SIGNAGE',
#  'VEHICLE',
#  'WASTE'}

# %%
codes_df[codes_df['VIOLATION_CATEGORY'] == '']
# Out:
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 2                       BGMATOWNER            PROPER MAINTENANCE REQ - OWNER
# 4                        BLDGMAINT                    PROPER MAINTENANCE REQ
# 5                       BLDGPERMIT                  BUILDING PERMIT REQUIRED
# 6                        BLDGSCOPE                    SCOPE OF BUILDING CODE
# 10                        CERTCOMP        CERTIFICATE OF COMPLIANCE REQUIRED
# 11                         CERTOCC         CERTIFICATE OF OCCUPANCY REQUIRED
# 40                         EXTEXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 48                         EXTGRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 60                       EXTREPAIR                 EXTERIOR REPAIR – GENERAL
# 70                         EXTSWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 76                      EXTWINDDRF   EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES
# 98                         HOMEOCC         HOME OCCUPATION – PERMIT REQUIRED
# 99                      HOMEOCCCON              HOME OCCUPATION – CONDITIONS
# 107                        LANDREG            LANDLORD REGISTRATION REQUIRED
# 117                      LITNOTICE                POSTING NOTICES PROHIBITED
# 118                         LITPRO          PROPER PLACEMENT IN RECEPTACLES
# 128                          NOISE           CONTINUOUS & INTERMITTENT NOISE
# 137                     OCCUPRMWID           OCCUPANCY – MINIMUM ROOM WIDTHS
# 145                      PERMITREQ       BUILDING AND ZONING PERMIT REQUIRED
# 153                       QUARHOLE                 NUISANCE DECLARED - HOLES
# 154                      RESPMAINT   FAILURE TO MAINTAIN BLDGS OR STRUCTURES
# 155                     RESUESECRS                        SECURITY RESIDENCE
# 174                         SIGH25           SIGNS – GREATER THAN 25 PERCENT
# 191                       STOPWORK                    STOP WORK ORDER POSTED
# 192                      TEMPEXPIR                     TEMPORARY U&O EXPIRED
# 199                     USENOTPERM                         USE NOT PERMITTED
# 210                      SWVIOLPTP  VIOLATIONS - POST CONSTRUCTION TREATMENT
# 212                       SWVIOLWQ      VIOLATIONS FOR WATER QUALITY IMPACTS
# 213                       SWENVCRT           ENVIRONMENTAL COURT PROCEEDINGS
# 214                       SWVIOLGP  VIOLATIONS - FOR CONSTRUCTION ACTIVITIES
# ...                            ...                                       ...
# 427                CAAH_BLDG_MAINT                    PROPER MAINTENANCE REQ
# 428                CAAH_BLDG_SCOPE                    SCOPE OF BUILDING CODE
# 431                  CAAH_CERT_OCC         CERTIFICATE OF OCCUPANCY REQUIRED
# 440                  CAAH_EXT_EXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 447                  CAAH_EXT_GRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 470                  CAAH_EXT_SWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 476               CAAH_EXT_WINDDRF   EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES
# 482           CAAH_EXTERIOR_REPAIR                 EXTERIOR REPAIR – GENERAL
# 504               CAAH_OCCUP_RMWID           OCCUPANCY – MINIMUM ROOM WIDTHS
# 511                CAAH_RESP_MAINT   FAILURE TO MAINTAIN BLDGS OR STRUCTURES
# 546                  CAAR_LAND_REG            LANDLORD REGISTRATION REQUIRED
# 549                 CAAZ_CERT_COMP        CERTIFICATE OF COMPLIANCE REQUIRED
# 550               CAAZ_CERT_COMPLY                CERTIFICATE COMPLIANCE REQ
# 552                CAAZ_COMVEH_RES   COMMERCIAL VEHICLE RESIDENTIAL DISTRICT
# 560                  CAAZ_HOME_OCC              HOME OCCUPATION – CONDITIONS
# 561                   CAAZ_HOMEOCC         HOME OCCUPATION – PERMIT REQUIRED
# 565                     CAAZ_NOISE           CONTINUOUS & INTERMITTENT NOISE
# 570            CAAZ_PERMIT_BLD_REQ       BUILDING AND ZONING PERMIT REQUIRED
# 573            CAAZ_PERMIT_USE_REQ     FAILURE TO OBTAIN REQUIRED USE PERMIT
# 575              CAAZ_REUSE_SECRES                        SECURITY RESIDENCE
# 599            CAAZ_USE_NOT_PERMIT                         USE NOT PERMITTED
# 600           CAAZT_FULL_COMPLANCE                 CERTIFICATE OF COMPLIANCE
# 661           CALL_LANDLORD_REGSTR                     LANDLORD REGISTRATION
# 749                         CAST45                                 YARD AREA
# 753                         CAST51               REMOVE COMBUSTIBLE MATERIAL
# 754                         CAST52                         FAILURE TO REPAIR
# 758                      HD1032140    ACCUMUALTION OF LUMBER, BOXES, BARRELS
# 763                     HD10360204                        CLEAN AMINAL AREAS
# 766                      HD1624110                           FAULTY PLUMBING
# 928                    BT574203B1A                            FAILURE TO PAY
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 2             SECTION 16.16.030 (B) - PROPER MAINTENANCE REQ...
# 4             SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 5             SECTION 16.28.010 - BUILDING PERMIT REQUIRED: ...
# 6             SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 10            SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 11            SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
# 40            SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 48            SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 60            SECTION 16.24.340 – EXTERIOR REPAIR: THE EXTER...
# 70            SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 76            SECTION 16.24.340 (M) – WINDOW, SKYLIGHT AND D...
# 98            SECTION 17.16.250 (C) - HOME OCCUPATION (PERMI...
# 99            SECTION 17.16.250 (C) - HOME OCCUPATION (CONDI...
# 107           TENNESSEE CODE ANNOTATED (TCA) 66-28-101 - FAI...
# 117           SECTION 10.24.020 - POSTING NOTICES PROHIBITED...
# 118           SECTION 10.24.110 - PROPER PLACEMENT IN RECEPT...
# 128           SECTION 17.28.090 (C) - NOISE LEVELS: SOUND LE...
# 137           SECTION 16.34.400 (B) - OCCUPANCY (MINIMUM ROO...
# 145           SECTION 17.40.520 - ZONING PERMIT REQUIRED: AN...
# 153           SECTION 10.52.020 - NUISANCE DECLARED WHEN: HO...
# 154           SECTION 16.24.310 – RESPONSIBILITY: THE OWNER ...
# 155           SECTION 17.16.030 (C) - SECURITY RESIDENCE: RE...
# 174           SECTION 17.32.040 (M) – TEMPORARY SIGNS AND DI...
# 191           SECTION 16.04.110 – VIOLATION OF STOP WORK ORD...
# 192           SECTION 17.04.100 – NO USE AND OCCUPANCY ISSUE...
# 199           SECTION 17.08.030 – USE NOT PERMITTED: THE USE...
# 210                                                 SEE SW CODE
# 212                                                 SEE SW CODE
# 213                                                 SEE SW CODE
# 214                                                 SEE SW CODE
# ...                                                         ...
# 427           SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 428           SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 431           SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
# 440           SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 447           SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 470           SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 476           SECTION 16.24.340 (M) – WINDOW, SKYLIGHT AND D...
# 482           SECTION 16.24.340 – EXTERIOR REPAIR: THE EXTER...
# 504           SECTION 16.34.400 (B) - OCCUPANCY (MINIMUM ROO...
# 511           SECTION 16.24.310 – RESPONSIBILITY: THE OWNER ...
# 546           TENNESSEE CODE ANNOTATED (TCA) 66-28-101 - FAI...
# 549           SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 550           FOLLOWING ISSUANCE OF A ZONING PERMIT, NO STRU...
# 552           SECTION 17.08.030 - USE NOT PERMITTED: THE OPE...
# 560           SECTION 17.16.250 (C) - HOME OCCUPATION (CONDI...
# 561           SECTION 17.16.250  (C) - HOME OCCUPATION (PERM...
# 565           SECTION 17.28.090 (C) - NOISE LEVELS: SOUND LE...
# 570           SECTION 17.40.520 - ZONING PERMIT REQUIRED: AN...
# 573           SECTION 17.40.520 - AN APPLICATION FOR A ZONIN...
# 575           SECTION 17.16.030 (C) - SECURITY RESIDENCE: RE...
# 599           SECTION 17.08.030 – USE NOT PERMITTED: THE USE...
# 600           SECTION 17.40.580 - FOLLOWING ISSUANCE OF A ZO...
# 661           FAILURE TO REGISTER AS A LANDLORD.  T.C.A. 66-...
# 749                                                         NAN
# 753           -REMOVE ALL COMBUSTIBLE MATERIALS -WITHIN TEN ...
# 754           THE OWNER, PARTY IN INTEREST, LESSEE, AGENT, O...
# 758                                                         NAN
# 763                                                         NAN
# 766                                                         NAN
# 928           T.C.A 57-4-203(B)(1)(A): ANY LICENSEE OR OTHER...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 2
# 4
# 5
# 6
# 10
# 11
# 40
# 48
# 60
# 70
# 76
# 98
# 99
# 107
# 117
# 118
# 128
# 137
# 145
# 153
# 154
# 155
# 174
# 191
# 192
# 199
# 210
# 212
# 213
# 214
# ...                         ...
# 427
# 428
# 431
# 440
# 447
# 470
# 476
# 482
# 504
# 511
# 546
# 549
# 550
# 552
# 560
# 561
# 565
# 570
# 573
# 575
# 599
# 600
# 661
# 749
# 753
# 754
# 758
# 763
# 766
# 928
#
# [76 rows x 4 columns]

# %% [markdown]
# ##### * I'm tired, so everything else gets 'OTHER/MISC'

# %%
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == ''
             , 'VIOLATION_CATEGORY'] = 'OTHER/MISC'
codes_df.loc[codes_df['VIOLATION_CATEGORY'] == 'OTHER/MISC']
# Out:
#                     VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 2                       BGMATOWNER            PROPER MAINTENANCE REQ - OWNER
# 4                        BLDGMAINT                    PROPER MAINTENANCE REQ
# 5                       BLDGPERMIT                  BUILDING PERMIT REQUIRED
# 6                        BLDGSCOPE                    SCOPE OF BUILDING CODE
# 10                        CERTCOMP        CERTIFICATE OF COMPLIANCE REQUIRED
# 11                         CERTOCC         CERTIFICATE OF OCCUPANCY REQUIRED
# 40                         EXTEXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 48                         EXTGRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 60                       EXTREPAIR                 EXTERIOR REPAIR – GENERAL
# 70                         EXTSWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 76                      EXTWINDDRF   EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES
# 98                         HOMEOCC         HOME OCCUPATION – PERMIT REQUIRED
# 99                      HOMEOCCCON              HOME OCCUPATION – CONDITIONS
# 107                        LANDREG            LANDLORD REGISTRATION REQUIRED
# 117                      LITNOTICE                POSTING NOTICES PROHIBITED
# 118                         LITPRO          PROPER PLACEMENT IN RECEPTACLES
# 128                          NOISE           CONTINUOUS & INTERMITTENT NOISE
# 137                     OCCUPRMWID           OCCUPANCY – MINIMUM ROOM WIDTHS
# 145                      PERMITREQ       BUILDING AND ZONING PERMIT REQUIRED
# 153                       QUARHOLE                 NUISANCE DECLARED - HOLES
# 154                      RESPMAINT   FAILURE TO MAINTAIN BLDGS OR STRUCTURES
# 155                     RESUESECRS                        SECURITY RESIDENCE
# 174                         SIGH25           SIGNS – GREATER THAN 25 PERCENT
# 191                       STOPWORK                    STOP WORK ORDER POSTED
# 192                      TEMPEXPIR                     TEMPORARY U&O EXPIRED
# 199                     USENOTPERM                         USE NOT PERMITTED
# 210                      SWVIOLPTP  VIOLATIONS - POST CONSTRUCTION TREATMENT
# 212                       SWVIOLWQ      VIOLATIONS FOR WATER QUALITY IMPACTS
# 213                       SWENVCRT           ENVIRONMENTAL COURT PROCEEDINGS
# 214                       SWVIOLGP  VIOLATIONS - FOR CONSTRUCTION ACTIVITIES
# ...                            ...                                       ...
# 427                CAAH_BLDG_MAINT                    PROPER MAINTENANCE REQ
# 428                CAAH_BLDG_SCOPE                    SCOPE OF BUILDING CODE
# 431                  CAAH_CERT_OCC         CERTIFICATE OF OCCUPANCY REQUIRED
# 440                  CAAH_EXT_EXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 447                  CAAH_EXT_GRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 470                  CAAH_EXT_SWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 476               CAAH_EXT_WINDDRF   EXT OF BLDGS – WIND, SKYLIT DOOR FRAMES
# 482           CAAH_EXTERIOR_REPAIR                 EXTERIOR REPAIR – GENERAL
# 504               CAAH_OCCUP_RMWID           OCCUPANCY – MINIMUM ROOM WIDTHS
# 511                CAAH_RESP_MAINT   FAILURE TO MAINTAIN BLDGS OR STRUCTURES
# 546                  CAAR_LAND_REG            LANDLORD REGISTRATION REQUIRED
# 549                 CAAZ_CERT_COMP        CERTIFICATE OF COMPLIANCE REQUIRED
# 550               CAAZ_CERT_COMPLY                CERTIFICATE COMPLIANCE REQ
# 552                CAAZ_COMVEH_RES   COMMERCIAL VEHICLE RESIDENTIAL DISTRICT
# 560                  CAAZ_HOME_OCC              HOME OCCUPATION – CONDITIONS
# 561                   CAAZ_HOMEOCC         HOME OCCUPATION – PERMIT REQUIRED
# 565                     CAAZ_NOISE           CONTINUOUS & INTERMITTENT NOISE
# 570            CAAZ_PERMIT_BLD_REQ       BUILDING AND ZONING PERMIT REQUIRED
# 573            CAAZ_PERMIT_USE_REQ     FAILURE TO OBTAIN REQUIRED USE PERMIT
# 575              CAAZ_REUSE_SECRES                        SECURITY RESIDENCE
# 599            CAAZ_USE_NOT_PERMIT                         USE NOT PERMITTED
# 600           CAAZT_FULL_COMPLANCE                 CERTIFICATE OF COMPLIANCE
# 661           CALL_LANDLORD_REGSTR                     LANDLORD REGISTRATION
# 749                         CAST45                                 YARD AREA
# 753                         CAST51               REMOVE COMBUSTIBLE MATERIAL
# 754                         CAST52                         FAILURE TO REPAIR
# 758                      HD1032140    ACCUMUALTION OF LUMBER, BOXES, BARRELS
# 763                     HD10360204                        CLEAN AMINAL AREAS
# 766                      HD1624110                           FAULTY PLUMBING
# 928                    BT574203B1A                            FAILURE TO PAY
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 2             SECTION 16.16.030 (B) - PROPER MAINTENANCE REQ...
# 4             SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 5             SECTION 16.28.010 - BUILDING PERMIT REQUIRED: ...
# 6             SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 10            SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 11            SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
# 40            SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 48            SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 60            SECTION 16.24.340 – EXTERIOR REPAIR: THE EXTER...
# 70            SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 76            SECTION 16.24.340 (M) – WINDOW, SKYLIGHT AND D...
# 98            SECTION 17.16.250 (C) - HOME OCCUPATION (PERMI...
# 99            SECTION 17.16.250 (C) - HOME OCCUPATION (CONDI...
# 107           TENNESSEE CODE ANNOTATED (TCA) 66-28-101 - FAI...
# 117           SECTION 10.24.020 - POSTING NOTICES PROHIBITED...
# 118           SECTION 10.24.110 - PROPER PLACEMENT IN RECEPT...
# 128           SECTION 17.28.090 (C) - NOISE LEVELS: SOUND LE...
# 137           SECTION 16.34.400 (B) - OCCUPANCY (MINIMUM ROO...
# 145           SECTION 17.40.520 - ZONING PERMIT REQUIRED: AN...
# 153           SECTION 10.52.020 - NUISANCE DECLARED WHEN: HO...
# 154           SECTION 16.24.310 – RESPONSIBILITY: THE OWNER ...
# 155           SECTION 17.16.030 (C) - SECURITY RESIDENCE: RE...
# 174           SECTION 17.32.040 (M) – TEMPORARY SIGNS AND DI...
# 191           SECTION 16.04.110 – VIOLATION OF STOP WORK ORD...
# 192           SECTION 17.04.100 – NO USE AND OCCUPANCY ISSUE...
# 199           SECTION 17.08.030 – USE NOT PERMITTED: THE USE...
# 210                                                 SEE SW CODE
# 212                                                 SEE SW CODE
# 213                                                 SEE SW CODE
# 214                                                 SEE SW CODE
# ...                                                         ...
# 427           SECTION 16.16.030 (A) - PROPER MAINTENANCE REQ...
# 428           SECTION 16.16.020 (B) - THE PROVISIONS OF THIS...
# 431           SECTION 16.24.130 – CERTIFICATE OF OCCUPANCY R...
# 440           SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 447           SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 470           SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 476           SECTION 16.24.340 (M) – WINDOW, SKYLIGHT AND D...
# 482           SECTION 16.24.340 – EXTERIOR REPAIR: THE EXTER...
# 504           SECTION 16.34.400 (B) - OCCUPANCY (MINIMUM ROO...
# 511           SECTION 16.24.310 – RESPONSIBILITY: THE OWNER ...
# 546           TENNESSEE CODE ANNOTATED (TCA) 66-28-101 - FAI...
# 549           SECTION 17.40.580 - CERTIFICATE OF COMPLIANCE:...
# 550           FOLLOWING ISSUANCE OF A ZONING PERMIT, NO STRU...
# 552           SECTION 17.08.030 - USE NOT PERMITTED: THE OPE...
# 560           SECTION 17.16.250 (C) - HOME OCCUPATION (CONDI...
# 561           SECTION 17.16.250  (C) - HOME OCCUPATION (PERM...
# 565           SECTION 17.28.090 (C) - NOISE LEVELS: SOUND LE...
# 570           SECTION 17.40.520 - ZONING PERMIT REQUIRED: AN...
# 573           SECTION 17.40.520 - AN APPLICATION FOR A ZONIN...
# 575           SECTION 17.16.030 (C) - SECURITY RESIDENCE: RE...
# 599           SECTION 17.08.030 – USE NOT PERMITTED: THE USE...
# 600           SECTION 17.40.580 - FOLLOWING ISSUANCE OF A ZO...
# 661           FAILURE TO REGISTER AS A LANDLORD.  T.C.A. 66-...
# 749                                                         NAN
# 753           -REMOVE ALL COMBUSTIBLE MATERIALS -WITHIN TEN ...
# 754           THE OWNER, PARTY IN INTEREST, LESSEE, AGENT, O...
# 758                                                         NAN
# 763                                                         NAN
# 766                                                         NAN
# 928           T.C.A 57-4-203(B)(1)(A): ANY LICENSEE OR OTHER...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 2                    OTHER/MISC
# 4                    OTHER/MISC
# 5                    OTHER/MISC
# 6                    OTHER/MISC
# 10                   OTHER/MISC
# 11                   OTHER/MISC
# 40                   OTHER/MISC
# 48                   OTHER/MISC
# 60                   OTHER/MISC
# 70                   OTHER/MISC
# 76                   OTHER/MISC
# 98                   OTHER/MISC
# 99                   OTHER/MISC
# 107                  OTHER/MISC
# 117                  OTHER/MISC
# 118                  OTHER/MISC
# 128                  OTHER/MISC
# 137                  OTHER/MISC
# 145                  OTHER/MISC
# 153                  OTHER/MISC
# 154                  OTHER/MISC
# 155                  OTHER/MISC
# 174                  OTHER/MISC
# 191                  OTHER/MISC
# 192                  OTHER/MISC
# 199                  OTHER/MISC
# 210                  OTHER/MISC
# 212                  OTHER/MISC
# 213                  OTHER/MISC
# 214                  OTHER/MISC
# ...                         ...
# 427                  OTHER/MISC
# 428                  OTHER/MISC
# 431                  OTHER/MISC
# 440                  OTHER/MISC
# 447                  OTHER/MISC
# 470                  OTHER/MISC
# 476                  OTHER/MISC
# 482                  OTHER/MISC
# 504                  OTHER/MISC
# 511                  OTHER/MISC
# 546                  OTHER/MISC
# 549                  OTHER/MISC
# 550                  OTHER/MISC
# 552                  OTHER/MISC
# 560                  OTHER/MISC
# 561                  OTHER/MISC
# 565                  OTHER/MISC
# 570                  OTHER/MISC
# 573                  OTHER/MISC
# 575                  OTHER/MISC
# 599                  OTHER/MISC
# 600                  OTHER/MISC
# 661                  OTHER/MISC
# 749                  OTHER/MISC
# 753                  OTHER/MISC
# 754                  OTHER/MISC
# 758                  OTHER/MISC
# 763                  OTHER/MISC
# 766                  OTHER/MISC
# 928                  OTHER/MISC
#
# [76 rows x 4 columns]

# %%
codes_df.groupby('VIOLATION_CATEGORY').size()
# Out:
# VIOLATION_CATEGORY
# ALCOHOL -- OTHER      153
# ALCOHOL -- PERMITS     28
# ANIMALS/VERMIN         20
# ELECTRICAL             39
# EXTBLD                 77
# FENCING                24
# FIRE                   19
# INTBLD                 65
# LANDSCAPE              11
# OCCUPANCY              31
# OTHER/MISC             76
# PLUMBING               81
# SALES                  10
# SHORT_TERM_RENTAL      10
# SIGNAGE                41
# VEHICLE                27
# WASTE                  76
# dtype: int64

# %% [markdown]
# #### Spot check

# %%
codes_df.loc[codes_df['VIOLATION_DESC'].str.contains('EXTERIOR PROP')]
# Out:
#                  VIOLATION_TYPE                            VIOLATION_DESC  \
# VIOLATION_ID
# 25                       EXPARK   EXTERIOR PROP AREA – VEHICLES – PARKING
# 26                       EXTACC     EXTERIOR PROP AREA – ACCES STRUCTURES
# 32                     EXTDENBW  EXTERIOR PROP AREA – FENCES  BARBED WIRE
# 40                      EXTEXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 43                   EXTFENMAIN  EXTERIOR PROP AREA – FENCE MATERIAL MAIN
# 44                    EXTFENMAT    EXTERIOR PROP AREA – FENCING MATERIALS
# 45                      EXTGATE                EXTERIOR PROP AREA – GATES
# 48                      EXTGRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 56                     EXTPRKAR   EXTERIOR PROP AREA – DESIGNATED PARKING
# 61                       EXTROD     EXTERIOR PROP AREA – RODENT HARBORAGE
# 64                       EXTSAN           EXTERIOR PROP AREA – SANITATION
# 67                     EXTSDWLK            EXTERIOR PROP AREA – SIDEWALKS
# 70                      EXTSWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 71                      EXTTRLS  EXTERIOR PROP AREA – TRAILERS WATERCRAFT
# 72                    EXTVEHCON      EXTERIOR PROP AREA – VEH – INOP/UNLC
# 73                     EXTVEHPT     EXTERIOR PROP AREA – VEHICLE PAINTING
# 74                     EXTVEHRP     EXTERIOR PROP AREA – VEH – DIS/REPAIR
# 75                      EXTWEED           EXTERIOR PROP AREA – HIGH WEEDS
# 140                     OPNSTOR   EXTERIOR PROP AREA – OPEN STORAGE - ALL
# 141                      OPSTDB   EXTERIOR PROP AREA – OPEN STOR – DEBRIS
# 142                     OPSTJTD   EXTERIOR PROP AREA – OPEN STORAGE – JTD
# 143                     OPSTVEH   EXTERIOR PROP AREA – OPEN STORAGE - VEH
# 432               CAAH_EX_FENBW  EXTERIOR PROP AREA – FENCES  BARBED WIRE
# 433                CAAH_EXT_ACC     EXTERIOR PROP AREA – ACCES STRUCTURES
# 440               CAAH_EXT_EXAH        EXTERIOR PROP AREA – EXHAUST VENTS
# 443           CAAH_EXT_FENMAINT  EXTERIOR PROP AREA – FENCE MATERIAL MAIN
# 444             CAAH_EXT_FENMAT    EXTERIOR PROP AREA – FENCING MATERIALS
# 445               CAAH_EXT_GATE                EXTERIOR PROP AREA – GATES
# 447               CAAH_EXT_GRAD     EXTERIOR PROP AREA – GRADING REQUIRED
# 454               CAAH_EXT_PARK   EXTERIOR PROP AREA – VEHICLES – PARKING
# 459              CAAH_EXT_PRKAR   EXTERIOR PROP AREA – DESIGNATED PARKING
# 463                CAAH_EXT_ROD     EXTERIOR PROP AREA – RODENT HARBORAGE
# 466                CAAH_EXT_SAN           EXTERIOR PROP AREA – SANITATION
# 467              CAAH_EXT_SDWLK            EXTERIOR PROP AREA – SIDEWALKS
# 470               CAAH_EXT_SWIM       EXTERIOR PROP AREA – SWIMMING POOLS
# 471               CAAH_EXT_TRLS  EXTERIOR PROP AREA – TRAILERS WATERCRAFT
# 472             CAAH_EXT_VEHCON      EXTERIOR PROP AREA – VEH – INOP/UNLC
# 473              CAAH_EXT_VEHPT     EXTERIOR PROP AREA – VEHICLE PAINTING
# 474              CAAH_EXT_VEHRP     EXTERIOR PROP AREA – VEH – DIS/REPAIR
# 475               CAAH_EXT_WEED           EXTERIOR PROP AREA – HIGH WEEDS
# 507               CAAH_OPN_STOR   EXTERIOR PROP AREA – OPEN STORAGE - ALL
# 508               CAAH_OPST_DEB   EXTERIOR PROP AREA – OPEN STOR – DEBRIS
# 509               CAAH_OPST_JTD   EXTERIOR PROP AREA – OPEN STORAGE – JTD
# 510               CAAH_OPST_VEH   EXTERIOR PROP AREA – OPEN STORAGE - VEH
#
#                                                  VIOLATION_TEXT  \
# VIOLATION_ID
# 25            SECTION 16.24.330 (K)(3) – MOTOR VEHICLES (PAR...
# 26            SECTION 16.24.330 (H) – ACCESSORY STRUCTURES: ...
# 32            SECTION 16.24.330 (O) – FENCES (BARBED WIRE): ...
# 40            SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 43            SECTION 16.24.330 (M) – FENCE MAINTENANCE: MET...
# 44            SECTION 16.24.330 (L) – FENCING MATERIALS: FEN...
# 45            SECTION 16.24.330 (I) – GATES: GATES WHICH ARE...
# 48            SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 56            SECTION 16.24.330 (K)(3) – VEHICLE PARKING ARE...
# 61            SECTION 16.24.330 (F) – RODENT HARBORAGE: ALL ...
# 64            SECTION 16.24.330 (A) – SANITATION: ALL EXTERI...
# 67            SECTION 16.24.330 (D) – SIDEWALKS AND DRIVEWAY...
# 70            SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 71            SECTION 16.24.330 (P) – TRAILERS AND WATERCRAF...
# 72            SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (CON...
# 73            SECTION 16.24.330 (K)(4) – VEHICLE PAINTING: P...
# 74            SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (REP...
# 75            SECTION 16.24.330 (E) – HIGH WEEDS: ALL PREMIS...
# 140           SECTION 16.24.330 (B) – OPEN STORAGE: IT IS UN...
# 141           SECTION 16.24.330 (B) – OPEN STORAGE (DEBRIS):...
# 142           SECTION 16.24.330 (B) – OPEN STORAGE (JUNK, TR...
# 143           SECTION 16.24.330 (B) – OPEN STORAGE (VEHICLES...
# 432           SECTION 16.24.330 (O) – FENCES (BARBED WIRE): ...
# 433           SECTION 16.24.330 (H) – ACCESSORY STRUCTURES: ...
# 440           SECTION 16.24.330 (G) – EXHAUST VENTS: EXHAUST...
# 443           SECTION 16.24.330 (M) – FENCE MAINTENANCE: MET...
# 444           SECTION 16.24.330 (L) – FENCING MATERIALS: FEN...
# 445           SECTION 16.24.330 (I) – GATES: GATES WHICH ARE...
# 447           SECTION 16.24.330 (C) – GRADING REQUIRED: ALL ...
# 454           SECTION 16.24.330 (K)(3) – MOTOR VEHICLES (PAR...
# 459           SECTION 16.24.330 (K)(3) – VEHICLE PARKING ARE...
# 463           SECTION 16.24.330 (F) – RODENT HARBORAGE: ALL ...
# 466           SECTION 16.24.330 (A) – SANITATION: ALL EXTERI...
# 467           SECTION 16.24.330 (D) – SIDEWALKS AND DRIVEWAY...
# 470           SECTION 16.24.330 (J) – SWIMMING POOLS: SWIMMI...
# 471           SECTION 16.24.330 (P) – TRAILERS AND WATERCRAF...
# 472           SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (CON...
# 473           SECTION 16.24.330 (K)(4) – VEHICLE PAINTING: P...
# 474           SECTION 16.24.330 (K)(1) – MOTOR VEHICLES (REP...
# 475           SECTION 16.24.330 (E) – HIGH WEEDS: ALL PREMIS...
# 507           SECTION 16.24.330 (B) – OPEN STORAGE: IT IS UN...
# 508           SECTION 16.24.330 (B) – OPEN STORAGE (DEBRIS):...
# 509           SECTION 16.24.330 (B) – OPEN STORAGE (JUNK, TR...
# 510           SECTION 16.24.330 (B) – OPEN STORAGE (VEHICLES...
#
#              VIOLATION_CATEGORY
# VIOLATION_ID
# 25                      VEHICLE
# 26                      FENCING
# 32                      FENCING
# 40                   OTHER/MISC
# 43                      FENCING
# 44                      FENCING
# 45                      FENCING
# 48                   OTHER/MISC
# 56                      VEHICLE
# 61               ANIMALS/VERMIN
# 64                        WASTE
# 67                      VEHICLE
# 70                   OTHER/MISC
# 71                      VEHICLE
# 72                      VEHICLE
# 73                      VEHICLE
# 74                      VEHICLE
# 75                    LANDSCAPE
# 140                       WASTE
# 141                       WASTE
# 142                       WASTE
# 143                       WASTE
# 432                     FENCING
# 433                     FENCING
# 440                  OTHER/MISC
# 443                     FENCING
# 444                     FENCING
# 445                     FENCING
# 447                  OTHER/MISC
# 454                     VEHICLE
# 459                     VEHICLE
# 463              ANIMALS/VERMIN
# 466                       WASTE
# 467                     VEHICLE
# 470                  OTHER/MISC
# 471                     VEHICLE
# 472                     VEHICLE
# 473                     VEHICLE
# 474                     VEHICLE
# 475                   LANDSCAPE
# 507                       WASTE
# 508                       WASTE
# 509                       WASTE
# 510                       WASTE

# %% [markdown]
# #### Time to work on predicting, using CountVectorizer...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# named my labels
y = codes_df.VIOLATION_CATEGORY

# built training/testing sets
X_train, X_test, y_train, y_test = train_test_split(codes_df['VIOLATION_DESC'], y, test_size=0.33, random_state=53)

# create word count vectors with stop words stripped out
count_vectorizer = CountVectorizer(stop_words='english')

# fit/transform the training rows
count_train = count_vectorizer.fit_transform(X_train.values)

# transform the test rows
count_test = count_vectorizer.transform(X_test)

# Create Naïve Bayes model
nb_classifier = MultinomialNB(alpha=0.1)

nb_classifier.fit(count_train, y_train)

# Run the model on the test data
pred = nb_classifier.predict(count_test)

# Calculate the accuracy score
score = metrics.accuracy_score(y_test, pred)
print('Accuracy Score: ' + str(score))

# Create confusion matrix
labels = pd.Series(codes_df.VIOLATION_CATEGORY.unique())
cm = metrics.confusion_matrix(y_test, pred, labels=labels)
pd.DataFrame(cm, index=labels, columns=labels)
# Out:
# Accuracy Score: 0.819923371648
#                     SIGNAGE  OTHER/MISC  OCCUPANCY  VEHICLE  ANIMALS/VERMIN  \
# SIGNAGE                  16           1          0        0               0
# OTHER/MISC                0          22          0        1               0
# OCCUPANCY                 0           0          6        0               0
# VEHICLE                   0           0          0        8               0
# ANIMALS/VERMIN            0           0          0        0               2
# SALES                     0           0          0        0               0
# WASTE                     0           0          0        0               0
# ELECTRICAL                0           0          0        0               0
# FENCING                   0           2          0        0               0
# EXTBLD                    1           0          0        0               0
# LANDSCAPE                 0           0          0        0               0
# FIRE                      0           0          0        0               0
# INTBLD                    0           1          0        0               0
# PLUMBING                  0           0          0        0               0
# SHORT_TERM_RENTAL         0           1          1        0               0
# ALCOHOL -- PERMITS        0           1          0        0               0
# ALCOHOL -- OTHER          2           2          0        0               0
#
#                     SALES  WASTE  ELECTRICAL  FENCING  EXTBLD  LANDSCAPE  \
# SIGNAGE                 0      0           0        0       0          0
# OTHER/MISC              0      2           0        0       3          0
# OCCUPANCY               0      0           0        0       1          0
# VEHICLE                 0      0           0        0       0          0
# ANIMALS/VERMIN          0      0           0        0       0          0
# SALES                   4      0           0        0       0          0
# WASTE                   0     23           0        0       0          0
# ELECTRICAL              0      0          10        0       0          0
# FENCING                 0      0           0        5       0          0
# EXTBLD                  0      0           0        0      21          0
# LANDSCAPE               0      0           0        0       0          1
# FIRE                    0      0           0        0       0          0
# INTBLD                  0      1           2        0       2          0
# PLUMBING                0      0           0        0       0          0
# SHORT_TERM_RENTAL       0      1           0        0       0          0
# ALCOHOL -- PERMITS      0      0           0        0       0          0
# ALCOHOL -- OTHER        0      1           1        0       1          0
#
#                     FIRE  INTBLD  PLUMBING  SHORT_TERM_RENTAL  \
# SIGNAGE                0       0         0                  0
# OTHER/MISC             0       1         1                  0
# OCCUPANCY              0       0         0                  0
# VEHICLE                0       0         0                  0
# ANIMALS/VERMIN         0       0         0                  0
# SALES                  0       0         0                  0
# WASTE                  0       0         0                  0
# ELECTRICAL             0       0         0                  0
# FENCING                0       0         0                  0
# EXTBLD                 0       0         1                  0
# LANDSCAPE              1       0         0                  0
# FIRE                   3       0         0                  0
# INTBLD                 1      12         1                  0
# PLUMBING               0       1        33                  0
# SHORT_TERM_RENTAL      0       0         0                  0
# ALCOHOL -- PERMITS     0       0         0                  0
# ALCOHOL -- OTHER       0       0         1                  0
#
#                     ALCOHOL -- PERMITS  ALCOHOL -- OTHER
# SIGNAGE                              0                 0
# OTHER/MISC                           0                 0
# OCCUPANCY                            0                 0
# VEHICLE                              0                 0
# ANIMALS/VERMIN                       0                 1
# SALES                                0                 0
# WASTE                                0                 0
# ELECTRICAL                           0                 0
# FENCING                              0                 0
# EXTBLD                               0                 0
# LANDSCAPE                            0                 0
# FIRE                                 0                 1
# INTBLD                               0                 1
# PLUMBING                             0                 0
# SHORT_TERM_RENTAL                    1                 0
# ALCOHOL -- PERMITS                   6                 1
# ALCOHOL -- OTHER                     6                42

# %%
print(classification_report(y_test, pred))
# Out:
#                     precision    recall  f1-score   support
#
#   ALCOHOL -- OTHER       0.91      0.75      0.82        56
# ALCOHOL -- PERMITS       0.46      0.75      0.57         8
#     ANIMALS/VERMIN       1.00      0.67      0.80         3
#         ELECTRICAL       0.77      1.00      0.87        10
#             EXTBLD       0.75      0.91      0.82        23
#            FENCING       1.00      0.71      0.83         7
#               FIRE       0.60      0.75      0.67         4
#             INTBLD       0.86      0.57      0.69        21
#          LANDSCAPE       1.00      0.50      0.67         2
#          OCCUPANCY       0.86      0.86      0.86         7
#         OTHER/MISC       0.73      0.73      0.73        30
#           PLUMBING       0.89      0.97      0.93        34
#              SALES       1.00      1.00      1.00         4
#  SHORT_TERM_RENTAL       0.00      0.00      0.00         4
#            SIGNAGE       0.84      0.94      0.89        17
#            VEHICLE       0.89      1.00      0.94         8
#              WASTE       0.82      1.00      0.90        23
#
#        avg / total       0.82      0.82      0.81       261
# /Users/paulomartinez/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Not the greatest when it comes to alcohol permits, fire, or short-term rental, but otherwise not terrible

# %% [markdown]
# #### Pull in violations data:

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/Nashville')
con = engine.connect()
tablenames = engine.table_names()
print(tablenames)
rs = con.execute("select * from property_standards_violations")
data = rs.fetchall()
viol_df = pd.DataFrame(data)

viol_df.columns = rs.keys()

con.close()
# Out:
# ['violation_codes', 'property_standards_violations']

# %% [markdown]
# #### Convert 'violations_noted' to uppercase and drop those records with no violations

# %%
viol_df['violations_noted'] = viol_df['violations_noted'].str.upper()
viol_df['violation_category'] = ''
viol_df = viol_df.dropna(subset=['violations_noted'])

# %% [markdown]
# #### Run the data through the model to get the categories assigned to the violations dataset

# %%
categories_test = viol_df

# Set up "violations_noted" as label to test
X_test = categories_test['violations_noted']

# Transform
count_test = count_vectorizer.transform(X_test)

# Make predictions
pred = nb_classifier.predict(count_test)

# Create the probability arrays for each prediction (i.e., a 2D array whose rows contain the 
# probabilities of a noted violation being each possible category -- .predict chooses based on the highest one)
pred_prob = nb_classifier.predict_proba(count_test)

# Set a threshold for selecting a category and convert everything below threshold to 0, everything above to 1
select_matrix = binarize(pred_prob, threshold=0.75)

# Add all the elements in each row together. If all the probabilities were below the threshold, then
# all the values (and thus their sum) will be 0. Otherwise, if one probability is above the threshold, 
# the sum will be 1. Convert these to boolean values.
high_enough_pred = np.sum(select_matrix, axis=1).astype('bool')

# For each value in pred, if the corresponding value in high_enough_pred is not true, then clear out the prediction 
# for that row. This prevents making wild predictions that have a low likelihood of being correct.
for i, item in enumerate(high_enough_pred) :
    if not high_enough_pred[i] :
        pred[i] = 'UNCATEGORIZED'

# Here are the probabilities of each category that the model predicted for the first violation
pred_prob[0]
# Out:
# array([  5.48228957e-04,   1.18461084e-03,   1.25284437e-03,
#          1.21076483e-03,   6.45422961e-04,   8.15085318e-04,
#          1.01344831e-03,   8.60354326e-04,   9.84542543e-01,
#          1.31477026e-03,   9.24666884e-04,   8.78373541e-04,
#          9.55473610e-04,   8.84810159e-04,   1.23778754e-03,
#          8.60933697e-04,   8.69881263e-04])

# %% [markdown]
# #### Fill in the category column with the predictions

# %%
categories_test['violation_category'] = pred

# Spot-check
categories_test.sample(n=10)
# Out:
#        request_no   date_recv     prop_apn           prop_address       city  \
# 15533  17-1151433  2017-01-18  09512001400      2522  HIBBITTS RD  NASHVILLE
# 25969  15-1124712  2015-09-28  03413007700       171  WELWORTH ST    MADISON
# 34398  17-1158913  2017-06-02  10713007400        1207  AINLAY DR  NASHVILLE
# 20581  17-1161993  2017-07-12  15003010800  3115  JUSTIN TOWNE CT    ANTIOCH
# 49566  16-1133338  2016-05-18  14716010900       362  FAIRLANE DR  NASHVILLE
# 31774  17-1163158  2017-07-26  12006000600        1316  SATURN DR  NASHVILLE
# 6536   17-1165889  2017-08-24  10713006400        1216  AINLAY DR  NASHVILLE
# 16263  16-1140392  2016-05-31  05204007800        229  MANZANO RD    MADISON
# 40779  15-1116064  2015-04-09  16110002800   629  HUNTINGTON PKWY  NASHVILLE
# 12353  16-1143957  2016-08-02  06111019800     1124  EASTDALE AVE  NASHVILLE
#
#       state    zip                prop_owner    complaint_source  \
# 15533    TN  37214    BRANDT, GEORGE C. ETUX               EMAIL
# 25969    TN  37115    OWNER INFO UNAVAILABLE  INSPECTOR REPORTED
# 34398    TN  37217            SPRAKER, ELDON  INSPECTOR REPORTED
# 20581    TN  37013          LONG, SABRINA C.               PHONE
# 49566    TN  37211  Scutella, Joshua Michael               PHONE
# 31774    TN  37217          RYERSON, RICHARD  INSPECTOR REPORTED
# 6536     TN  37217          HIGH FLIGHT, LLC               PHONE
# 16263    TN  37115   RUFO, VIRGILIO B. ET UX               EMAIL
# 40779    TN  37211    OWNER INFO UNAVAILABLE               EMAIL
# 12353    TN  37216           DAVIDSON, DAVID               PHONE
#
#                                         reported_problem  status  \
# 15533  HOW TAKEN:  EMAIL\nJunk trash and debris under...    DONE
# 25969                               PARKING IN THE GRASS    DONE
# 34398    JUNK TRASH AND DEBRIS/ INOPERABLE MOTOR VEHICLE    OPEN
# 20581  High grass/weeds in back yard. Front looks goo...    DONE
# 49566                                      COUCH IN YARD    DONE
# 31774                                              AUDIT    DONE
# 6536                  high grass weeds at corner by road    DONE
# 16263                                              Grass    DONE
# 40779                                   PARKING ON GRASS  CLOSED
# 12353  wrecked vehicle on property; junk trash debris...    DONE
#
#       council_district last_activity_date                last_activity  \
# 15533               15         2017-03-03    Violation Inspection - PS
# 25969               10         2016-07-05           Warrant Check - PS
# 34398               13         2017-07-03    Violation Inspection - PS
# 20581               29         2017-08-14    Violation Inspection - PS
# 49566               30         2016-06-21    Violation Inspection - PS
# 31774               13         2017-08-14    Violation Inspection - PS
# 6536                13         2017-09-12    Violation Inspection - PS
# 16263                9         2016-06-08  Abate Notice Generated - PS
# 40779               27         2015-05-08              CLOSED INCIDENT
# 12353                7         2016-11-17    Violation Inspection - PS
#
#       last_activity_code                                   violations_noted  \
# 15533             VIORES                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 25969             VIORES  EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERI...
# 34398            VIOREIN  EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERI...
# 20581             VIORES                                         HIGH WEEDS
# 49566             VIORES                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 31774             VIORES            EXTERIOR PROP AREA � OPEN STORAGE - ALL
# 6536              VIORES                                         HIGH WEEDS
# 16263          COMPLETED                    EXTERIOR PROP AREA � HIGH WEEDS
# 40779           PSSRCOMP                                   PARKING ON GRASS
# 12353             VIORES  OPEN STORAGE, JUNK, TRASH, DEBRIS,PARKING ON G...
#
#                                               mapped_loc violation_category
# 15533  2522 HIBBITTS RD\nNASHVILLE, TN 37214\n(36.158...              WASTE
# 25969  171 WELWORTH ST\nMADISON, TN 37115\n(36.281863...            VEHICLE
# 34398  1207 AINLAY DR\nNASHVILLE, TN 37217\n(36.12842...            VEHICLE
# 20581  3115 JUSTIN TOWNE CT\nANTIOCH, TN 37013\n(36.0...          LANDSCAPE
# 49566  362 FAIRLANE DR\nNASHVILLE, TN 37211\n(36.0637...              WASTE
# 31774  1316 SATURN DR\nNASHVILLE, TN 37217\n(36.11999...              WASTE
# 6536   1216 AINLAY DR\nNASHVILLE, TN 37217\n(36.12843...          LANDSCAPE
# 16263  229 MANZANO RD\nMADISON, TN 37115\n(36.257525,...          LANDSCAPE
# 40779  629 HUNTINGTON PKWY\nNASHVILLE, TN 37211\n(36....            VEHICLE
# 12353  1124 EASTDALE AVE\nNASHVILLE, TN 37216\n(36.22...            VEHICLE

# %% [markdown]
# #### Here are the counts of each category:

# %%
counts = categories_test.groupby('violation_category').size()
counts
# Out:
# violation_category
# ALCOHOL -- OTHER          3
# ALCOHOL -- PERMITS        1
# ANIMALS/VERMIN           45
# ELECTRICAL              126
# EXTBLD                  774
# FENCING                 482
# FIRE                     33
# INTBLD                  301
# LANDSCAPE              7608
# OCCUPANCY               283
# OTHER/MISC             2544
# PLUMBING                164
# SALES                    10
# SHORT_TERM_RENTAL       110
# SIGNAGE                 918
# UNCATEGORIZED          1413
# VEHICLE                9521
# WASTE                 11610
# dtype: int64

# %%
categories_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35946 entries, 0 to 51912
# Data columns (total 18 columns):
# request_no            35946 non-null object
# date_recv             35946 non-null object
# prop_apn              35810 non-null object
# prop_address          35839 non-null object
# city                  35676 non-null object
# state                 35700 non-null object
# zip                   35816 non-null object
# prop_owner            35946 non-null object
# complaint_source      35872 non-null object
# reported_problem      35318 non-null object
# status                35946 non-null object
# council_district      35775 non-null object
# last_activity_date    35939 non-null object
# last_activity         35939 non-null object
# last_activity_code    35929 non-null object
# violations_noted      35946 non-null object
# mapped_loc            35839 non-null object
# violation_category    35946 non-null object
# dtypes: object(18)
# memory usage: 5.2+ MB

# %%
categories_test.head(10)
# Out:
#     request_no   date_recv     prop_apn          prop_address       city  \
# 0   17-1156755  2017-05-04  05814005400        121  QUEENS LN  NASHVILLE
# 2   17-1157131  2017-05-09  10703001600         715  ERMAC DR  NASHVILLE
# 4   17-1153921  2017-03-06  11813018100   3605B  MAYFLOWER PL  NASHVILLE
# 5   17-1156955  2017-05-08  12001009000     1202  VULTEE BLVD  NASHVILLE
# 6   17-1154514  2017-03-20  11613007600         5971  POST RD  NASHVILLE
# 7   15-1114246  2015-02-11  08102009600       1713  NUBELL ST  NASHVILLE
# 8   17-1153010  2017-02-10  07103005200  2402  DICKERSON PIKE  NASHVILLE
# 9   17-1153720  2017-03-01  14812018200      4641  ARTELIA DR    ANTIOCH
# 10  17-1152787  2017-02-08  14604005100    4712  TROUSDALE DR  NASHVILLE
# 11  17-1154277  2017-03-13  08307022500    2305  EASTLAND AVE  NASHVILLE
#
#    state    zip                                        prop_owner  \
# 0     TN  37218                                  LUSTER, PATRICIA
# 2     TN  37214               H.H. HERITAGE INN OF NASHVILLE, LLC
# 4     TN  37204                       ROBISON, ALEXANDER B. ET UX
# 5     TN  37217                           BARRETT, MALCOLM L. JR.
# 6     TN  37205  ELLIS, STEPHEN NICHOLAS & ODOM, KIMBERLY SUZANNE
# 7     TN  37208                                FREEDOM PROPERTIES
# 8     TN  37207                  ALBARATI, AZIZ M. & HAUTER, AMIN
# 9     TN  37013                        LANDAVERDE, FREDDY ANTONIO
# 10    TN  37220                                  GILLIAM, LEAH C.
# 11    TN  37206          HAITIAN MIN.THEOPHILE CH.IN CHRIST, INC.
#
#       complaint_source                                   reported_problem  \
# 0                EMAIL                      HOW TAKEN:  EMAIL\nHigh grass
# 2                PHONE                                 High grass & weeds
# 4                PHONE                               Junk, trash & debris
# 5                PHONE                           Couch in the front ditch
# 6                PHONE              mattresses and trash on side of road.
# 7   INSPECTOR REPORTED                                   VACANT/UNSECURED
# 8                PHONE  Garage door unsecure - vacant building; food t...
# 9   INSPECTOR REPORTED                                           IMV, JTD
# 10               PHONE               temporary signs and parking on grass
# 11               EMAIL  Haitian Min Theophile Church setting up traile...
#
#    status council_district last_activity_date               last_activity  \
# 0    DONE                1         2017-07-13   Violation Inspection - PS
# 2    DONE               15         2017-07-13  Env Court 1st Setting - PS
# 4    DONE               25         2017-04-06   Violation Inspection - PS
# 5    DONE               13         2017-07-13  Env Court 1st Setting - PS
# 6    DONE               23         2017-04-06   Violation Inspection - PS
# 7    DONE                2         2016-12-08         Final Sign-off - PS
# 8    DONE                5         2017-07-13  Env Court 1st Setting - PS
# 9    DONE               28         2017-07-13  Env Court 1st Setting - PS
# 10   DONE               26         2017-04-06  Env Court 1st Setting - PS
# 11   DONE                6         2017-04-06   Violation Inspection - PS
#
#    last_activity_code                                   violations_noted  \
# 0              VIORES                                         HIGH WEEDS
# 2            DMJCFINE                                         HIGH WEEDS
# 4              VIORES                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 5            DMJUSTCT                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 6              VIORES                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 7              VIORES                    EXTERIOR REPAIR,INTERIOR REPAIR
# 8            DMJCFINE    EXTERIOR OF BUILDINGS � DOORS,USE NOT PERMITTED
# 9            DMJCFINE  EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERI...
# 10           DMJUSTCT                                   PROHIBITED SIGNS
# 11             VIORES                    MOBILE VENDING,PARKING ON GRASS
#
#                                            mapped_loc violation_category
# 0   121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...          LANDSCAPE
# 2   715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...          LANDSCAPE
# 4   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...              WASTE
# 5   1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...              WASTE
# 6   5971 POST RD\nNASHVILLE, TN 37205\n(36.107168,...              WASTE
# 7   1713 NUBELL ST\nNASHVILLE, TN 37208\n(36.18863...      UNCATEGORIZED
# 8   2402 DICKERSON PIKE\nNASHVILLE, TN 37207\n(36....             EXTBLD
# 9   4641 ARTELIA DR\nANTIOCH, TN 37013\n(36.06956,...            VEHICLE
# 10  4712 TROUSDALE DR\nNASHVILLE, TN 37220\n(36.07...            SIGNAGE
# 11  2305 EASTLAND AVE\nNASHVILLE, TN 37206\n(36.18...      UNCATEGORIZED

# %%
#check to see if the dates are strings, or datetime objects
type(categories_test.date_recv)
# Out:
# pandas.core.series.Series

# %%
type(categories_test['date_recv'][99])
# Out:
# datetime.date

# %% [markdown]
# for entry in categories_test['date_recv']:
#     if not print(type(entry)) == "datetime.date":
#         print('non-datetime object detected')
#     else:
#         print('good to go')

# %% [markdown]
# categories_test['date_recv'].info()

# %%
type(categories_test['date_recv'][0])
# Out:
# datetime.date

# %%
type(categories_test['date_recv'][1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-d891d3acb869> in <module>()
# ----> 1 type(categories_test['date_recv'][1])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
type(categories_test['date_recv'][2])
# Out:
# datetime.date

# %%
type(categories_test['date_recv'])
# Out:
# pandas.core.series.Series

# %%
print(type(categories_test['date_recv'][2]))
# Out:
# <class 'datetime.date'>

# %%
categories_test['date_recv'][2].year
# Out:
# 2017

# %%
viols_grid = sns.FacetGrid(categories_test, col = 'council_district', row = 'date_recv'.year)
viols_grid.map(plt.bar, 'violation_category')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-0ff547e9faea> in <module>()
# ----> 1 viols_grid = sns.FacetGrid(categories_test, col = 'council_district', row = 'date_recv'.year)
#       2 viols_grid.map(plt.bar, 'violation_category')
#
# AttributeError: 'str' object has no attribute 'year'

# %%
categories_test['year_recv'] = categories_test.date_recv.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-c87a63e54ad8> in <module>()
# ----> 1 categories_test['year_recv'] = categories_test.date_recv.year
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
categories_test['year_recv'] = categories_test['date_recv'].apply(.year)
# Out:
#   File "<ipython-input-46-ea5757757e9a>", line 1
#     categories_test['year_recv'] = categories_test['date_recv'].apply(.year)
#                                                                       ^
# SyntaxError: invalid syntax

# %%
def get_year(d):
    return d.year

# %%
categories_test['year_recv'] = categories_test['date_recv'].apply(get_year)

# %%
categories_test.council_district.value_counts(dropna=False)
# Out:
# 28     2059
# 7      1981
# 13     1969
# 16     1922
# 21     1844
# 11     1783
# 5      1636
# 8      1591
# 6      1587
# 29     1336
# 9      1311
# 12     1269
# 33     1260
# 3      1168
# 30     1156
# 2      1120
# 15     1107
# 17     1105
# 20     1009
# 14      946
# 26      916
# 19      847
# 1       821
# 31      801
# 27      663
# 24      499
# 10      362
# 22      306
# 32      291
# 18      271
# 35      224
# 4       206
# 25      185
# NaN     171
# 23      144
# 34       80
# Name: council_district, dtype: int64

# %%
categories_test.city.unique()
# Out:
# array(['NASHVILLE', 'ANTIOCH', 'MADISON', 'OLD HICKORY', 'WHITES CREEK',
#        'HERMITAGE', 'GOODLETTSVILLE', 'BRENTWOOD', 'JOELTON', 'PEGRAM',
#        None, 'NOLENSVILLE', 'ASHLAND CITY', 'MOUNT JULIET', 'FRANKLIN',
#        'ANTICOH', 'LAVERGNE'], dtype=object)

# %%
categories_test[categories_test['city'] == ""]
# Out:
# Empty DataFrame
# Columns: [request_no, date_recv, prop_apn, prop_address, city, state, zip, prop_owner, complaint_source, reported_problem, status, council_district, last_activity_date, last_activity, last_activity_code, violations_noted, mapped_loc, violation_category, year_recv]
# Index: []

# %%
categories_test.head(10)
# Out:
#     request_no   date_recv     prop_apn          prop_address       city  \
# 0   17-1156755  2017-05-04  05814005400        121  QUEENS LN  NASHVILLE
# 2   17-1157131  2017-05-09  10703001600         715  ERMAC DR  NASHVILLE
# 4   17-1153921  2017-03-06  11813018100   3605B  MAYFLOWER PL  NASHVILLE
# 5   17-1156955  2017-05-08  12001009000     1202  VULTEE BLVD  NASHVILLE
# 6   17-1154514  2017-03-20  11613007600         5971  POST RD  NASHVILLE
# 7   15-1114246  2015-02-11  08102009600       1713  NUBELL ST  NASHVILLE
# 8   17-1153010  2017-02-10  07103005200  2402  DICKERSON PIKE  NASHVILLE
# 9   17-1153720  2017-03-01  14812018200      4641  ARTELIA DR    ANTIOCH
# 10  17-1152787  2017-02-08  14604005100    4712  TROUSDALE DR  NASHVILLE
# 11  17-1154277  2017-03-13  08307022500    2305  EASTLAND AVE  NASHVILLE
#
#    state    zip                                        prop_owner  \
# 0     TN  37218                                  LUSTER, PATRICIA
# 2     TN  37214               H.H. HERITAGE INN OF NASHVILLE, LLC
# 4     TN  37204                       ROBISON, ALEXANDER B. ET UX
# 5     TN  37217                           BARRETT, MALCOLM L. JR.
# 6     TN  37205  ELLIS, STEPHEN NICHOLAS & ODOM, KIMBERLY SUZANNE
# 7     TN  37208                                FREEDOM PROPERTIES
# 8     TN  37207                  ALBARATI, AZIZ M. & HAUTER, AMIN
# 9     TN  37013                        LANDAVERDE, FREDDY ANTONIO
# 10    TN  37220                                  GILLIAM, LEAH C.
# 11    TN  37206          HAITIAN MIN.THEOPHILE CH.IN CHRIST, INC.
#
#       complaint_source                                   reported_problem  \
# 0                EMAIL                      HOW TAKEN:  EMAIL\nHigh grass
# 2                PHONE                                 High grass & weeds
# 4                PHONE                               Junk, trash & debris
# 5                PHONE                           Couch in the front ditch
# 6                PHONE              mattresses and trash on side of road.
# 7   INSPECTOR REPORTED                                   VACANT/UNSECURED
# 8                PHONE  Garage door unsecure - vacant building; food t...
# 9   INSPECTOR REPORTED                                           IMV, JTD
# 10               PHONE               temporary signs and parking on grass
# 11               EMAIL  Haitian Min Theophile Church setting up traile...
#
#    status council_district last_activity_date               last_activity  \
# 0    DONE                1         2017-07-13   Violation Inspection - PS
# 2    DONE               15         2017-07-13  Env Court 1st Setting - PS
# 4    DONE               25         2017-04-06   Violation Inspection - PS
# 5    DONE               13         2017-07-13  Env Court 1st Setting - PS
# 6    DONE               23         2017-04-06   Violation Inspection - PS
# 7    DONE                2         2016-12-08         Final Sign-off - PS
# 8    DONE                5         2017-07-13  Env Court 1st Setting - PS
# 9    DONE               28         2017-07-13  Env Court 1st Setting - PS
# 10   DONE               26         2017-04-06  Env Court 1st Setting - PS
# 11   DONE                6         2017-04-06   Violation Inspection - PS
#
#    last_activity_code                                   violations_noted  \
# 0              VIORES                                         HIGH WEEDS
# 2            DMJCFINE                                         HIGH WEEDS
# 4              VIORES                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 5            DMJUSTCT                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 6              VIORES                  OPEN STORAGE, JUNK, TRASH, DEBRIS
# 7              VIORES                    EXTERIOR REPAIR,INTERIOR REPAIR
# 8            DMJCFINE    EXTERIOR OF BUILDINGS � DOORS,USE NOT PERMITTED
# 9            DMJCFINE  EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERI...
# 10           DMJUSTCT                                   PROHIBITED SIGNS
# 11             VIORES                    MOBILE VENDING,PARKING ON GRASS
#
#                                            mapped_loc violation_category  \
# 0   121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...          LANDSCAPE
# 2   715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...          LANDSCAPE
# 4   3605B MAYFLOWER PL\nNASHVILLE, TN 37204\n(36.1...              WASTE
# 5   1202 VULTEE BLVD\nNASHVILLE, TN 37217\n(36.123...              WASTE
# 6   5971 POST RD\nNASHVILLE, TN 37205\n(36.107168,...              WASTE
# 7   1713 NUBELL ST\nNASHVILLE, TN 37208\n(36.18863...      UNCATEGORIZED
# 8   2402 DICKERSON PIKE\nNASHVILLE, TN 37207\n(36....             EXTBLD
# 9   4641 ARTELIA DR\nANTIOCH, TN 37013\n(36.06956,...            VEHICLE
# 10  4712 TROUSDALE DR\nNASHVILLE, TN 37220\n(36.07...            SIGNAGE
# 11  2305 EASTLAND AVE\nNASHVILLE, TN 37206\n(36.18...      UNCATEGORIZED
#
#     year_recv
# 0        2017
# 2        2017
# 4        2017
# 5        2017
# 6        2017
# 7        2015
# 8        2017
# 9        2017
# 10       2017
# 11       2017

# %%
viols_grid = sns.FacetGrid(categories_test, col = 'council_district', row = 'year_recv')
viols_grid.map(plt.bar, 'violation_category')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-74dae0f848ba> in <module>()
#       1 viols_grid = sns.FacetGrid(categories_test, col = 'council_district', row = 'year_recv')
# ----> 2 viols_grid.map(plt.bar, 'violation_category')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     729
#     730             # Draw the plot
# --> 731             self._facet_plot(func, ax, plot_args, kwargs)
#     732
#     733         # Finalize the annotations and layout
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     813
#     814         # Draw the plot
# --> 815         func(*plot_args, **plot_kwargs)
#     816
#     817         # Sort out the supporting information
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
categories_test.violation_category.value_counts(dropna=False)
# Out:
# WASTE                 11610
# VEHICLE                9521
# LANDSCAPE              7608
# OTHER/MISC             2544
# UNCATEGORIZED          1413
# SIGNAGE                 918
# EXTBLD                  774
# FENCING                 482
# INTBLD                  301
# OCCUPANCY               283
# PLUMBING                164
# ELECTRICAL              126
# SHORT_TERM_RENTAL       110
# ANIMALS/VERMIN           45
# FIRE                     33
# SALES                    10
# ALCOHOL -- OTHER          3
# ALCOHOL -- PERMITS        1
# Name: violation_category, dtype: int64

# %%
categories_test.year_recv.value_counts(dropna=False)
# Out:
# 2017    14087
# 2016    11355
# 2015     9963
# 2014      541
# Name: year_recv, dtype: int64

# %%
Nashville = categories_test.query('city == "NASHVILLE"')
Nashville.violation_category.value_counts(dropna=False).plot.bar()

# %%
categories_test.city.value_counts(dropna=False)
# Out:
# NASHVILLE         24286
# ANTIOCH            4650
# MADISON            2390
# HERMITAGE          2179
# OLD HICKORY        1515
# NaN                 270
# WHITES CREEK        237
# GOODLETTSVILLE      206
# JOELTON             108
# BRENTWOOD            63
# ASHLAND CITY         17
# MOUNT JULIET          9
# PEGRAM                9
# NOLENSVILLE           4
# FRANKLIN              1
# ANTICOH               1
# LAVERGNE              1
# Name: city, dtype: int64

# %%
Nashville14 = categories_test.query('city == "NASHVILLE" and year_recv == "2014"')
Nashville15 = categories_test.query('city == "NASHVILLE" and year_recv == "2015"')
Nashville16 = categories_test.query('city == "NASHVILLE" and year_recv == "2016"')
Nashville17 = categories_test.query('city == "NASHVILLE" and year_recv == "2017"')
Antioch14 = categories_test.query('city == "ANTIOCH" and year_recv == "2014"')
Antioch15 = categories_test.query('city == "ANTIOCH" and year_recv == "2015"')
Antioch16 = categories_test.query('city == "ANTIOCH" and year_recv == "2016"')
Antioch17 = categories_test.query('city == "ANTIOCH" and year_recv == "2017"')
Madison14 = categories_test.query('city == "MADISON" and year_recv == "2014"')
Madison15 = categories_test.query('city == "MADISON" and year_recv == "2015"')
Madison16 = categories_test.query('city == "MADISON" and year_recv == "2016"')
Madison17 = categories_test.query('city == "MADISON" and year_recv == "2017"')
Hermitage14 = categories_test.query('city == "HERMITAGE" and year_recv == "2014"')
Hermitage15 = categories_test.query('city == "HERMITAGE" and year_recv == "2015"')
Hermitage16 = categories_test.query('city == "HERMITAGE" and year_recv == "2016"')
Hermitage17 = categories_test.query('city == "HERMITAGE" and year_recv == "2017"')
Old_Hickory14 = categories_test.query('city == "OLD HICKORY" and year_recv == "2014"')
Old_Hickory15 = categories_test.query('city == "OLD HICKORY" and year_recv == "2015"')
Old_Hickory16 = categories_test.query('city == "OLD HICKORY" and year_recv == "2016"')
Old_Hickory17 = categories_test.query('city == "OLD HICKORY" and year_recv == "2017"')
Whites_Creek14 = categories_test.query('city == "WHITES CREEK" and year_recv == "2014"')
Whites_Creek15 = categories_test.query('city == "WHITES CREEK" and year_recv == "2015"')
Whites_Creek16 = categories_test.query('city == "WHITES CREEK" and year_recv == "2016"')
Whites_Creek17 = categories_test.query('city == "WHITES CREEK" and year_recv == "2017"')
Goodlettsville14 = categories_test.query('city == "GOODLETTSVILLE" and year_recv == "2014"')
Goodlettsville15 = categories_test.query('city == "GOODLETTSVILLE" and year_recv == "2015"')
Goodlettsville16 = categories_test.query('city == "GOODLETTSVILLE" and year_recv == "2016"')
Goodlettsville17 = categories_test.query('city == "GOODLETTSVILLE" and year_recv == "2017"')
Joelton14 = categories_test.query('city == "JOELTON" and year_recv == "2014"')
Joelton15 = categories_test.query('city == "JOELTON" and year_recv == "2015"')
Joelton16 = categories_test.query('city == "JOELTON" and year_recv == "2016"')
Joelton17 = categories_test.query('city == "JOELTON" and year_recv == "2017"')
Brentwood14 = categories_test.query('city == "BRENTWOOD" and year_recv == "2014"')
Brentwood15 = categories_test.query('city == "BRENTWOOD" and year_recv == "2015"')
Brentwood16 = categories_test.query('city == "BRENTWOOD" and year_recv == "2016"')
Brentwood17 = categories_test.query('city == "BRENTWOOD" and year_recv == "2017"')
Ashland_City14 = categories_test.query('city == "ASHLAND CITY" and year_recv == "2014"')
Ashland_City15 = categories_test.query('city == "ASHLAND CITY" and year_recv == "2015"')
Ashland_City16 = categories_test.query('city == "ASHLAND CITY" and year_recv == "2016"')
Ashland_City17 = categories_test.query('city == "ASHLAND CITY" and year_recv == "2017"')
Mount_Juliet14 = categories_test.query('city == "MOUNT JULIET" and year_recv == "2014"')
Mount_Juliet15 = categories_test.query('city == "MOUNT JULIET" and year_recv == "2015"')
Mount_Juliet16 = categories_test.query('city == "MOUNT JULIET" and year_recv == "2016"')
Mount_Juliet17 = categories_test.query('city == "MOUNT JULIET" and year_recv == "2017"')
Pegram14 = categories_test.query('city == "PEGRAM" and year_recv == "2014"')
Pegram15 = categories_test.query('city == "PEGRAM" and year_recv == "2015"')
Pegram16 = categories_test.query('city == "PEGRAM" and year_recv == "2016"')
Pegram17 = categories_test.query('city == "PEGRAM" and year_recv == "2017"')
Nolensville14 = categories_test.query('city == "NOLENSVILLE" and year_recv == "2014"')
Nolensville15 = categories_test.query('city == "NOLENSVILLE" and year_recv == "2015"')
Nolensville16 = categories_test.query('city == "NOLENSVILLE" and year_recv == "2016"')
Nolensville17 = categories_test.query('city == "NOLENSVILLE" and year_recv == "2017"')
Franklin14 = categories_test.query('city == "FRANKLIN" and year_recv == "2014"')
Franklin15 = categories_test.query('city == "FRANKLIN" and year_recv == "2015"')
Franklin16 = categories_test.query('city == "FRANKLIN" and year_recv == "2016"')
Franklin17 = categories_test.query('city == "FRANKLIN" and year_recv == "2017"')
Lavergne14 = categories_test.query('city == "LAVERGNE" and year_recv == "2014"')
Lavergne15 = categories_test.query('city == "LAVERGNE" and year_recv == "2015"')
Lavergne16 = categories_test.query('city == "LAVERGNE" and year_recv == "2016"')
Lavergne17 = categories_test.query('city == "LAVERGNE" and year_recv == "2017"')

# %%
Nashville14.violation_category.value_counts(dropna=False).plot.bar()

# %%
Nashville15.violation_category.value_counts(dropna=False).plot.bar()

# %%
Nashville16.violation_category.value_counts(dropna=False).plot.bar()

# %%
Nashville17.violation_category.value_counts(dropna=False).plot.bar()

# %%
D1_2017v = categories_test.query('year_recv == "2017" and council_district == "1"')
D1_2017v.info()

# %%
type(D1_2017v.violation_category.value_counts(dropna = False))

# %%
D1_2017v.violation_category.value_counts(dropna = False)

# %%
D1_2017v.violation_category.value_counts(dropna = False)[:1]

# %%
D1_2017v.violation_category.value_counts(dropna = False)[0]

# %%
D1_2017v.violation_category.value_counts(dropna = False)[1]

# %%
#D1_2017v.plot.bar()

# %%
D1_2017v.violation_category.value_counts(dropna = False).plot.bar()

# %%
categories_test.violation_category.value_counts(dropna = False).plot.bar()

# %%
categories_test.columns

# %%
my_colors = 'rgbcymk'
plt.subplot(1,4,1)
Nashville14.violation_category.value_counts(dropna=False).plot(kind = 'bar', title = "Nashville 14", figsize = (20,6), grid = True, color = my_colors, )
plt.subplot(1,4,2)
Nashville15.violation_category.value_counts(dropna=False).plot(kind = 'bar', title = "Nashville 15", grid = True, color = my_colors)
plt.subplot(1,4,3)
Nashville16.violation_category.value_counts(dropna=False).plot(kind = 'bar', title = "Nashville 16", grid = True, color = my_colors)
plt.subplot(1,4,4)
Nashville17.violation_category.value_counts(dropna=False).plot(kind = 'bar', title = "Nashville 17", grid = True, color = my_colors)

# %%
my_colors = 'rgbkymc'
plt.ylabel('Number of Violations', fontsize = 15 )
plt.subplot(2,2,1)
Nashville14.violation_category.value_counts(dropna=False).plot.bar(title = "Nashville14", figsize = (10,8), grid = True)
plt.subplot(2,2,2)
Nashville15.violation_category.value_counts(dropna=False).plot.bar(title = "Nashville15", grid = True)
plt.subplot(2,2,3)
Nashville16.violation_category.value_counts(dropna=False).plot.bar(title = "Nashville16", grid = True)
plt.subplot(2,2,4)
Nashville17.violation_category.value_counts(dropna=False).plot.bar(title = "Nashville17", grid = True)
